# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

csv_file_path='top200_1997.xlsx'

df = pd.read_excel(csv_file_path)
df.head()
# Out:
#          證券代碼           簡稱        年月   市值(百萬元)  收盤價(元)_年     本益比    股價淨值比  \
# 0  19972330.0   台積電         199712.0  457105.0     15.24  3.4636  0.89594
# 1      2303.0  聯電           199712.0  263536.0     20.55  9.1333  1.27240
# 2      2002.0  中鋼           199712.0  181781.0      5.53  2.6209  0.35770
# 3      1303.0  南亞           199712.0  175637.0     14.81  6.6116  0.74949
# 4      2357.0  華碩           199712.0  166991.0    158.47  7.0746  2.59620
#
#      股價營收比  M淨值報酬率─稅後  資產報酬率ROA  ...   利潤邊際NPM   負債/淨值比   M流動比率   M速動比率  \
# 0  1.41640   0.144140  0.223790  ...  0.408870  0.55256  223.86  177.18
# 1  3.38550   0.111460  0.145880  ...  0.388200  0.30889  338.15  303.48
# 2  0.42117   0.077890  0.136380  ...  0.160150  0.75094   85.46   26.60
# 3  0.40821   0.035977  0.099458  ...  0.061046  1.76440  133.30   80.55
# 4  2.39490   0.300880  0.356970  ...  0.329330  0.18643  556.46  476.72
#
#    M存貨週轉率 (次)  M應收帳款週轉次  M營業利益成長率  M稅後淨利成長率   Return  ReturnMean_year_Label
# 0        5.99      6.34    -18.13     -8.00  -6.3648                    1.0
# 1        5.27      6.80    -41.39     27.37 -18.0049                    1.0
# 2        4.10     22.41     44.39     63.01  -9.2224                    1.0
# 3        4.36      7.00      8.65    -15.94 -12.0864                    1.0
# 4        7.60     23.93     52.07     84.82  46.2737                    1.0
#
# [5 rows x 21 columns]

# %%
from sklearn.preprocessing import StandardScaler

columns_to_exclude = ['簡稱', '證券代碼', '年月','ReturnMean_year_Label']

# 排除指定的欄位
features_to_scale = df.drop(columns=columns_to_exclude)

scaler = StandardScaler()
scaled_features = scaler.fit_transform(features_to_scale)

# 將標準化後的特徵資料轉換為 DataFrame
df_feat = pd.DataFrame(scaled_features, columns=features_to_scale.columns)
df_feat.head()
# Out:
#     市值(百萬元)  收盤價(元)_年       本益比     股價淨值比     股價營收比  M淨值報酬率─稅後  資產報酬率ROA  \
# 0  9.522117 -0.335092 -0.060623 -0.370416 -0.312907   1.454294  1.423924
# 1  5.231831 -0.259893 -0.038129 -0.264764  0.162296   0.884739  0.519556
# 2  3.419803 -0.472602 -0.063967 -0.521471 -0.553085   0.299672  0.409282
# 3  3.283627 -0.341182 -0.048133 -0.411517 -0.556213  -0.430800 -0.019304
# 4  3.091996  1.693289 -0.046297  0.106755 -0.076766   4.186002  2.969858
#
#    營業利益率OPM   利潤邊際NPM    負債/淨值比     M流動比率     M速動比率  M存貨週轉率 (次)  M應收帳款週轉次  \
# 0  2.971872  2.582918 -0.611436  0.183285  0.525878   -0.088286 -0.248544
# 1  0.682545  2.402131 -1.081365  1.174071  1.744121   -0.113169 -0.224163
# 2  1.670479  0.407519 -0.228851 -1.016512 -0.926561   -0.153606  0.603203
# 3  0.082855 -0.459282  1.725653 -0.601785 -0.406180   -0.144620 -0.213562
# 4  2.153807  1.887231 -1.317535  3.066612  3.415131   -0.032643  0.683767
#
#    M營業利益成長率  M稅後淨利成長率    Return
# 0 -0.105409 -0.413608  0.342587
# 1 -0.110777 -0.292221  0.013387
# 2 -0.090981 -0.169907  0.261769
# 3 -0.099229 -0.440858  0.180771
# 4 -0.089208 -0.095057  1.831282

# %%
from itertools import combinations
# 所有的欄位
all_columns = ['市值(百萬元)', '收盤價(元)_年', '本益比', '股價淨值比', '股價營收比', 'M淨值報酬率─稅後', '資產報酬率ROA', '營業利益率OPM', '利潤邊際NPM', '負債/淨值比', 'M流動比率', 'M速動比率', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M營業利益成長率', 'M稅後淨利成長率']

# 開始的欄位
start_column = '本益比'

# 開始欄位的索引
start_index = all_columns.index(start_column)

# 創建一個字典來保存結果
column_combinations_dict = {}

# 生成所有可能的欄位組合
for i in range(1, len(all_columns) - start_index + 1):
    for subset in combinations(all_columns[start_index:], i):
        selected_columns = list(subset)
        # 將結果存入字典
        column_combinations_dict[len(column_combinations_dict) + 1] = selected_columns

# 打開一個檔案來保存結果
with open('column_combinations.txt', 'w') as file:
    # 遍歷字典，將結果寫入檔案
    for key, value in column_combinations_dict.items():
        file.write(f"Key: {key}, Selected Columns: {value}\n")
        # 在這裡進行你的分析或模型擬合等操作
        # ...
        file.write("\n" + "="*40 + "\n")

# 提示保存成功
print("Results saved to 'column_combinations.txt'")
# Out:
# Results saved to 'column_combinations.txt'

# %%
max_ret=37.52339415172343
ans={}
list_ans=[]
#選擇特定欄位分析
from sklearn.preprocessing import StandardScaler
#16384
with open('test1.txt', 'a') as file:
    
    for col in range (7120,16384):
        list_ans=[]
        # 指定要選擇的欄位
        selected_columns = column_combinations_dict[col]
        list_ans.append(selected_columns)
        # 選擇指定的欄位
        features_to_scale = df[selected_columns]

        #scaler = StandardScaler()
        scaled_features = scaler.fit_transform(features_to_scale)

        # 將標準化後的特徵資料轉換為 DataFrame
        df_feat = pd.DataFrame(scaled_features, columns=selected_columns)
        print(df_feat.head())
    #--------------------------------------------------------------------------------------------------

        #將資料分成訓練組及測試組
        from sklearn.model_selection import train_test_split

        X = df_feat.dropna()
        print(X)
        y = df.loc[X.index, 'ReturnMean_year_Label']
        print(y)
        X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=101)
        print(X_train, y_train)
    #--------------------------------------------------------------------------------------------------
        error_rate = []
        from sklearn.neighbors import KNeighborsClassifier
        for i in range(1, 100):
            knn = KNeighborsClassifier(n_neighbors=i, p=2, weights='distance', algorithm='brute')
            knn.fit(X_train, y_train)
            pred_i = knn.predict(X_test)
            error_rate.append(np.mean(pred_i != y_test))

        # 將k=1~60的錯誤率製圖畫出。k=23之後，錯誤率就在5-6%之間震盪。
        plt.figure(figsize=(10, 6))
        plt.plot(range(1, 100), error_rate, color='blue', linestyle='dashed', marker='o', markerfacecolor='red', markersize=10)
        plt.title('Error Rate vs. K Value')
        plt.xlabel('K')
        plt.ylabel('Error Rate')
        plt.show()
    #--------------------------------------------------------------------------------------------------
        min_error = min(error_rate)
        optimal_k = error_rate.index(min_error) + 1  # Adding 1 because Python indexing starts from 0

        print(f"Optimal k value for minimum error rate: {optimal_k}")
        print(f"Minimum Error Rate: {min_error}")
        list_ans.append(optimal_k)
    #--------------------------------------------------------------------------------------------------
        #使用KNN演算法
        clf=KNeighborsClassifier(n_neighbors=optimal_k,p=2,weights='distance',algorithm='brute')
        clf.fit(X_train,y_train)
    #--------------------------------------------------------------------------------------------------
        predict_label1={}
        predict_k_pre5={}
    #--------------------------------------------------------------------------------------------------
        for year in range(1998,2010):
            csv_file_path = f'top200_{year}.xlsx'
            new = pd.read_excel(csv_file_path)

            # 排除指定的欄位
            df_temp = new.drop(columns=columns_to_exclude)
            # 選擇指定的欄位
            features_to_scale_new=df_temp[selected_columns]

            # 使用之前訓練好的標準化物件進行標準化
            scaled_features_new = scaler.fit_transform(features_to_scale_new)

            # 將標準化後的特徵資料轉換為 DataFrame
            df_feat_new = pd.DataFrame(scaled_features_new, columns=features_to_scale_new.columns)        

            # 使用已經訓練好的模型進行預測
            predictions_new = clf.predict(df_feat_new)

            #------------------------------
            #測試KNN演算法的好壞
            from sklearn.metrics import classification_report,confusion_matrix
            #將實際類別分為真正例（True Positive）、真負例（True Negative）、偽正例（False Positive）和偽負例（False Negative）
            print('confusion_matrix:')
            print(confusion_matrix(new['ReturnMean_year_Label'],predictions_new))

            #模型的精確度、召回率、F1分數和支持數等指標，用來評估模型對於每個類別的預測性能。
            print('classification_report')
            print(classification_report(new['ReturnMean_year_Label'],predictions_new))

            # 比較預測結果
            accuracy_new = clf.score(df_feat_new, new['ReturnMean_year_Label'])
            print(f'新數據的預測準確率: {accuracy_new}')
            #---------------------------------------
            #print(predictions_new)

            predicted_positive_indices = (predictions_new == 1)

            # 獲取股票名稱
            predicted_positive_stock_names = new.loc[predicted_positive_indices, '簡稱']

            # 設定檔案名稱
            output_file_name = 'selected_stocks_1998.csv'

            # 匯出成 CSV 檔案
            predicted_positive_stock_names.to_csv(output_file_name, index=True)

            # 預測要投資的股票名稱
            print("選擇股票:")
            print(predicted_positive_stock_names)


            # 選擇預測為1的股票
            selected_stocks = new[predictions_new == 1]

            # 計算return
            stock_returns = selected_stocks['Return']

            portfolio_returns = (stock_returns.mean()/100)+1

            print(portfolio_returns)
            predict_label1[year]=portfolio_returns

            # 使用 kneighbors 方法取得最近鄰居的索引和距離
            distances, indices = clf.kneighbors(df_feat_new, n_neighbors=5)

            # 合併所有測試樣本的最近鄰居索引
            all_indices = np.concatenate(indices)
            all_distances = np.concatenate(distances)

            # 將索引和距離組合成一個 2D 陣列，方便排序
            combined_data = np.column_stack((all_indices, all_distances))

            # 按照距離重新排序
            sorted_combined_data = combined_data[np.argsort(combined_data[:, 1])]

            # 選取最近鄰居中預測值為1的前5筆，且不重複
            selected_indices = set()
            i = 0
            while len(selected_indices) < 5 and i < len(sorted_combined_data):
                index = int(sorted_combined_data[i, 0])
                prediction = predictions_new[index]
                if prediction == 1 and index not in selected_indices:
                    selected_indices.add(index)
                i += 1

            # 將選取的索引轉換成列表
            selected_indices_list = list(selected_indices)

            # 打印最近鄰居中預測值為1的前5筆索引
            print("最近鄰居中預測值為1的前5筆索引:")
            print(selected_indices_list)
            select = pd.read_excel(csv_file_path)
            # 獲取股票名稱
            selects_stock = select.loc[selected_indices_list,'簡稱']
            print(selects_stock)
            # 獲取股票return
            selects_ret = select.loc[selected_indices_list,'Return']
            print(selects_ret)
            with open(f'selected_stock/{col}.txt', 'a') as stockfile:
                stockfile.write(selects_stock.to_string())
                stockfile.write('\n')
                stockfile.write(selects_ret.to_string())
            # 計算return
            stock_returns = (selects_ret.mean() / 100)+1
            portfolio_returns = stock_returns
            print(portfolio_returns)
            predict_k_pre5[year]=portfolio_returns
            #print(stock_returns)
        sum1=1
        sum2=1
        print(predict_label1)
        for k in predict_label1.keys():
            if not (predict_label1[k]==0):
                sum1=predict_label1[k]*sum1
        print(f'複利為:{sum1}')
        print('\n')
        print(predict_k_pre5)
        for k in predict_k_pre5.keys():
            if not (predict_k_pre5[k]==0):
                sum2=predict_k_pre5[k]*sum2
        print(f'複利為:{sum2}')
        list_ans.append(sum2)
        ans[col]=list_ans
        file.write(f'{col}:{list_ans}\n\n')
        file.flush()  # 強制將緩衝區內容寫入檔案
        if(sum2>max_ret):
            max_ret=sum2
            with open('max.txt', 'w') as maxfile:
                maxfile.write(f'max:{col}:{list_ans}\n\n')
                maxfile.flush()  # 強制將緩衝區內容寫入檔案
# Out:
#         本益比     股價淨值比  資產報酬率ROA    負債/淨值比     M速動比率  M應收帳款週轉次  M營業利益成長率
# 0 -0.060623 -0.370416  1.423924 -0.611436  0.525878 -0.248544 -0.105409
# 1 -0.038129 -0.264764  0.519556 -1.081365  1.744121 -0.224163 -0.110777
# 2 -0.063967 -0.521471  0.409282 -0.228851 -0.926561  0.603203 -0.090981
# 3 -0.048133 -0.411517 -0.019304  1.725653 -0.406180 -0.213562 -0.099229
# 4 -0.046297  0.106755  2.969858 -1.317535  3.415131  0.683767 -0.089208
#           本益比     股價淨值比  資產報酬率ROA    負債/淨值比     M速動比率  M應收帳款週轉次  M營業利益成長率
# 0   -0.060623 -0.370416  1.423924 -0.611436  0.525878 -0.248544 -0.105409
# 1   -0.038129 -0.264764  0.519556 -1.081365  1.744121 -0.224163 -0.110777
# 2   -0.063967 -0.521471  0.409282 -0.228851 -0.926561  0.603203 -0.090981
# 3   -0.048133 -0.411517 -0.019304  1.725653 -0.406180 -0.213562 -0.099229
# 4   -0.046297  0.106755  2.969858 -1.317535  3.415131  0.683767 -0.089208
# ..        ...       ...       ...       ...       ...       ...       ...
# 195 -0.020360 -0.198700 -0.027917 -1.410935  0.785153 -0.423451 -0.086363
# 196 -0.029794 -0.385355 -0.311369 -0.512907  0.071183 -0.313736 -0.099656
# 197 -0.045048 -0.456510 -0.250462 -1.404532  3.139652 -0.356138 -0.113323
# 198  0.015946 -0.322633 -0.691468  0.453777 -0.971799 -0.342888  0.035129
# 199 -0.048958 -0.456397 -0.346866  0.838329  0.709820 -0.321157 -0.114375
#
# [200 rows x 7 columns]
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 195   -1.0
# 196    1.0
# 197    1.0
# 198    1.0
# 199    1.0
# Name: ReturnMean_year_Label, Length: 200, dtype: float64
#           本益比     股價淨值比  資產報酬率ROA    負債/淨值比     M速動比率  M應收帳款週轉次  M營業利益成長率
# 85  -0.021605 -0.377904 -0.485080  0.325143 -0.264775 -0.116038 -0.054000
# 183  0.006969  0.180733 -0.088660  2.809496 -1.043756  0.329181  0.061530
# 127  0.069751 -0.097387 -0.580857 -1.219546 -0.723424 -0.003143 -0.099965
# 53   0.101419  0.180340 -0.496201  1.443121  0.392093 -0.321157 -0.131441
# 100  0.026539 -0.416501 -0.843310  0.199479 -0.405601 -0.290415 -0.061074
# ..        ...       ...       ...       ...       ...       ...       ...
# 63  -0.030793 -0.389404 -0.420958  2.216083 -0.558773 -0.033354 -0.093226
# 70  -0.045646 -0.364211  0.158320 -0.982836 -0.762972  0.326001 -0.099711
# 81   0.006834  0.282720  0.257219 -0.088646  0.003953  0.102332 -0.086268
# 11   0.730437  2.303706 -0.687045  0.817694 -0.721399 -0.284585 -0.129059
# 95  -0.198790 -0.255138 -1.533502 -0.607059 -0.443315  0.005867 -0.117340
#
# [140 rows x 7 columns] 85    -1.0
# 183    1.0
# 127   -1.0
# 53    -1.0
# 100   -1.0
#       ...
# 63     1.0
# 70     1.0
# 81     1.0
# 11     1.0
# 95    -1.0
# Name: ReturnMean_year_Label, Length: 140, dtype: float64
# Optimal k value for minimum error rate: 14
# Minimum Error Rate: 0.3
# confusion_matrix:
# [[105  21]
#  [ 44  30]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.70      0.83      0.76       126
#            1       0.59      0.41      0.48        74
#
#     accuracy                           0.68       200
#    macro avg       0.65      0.62      0.62       200
# weighted avg       0.66      0.68      0.66       200
#
# 新數據的預測準確率: 0.675
# 選擇股票:
# 0       台積電
# 1      華碩
# 2      南亞
# 5      鴻海
# 6       英業達
# 7       日月光
# 8       華邦電
# 10     華通
# 15     裕隆
# 17      台達電
# 18     矽品
# 21     華宇
# 24     寶成
# 26      統一超
# 28     中環
# 34     聯強
# 37     華新
# 39     神達
# 40     技嘉
# 50      楠梓電
# 54      震旦行
# 59     旭麗
# 67     和泰
# 68     中鼎
# 72     微星
# 75     六福
# 79     長興
# 89      第一店
# 97     國聯
# 98     立榮
# 105    巨大
# 111    泰豐
# 114    冠德
# 120    智邦
# 122    建大
# 137    云辰
# 141    佳鼎
# 146    宏碁
# 152    統領
# 154    味全
# 156    合勤
# 160    金緯
# 161    亞聚
# 168    東訊
# 170    燦坤
# 173    華紙
# 175    國電
# 176    虹光
# 181    美格
# 182    大華
# 191     劍湖山
# Name: 簡稱, dtype: object
# 1.342291725490196
# 最近鄰居中預測值為1的前5筆索引:
# [0, 10, 15, 120, 89]
# 0       台積電
# 10     華通
# 15     裕隆
# 120    智邦
# 89      第一店
# Name: 簡稱, dtype: object
# 0      193.2025
# 10       5.8307
# 15     -45.9188
# 120    153.0937
# 89      10.5944
# Name: Return, dtype: float64
# 1.633605
# confusion_matrix:
# [[79 32]
#  [53 36]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.60      0.71      0.65       111
#            1       0.53      0.40      0.46        89
#
#     accuracy                           0.57       200
#    macro avg       0.56      0.56      0.55       200
# weighted avg       0.57      0.57      0.56       200
#
# 新數據的預測準確率: 0.575
# 選擇股票:
# 0       台積電
# 1      聯電
# 2      華碩
# 4      宏電
# 5      廣達
#           ...
# 177    中鴻
# 183    巨大
# 185    冠德
# 187    燦坤
# 189     中興電
# Name: 簡稱, Length: 68, dtype: object
# 0.5942519558823529
# 最近鄰居中預測值為1的前5筆索引:
# [66, 8, 9, 109, 25]
# 66     勝華
# 8      台塑
# 9      茂德
# 109    世平
# 25     聯強
# Name: 簡稱, dtype: object
# 66    -42.8671
# 8     -18.0935
# 9     -59.5213
# 109   -40.9449
# 25    -70.0025
# Name: Return, dtype: float64
# 0.5371414
# confusion_matrix:
# [[87 40]
#  [43 30]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.67      0.69      0.68       127
#            1       0.43      0.41      0.42        73
#
#     accuracy                           0.58       200
#    macro avg       0.55      0.55      0.55       200
# weighted avg       0.58      0.58      0.58       200
#
# 新數據的預測準確率: 0.585
# 選擇股票:
# 0       台積電
# 2      聯電
# 3      鴻海
# 6      中鋼
# 7      華碩
#           ...
# 170     遠雄港
# 173    特力
# 176      匯僑工業
# 196    鴻準
# 198    強茂
# Name: 簡稱, Length: 70, dtype: object
# 1.5096184857142858
# 最近鄰居中預測值為1的前5筆索引:
# [9, 109, 77, 84, 127]
# 9      威盛
# 109     禾伸堂
# 77     晶華
# 84     宏碁
# 127    鑽全
# Name: 簡稱, dtype: object
# 9      28.5075
# 109    46.1834
# 77    -29.5122
# 84     39.6409
# 127     8.2527
# Name: Return, dtype: float64
# 1.1861446
# confusion_matrix:
# [[68 50]
#  [54 28]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.56      0.58      0.57       118
#            1       0.36      0.34      0.35        82
#
#     accuracy                           0.48       200
#    macro avg       0.46      0.46      0.46       200
# weighted avg       0.48      0.48      0.48       200
#
# 新數據的預測準確率: 0.48
# 選擇股票:
# 3      鴻海
# 4       聯發科
# 5       台灣大
# 17      台達電
# 21     精英
#           ...
# 177    科風
# 182    中碳
# 187    嘉泥
# 188    訊連
# 196     潤泰新
# Name: 簡稱, Length: 78, dtype: object
# 0.8509959743589743
# 最近鄰居中預測值為1的前5筆索引:
# [100, 74, 109, 119, 95]
# 100     三商行
# 74      中光電
# 109    光罩
# 119    云辰
# 95     群光
# Name: 簡稱, dtype: object
# 100   -33.8859
# 74    -46.1036
# 109   -21.8798
# 119   -52.2576
# 95    -10.4196
# Name: Return, dtype: float64
# 0.670907
# confusion_matrix:
# [[76 40]
#  [64 20]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.54      0.66      0.59       116
#            1       0.33      0.24      0.28        84
#
#     accuracy                           0.48       200
#    macro avg       0.44      0.45      0.44       200
# weighted avg       0.45      0.48      0.46       200
#
# 新數據的預測準確率: 0.48
# 選擇股票:
# 3      鴻海
# 8      廣達
# 9       聯發科
# 10      台灣大
# 13     友達
# 14     中華
# 16     裕隆
# 21     宏碁
# 24      台達電
# 26     瑞昱
# 30      統一超
# 33      建興電
# 36      英業達
# 44     彩晶
# 46     微星
# 47     錸德
# 56     精英
# 58      宏達電
# 63     D 復盛
# 66     合勤
# 69     金寶
# 70     聯詠
# 71     茂矽
# 75      大立光
# 76     華通
# 78     台肥
# 81     友訊
# 85     華宇
# 89      晶豪科
# 92     創見
# 94     瑞軒
# 96      鼎創達
# 97     勝華
# 100    正崴
# 116     中光電
# 124    特力
# 127     美隆電
# 129     敦陽科
# 139    普誠
# 141    光罩
# 142    全國
# 150    思源
# 153    華立
# 155    智冠
# 158    鑽全
# 161    益登
# 165    正文
# 168    松翰
# 170    橘子
# 173    中碳
# 174    晶電
# 175    帆宣
# 180    綠點
# 181    揚智
# 184     偉詮電
# 188    毅嘉
# 191    崇越
# 195    神基
# 198    國聯
# 199    普安
# Name: 簡稱, dtype: object
# 1.2386948466666667
# 最近鄰居中預測值為1的前5筆索引:
# [100, 9, 14, 16, 89]
# 100    正崴
# 9       聯發科
# 14     中華
# 16     裕隆
# 89      晶豪科
# Name: 簡稱, dtype: object
# 100    24.59600
# 9      58.82350
# 14     -0.75205
# 16      5.92150
# 89    -19.08210
# Name: Return, dtype: float64
# 1.1390137
# confusion_matrix:
# [[66 32]
#  [63 39]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.51      0.67      0.58        98
#            1       0.55      0.38      0.45       102
#
#     accuracy                           0.53       200
#    macro avg       0.53      0.53      0.52       200
# weighted avg       0.53      0.53      0.51       200
#
# 新數據的預測準確率: 0.525
# 選擇股票:
# 4      鴻海
# 5      南亞
# 7      中鋼
# 10      聯發科
# 13     仁寶
#           ...
# 184     威達電
# 185     華晶科
# 188    泰豐
# 190    憶聲
# 194     宏正科
# Name: 簡稱, Length: 71, dtype: object
# 1.0370788746478874
# 最近鄰居中預測值為1的前5筆索引:
# [98, 40, 107, 84, 25]
# 98     創見
# 40     萬海
# 107    億光
# 84     群光
# 25     遠傳
# Name: 簡稱, dtype: object
# 98     19.7101
# 40     21.0459
# 107   -37.3732
# 84    -39.4586
# 25     74.4994
# Name: Return, dtype: float64
# 1.0768472
# confusion_matrix:
# [[91 39]
#  [44 26]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.67      0.70      0.69       130
#            1       0.40      0.37      0.39        70
#
#     accuracy                           0.58       200
#    macro avg       0.54      0.54      0.54       200
# weighted avg       0.58      0.58      0.58       200
#
# 新數據的預測準確率: 0.585
# 選擇股票:
# 2       台塑化
# 5      中鋼
# 6      南亞
# 7      台化
# 8      台塑
#           ...
# 184     四維航
# 186    世平
# 187    亞翔
# 193    威剛
# 196    華立
# Name: 簡稱, Length: 65, dtype: object
# 1.2392813
# 最近鄰居中預測值為1的前5筆索引:
# [133, 102, 103, 72, 87]
# 133    景碩
# 102    新興
# 103     京元電
# 72     勝華
# 87     創見
# Name: 簡稱, dtype: object
# 133    163.1637
# 102     -9.8821
# 103     99.0573
# 72      89.4196
# 87       9.1756
# Name: Return, dtype: float64
# 1.7018681999999998
# confusion_matrix:
# [[72 40]
#  [57 31]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.56      0.64      0.60       112
#            1       0.44      0.35      0.39        88
#
#     accuracy                           0.52       200
#    macro avg       0.50      0.50      0.49       200
# weighted avg       0.50      0.52      0.51       200
#
# 新數據的預測準確率: 0.515
# 選擇股票:
# 0       台積電
# 3      南亞
# 4       聯發科
# 7      台塑
# 8      中鋼
#           ...
# 187    中鼎
# 189    矽創
# 195    育富
# 197    圓剛
# 198    群聯
# Name: 簡稱, Length: 71, dtype: object
# 1.2643408763380282
# 最近鄰居中預測值為1的前5筆索引:
# [4, 109, 77, 48, 26]
# 4       聯發科
# 109    頎邦
# 77     瑞儀
# 48     力成
# 26     可成
# Name: 簡稱, dtype: object
# 4       1.2951
# 109   -39.6236
# 77    -24.8293
# 48     52.9836
# 26     69.8244
# Name: Return, dtype: float64
# 1.1193004
# confusion_matrix:
# [[82 33]
#  [60 25]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.71      0.64       115
#            1       0.43      0.29      0.35        85
#
#     accuracy                           0.54       200
#    macro avg       0.50      0.50      0.49       200
# weighted avg       0.52      0.54      0.52       200
#
# 新數據的預測準確率: 0.535
# 選擇股票:
# 4      南亞
# 8       聯發科
# 12      宏達電
# 15      台達電
# 25     可成
# 28      華亞科
# 30     統一
# 31     南科
# 32     茂德
# 36     聯詠
# 39      英業達
# 40     力成
# 43     台肥
# 49     華寶
# 74      英華達
# 76     國建
# 78     裕民
# 80     景碩
# 82     國巨
# 83     茂矽
# 84     長興
# 90     億光
# 91      京元電
# 92     創見
# 93     雅新
# 94     友訊
# 96      中光電
# 97      裕日車
# 100    立錡
# 104    伍豐
# 112    遠百
# 120    群聯
# 124    新興
# 126    閎暉
# 128     新日興
# 129    瑞儀
# 130    太子
# 137     華新科
# 139    中鼎
# 143    新普
# 145    信義
# 147     威力盟
# 149    飛瑞
# 152     興富發
# 156    皇翔
# 158    訊連
# 162    合晶
# 168     華晶科
# 169    嘉泥
# 175    華立
# 177    啟碁
# 179     大成鋼
# 188    美律
# 189    陞泰
# 190    鄉林
# 191    普安
# 192    華固
# 194     大聯大
# Name: 簡稱, dtype: object
# 1.1125177413793104
# 最近鄰居中預測值為1的前5筆索引:
# [100, 43, 84, 25, 90]
# 100    立錡
# 43     台肥
# 84     長興
# 25     可成
# 90     億光
# Name: 簡稱, dtype: object
# 100    32.4277
# 43     32.8709
# 84    -19.3748
# 25    -21.5679
# 90     39.8760
# Name: Return, dtype: float64
# 1.1284638
# confusion_matrix:
# [[76 36]
#  [54 34]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.68      0.63       112
#            1       0.49      0.39      0.43        88
#
#     accuracy                           0.55       200
#    macro avg       0.54      0.53      0.53       200
# weighted avg       0.54      0.55      0.54       200
#
# 新數據的預測準確率: 0.55
# 選擇股票:
# 2       台塑化
# 3      南亞
# 5      台塑
# 9       聯發科
# 11      宏達電
#           ...
# 189    神基
# 190    鈊象
# 193    佰鴻
# 195     海韻電
# 196    華立
# Name: 簡稱, Length: 70, dtype: object
# 0.5155377714285714
# 最近鄰居中預測值為1的前5筆索引:
# [100, 134, 103, 9, 43]
# 100    台橡
# 134    致茂
# 103     信昌化
# 9       聯發科
# 43     裕民
# Name: 簡稱, dtype: object
# 100   -36.7860
# 134   -63.9590
# 103   -78.0456
# 9     -42.2294
# 43    -50.3668
# Name: Return, dtype: float64
# 0.45722640000000003
# confusion_matrix:
# [[87 30]
#  [48 35]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.64      0.74      0.69       117
#            1       0.54      0.42      0.47        83
#
#     accuracy                           0.61       200
#    macro avg       0.59      0.58      0.58       200
# weighted avg       0.60      0.61      0.60       200
#
# 新數據的預測準確率: 0.61
# 選擇股票:
# 3      鴻海
# 13      台達電
# 18     聯電
# 22     亞泥
# 26      日月光
#           ...
# 187    信義
# 191    特力
# 194     順達科
# 195    大榮
# 199     中聯資
# Name: 簡稱, Length: 65, dtype: object
# 2.2209320923076925
# 最近鄰居中預測值為1的前5筆索引:
# [41, 109, 84, 90, 95]
# 41     裕民
# 109     中光電
# 84     億光
# 90     瑞昱
# 95     中鼎
# Name: 簡稱, dtype: object
# 41      80.9351
# 109    189.3970
# 84     188.5513
# 90     209.0255
# 95      53.1234
# Name: Return, dtype: float64
# 2.4420645999999997
# confusion_matrix:
# [[123  77]
#  [  0   0]]
# classification_report
#               precision    recall  f1-score   support
#
#         -1.0       1.00      0.61      0.76       200
#          1.0       0.00      0.00      0.00         0
#
#     accuracy                           0.61       200
#    macro avg       0.50      0.31      0.38       200
# weighted avg       1.00      0.61      0.76       200
#
# 新數據的預測準確率: 0.615
# 選擇股票:
# 1      鴻海
# 4       聯發科
# 7      台塑
# 10      宏達電
# 11     廣達
#           ...
# 187    台聚
# 191    川湖
# 194    聯成
# 198    太子
# 199    志超
# Name: 簡稱, Length: 77, dtype: object
# 0.0
# 最近鄰居中預測值為1的前5筆索引:
# [74, 14, 20, 25, 26]
# 74    網龍
# 14     台灣大
# 20     日月光
# 25    正新
# 26    鴻準
# Name: 簡稱, dtype: object
# 74   -100
# 14   -100
# 20   -100
# 25   -100
# 26   -100
# Name: Return, dtype: int64
# 0.0
# {1998: 1.342291725490196, 1999: 0.5942519558823529, 2000: 1.5096184857142858, 2001: 0.8509959743589743, 2002: 1.2386948466666667, 2003: 1.0370788746478874, 2004: 1.2392813, 2005: 1.2643408763380282, 2006: 1.1125177413793104, 2007: 0.5155377714285714, 2008: 2.2209320923076925, 2009: 0.0}
# 複利為:2.6273936907537
#
#
# {1998: 1.633605, 1999: 0.5371414, 2000: 1.1861446, 2001: 0.670907, 2002: 1.1390137, 2003: 1.0768472, 2004: 1.7018681999999998, 2005: 1.1193004, 2006: 1.1284638, 2007: 0.45722640000000003, 2008: 2.4420645999999997, 2009: 0.0}
# 複利為:2.055735954642835
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#         本益比     股價淨值比  資產報酬率ROA    負債/淨值比     M速動比率  M應收帳款週轉次  M稅後淨利成長率
# 0 -0.060623 -0.370416  1.423924 -0.611436  0.525878 -0.248544 -0.413608
# 1 -0.038129 -0.264764  0.519556 -1.081365  1.744121 -0.224163 -0.292221
# 2 -0.063967 -0.521471  0.409282 -0.228851 -0.926561  0.603203 -0.169907
# 3 -0.048133 -0.411517 -0.019304  1.725653 -0.406180 -0.213562 -0.440858
# 4 -0.046297  0.106755  2.969858 -1.317535  3.415131  0.683767 -0.095057
#           本益比     股價淨值比  資產報酬率ROA    負債/淨值比     M速動比率  M應收帳款週轉次  M稅後淨利成長率
# 0   -0.060623 -0.370416  1.423924 -0.611436  0.525878 -0.248544 -0.413608
# 1   -0.038129 -0.264764  0.519556 -1.081365  1.744121 -0.224163 -0.292221
# 2   -0.063967 -0.521471  0.409282 -0.228851 -0.926561  0.603203 -0.169907
# 3   -0.048133 -0.411517 -0.019304  1.725653 -0.406180 -0.213562 -0.440858
# 4   -0.046297  0.106755  2.969858 -1.317535  3.415131  0.683767 -0.095057
# ..        ...       ...       ...       ...       ...       ...       ...
# 195 -0.020360 -0.198700 -0.027917 -1.410935  0.785153 -0.423451  0.122768
# 196 -0.029794 -0.385355 -0.311369 -0.512907  0.071183 -0.313736 -0.406504
# 197 -0.045048 -0.456510 -0.250462 -1.404532  3.139652 -0.356138 -0.440274
# 198  0.015946 -0.322633 -0.691468  0.453777 -0.971799 -0.342888  5.493014
# 199 -0.048958 -0.456397 -0.346866  0.838329  0.709820 -0.321157 -0.538325
#
# [200 rows x 7 columns]
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 195   -1.0
# 196    1.0
# 197    1.0
# 198    1.0
# 199    1.0
# Name: ReturnMean_year_Label, Length: 200, dtype: float64
#           本益比     股價淨值比  資產報酬率ROA    負債/淨值比     M速動比率  M應收帳款週轉次  M稅後淨利成長率
# 85  -0.021605 -0.377904 -0.485080  0.325143 -0.264775 -0.116038 -0.369337
# 183  0.006969  0.180733 -0.088660  2.809496 -1.043756  0.329181  5.236375
# 127  0.069751 -0.097387 -0.580857 -1.219546 -0.723424 -0.003143 -0.325751
# 53   0.101419  0.180340 -0.496201  1.443121  0.392093 -0.321157 -0.415530
# 100  0.026539 -0.416501 -0.843310  0.199479 -0.405601 -0.290415 -0.487669
# ..        ...       ...       ...       ...       ...       ...       ...
# 63  -0.030793 -0.389404 -0.420958  2.216083 -0.558773 -0.033354  0.285029
# 70  -0.045646 -0.364211  0.158320 -0.982836 -0.762972  0.326001 -0.270600
# 81   0.006834  0.282720  0.257219 -0.088646  0.003953  0.102332 -0.222828
# 11   0.730437  2.303706 -0.687045  0.817694 -0.721399 -0.284585 -0.578032
# 95  -0.198790 -0.255138 -1.533502 -0.607059 -0.443315  0.005867 -0.893083
#
# [140 rows x 7 columns] 85    -1.0
# 183    1.0
# 127   -1.0
# 53    -1.0
# 100   -1.0
#       ...
# 63     1.0
# 70     1.0
# 81     1.0
# 11     1.0
# 95    -1.0
# Name: ReturnMean_year_Label, Length: 140, dtype: float64
# Optimal k value for minimum error rate: 14
# Minimum Error Rate: 0.3333333333333333
# confusion_matrix:
# [[96 30]
#  [44 30]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.69      0.76      0.72       126
#            1       0.50      0.41      0.45        74
#
#     accuracy                           0.63       200
#    macro avg       0.59      0.58      0.58       200
# weighted avg       0.62      0.63      0.62       200
#
# 新數據的預測準確率: 0.63
# 選擇股票:
# 0       台積電
# 1      華碩
# 2      南亞
# 5      鴻海
# 6       英業達
# 7       日月光
# 8       華邦電
# 10     華通
# 11     仁寶
# 15     裕隆
# 17      台達電
# 21     華宇
# 23     長榮
# 24     寶成
# 26      統一超
# 28     中環
# 34     聯強
# 35     大眾
# 37     華新
# 40     技嘉
# 47     台鳳
# 49     凌陽
# 50      楠梓電
# 54      震旦行
# 59     旭麗
# 66     士電
# 67     和泰
# 72     微星
# 75     六福
# 79     長興
# 89      第一店
# 97     國聯
# 102    D 復盛
# 103    耀文
# 105    巨大
# 114    冠德
# 120    智邦
# 122    建大
# 124    勝華
# 127    英誌
# 138    力山
# 141    佳鼎
# 146    宏碁
# 152    統領
# 155    D 致伸
# 160    金緯
# 161    亞聚
# 165     聯上發
# 167    欣錩
# 168    東訊
# 170    燦坤
# 173    華紙
# 175    國電
# 176    虹光
# 179     堤維西
# 180    民興
# 181    美格
# 188     中興電
# 191     劍湖山
# 196    中友
# Name: 簡稱, dtype: object
# 1.2633527666666666
# 最近鄰居中預測值為1的前5筆索引:
# [0, 103, 10, 120, 26]
# 0       台積電
# 103    耀文
# 10     華通
# 120    智邦
# 26      統一超
# Name: 簡稱, dtype: object
# 0      193.2025
# 103    -39.2704
# 10       5.8307
# 120    153.0937
# 26      62.5085
# Name: Return, dtype: float64
# 1.7507300000000001
# confusion_matrix:
# [[75 36]
#  [55 34]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.68      0.62       111
#            1       0.49      0.38      0.43        89
#
#     accuracy                           0.55       200
#    macro avg       0.53      0.53      0.53       200
# weighted avg       0.54      0.55      0.54       200
#
# 新數據的預測準確率: 0.545
# 選擇股票:
# 0       台積電
# 2      華碩
# 4      宏電
# 5      廣達
# 6      鴻海
#           ...
# 183    巨大
# 185    冠德
# 187    燦坤
# 189     中興電
# 192    佳格
# Name: 簡稱, Length: 70, dtype: object
# 0.5774814142857143
# 最近鄰居中預測值為1的前5筆索引:
# [8, 53, 25, 26, 28]
# 8     台塑
# 53    國電
# 25    聯強
# 26     統一超
# 28    精業
# Name: 簡稱, dtype: object
# 8    -18.0935
# 53   -13.9989
# 25   -70.0025
# 26   -22.9665
# 28   -74.0175
# Name: Return, dtype: float64
# 0.6018422000000001
# confusion_matrix:
# [[85 42]
#  [42 31]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.67      0.67      0.67       127
#            1       0.42      0.42      0.42        73
#
#     accuracy                           0.58       200
#    macro avg       0.55      0.55      0.55       200
# weighted avg       0.58      0.58      0.58       200
#
# 新數據的預測準確率: 0.58
# 選擇股票:
# 0       台積電
# 2      聯電
# 3      鴻海
# 4      南亞
# 6      中鋼
#           ...
# 163    台南
# 170     遠雄港
# 173    特力
# 176      匯僑工業
# 198    強茂
# Name: 簡稱, Length: 73, dtype: object
# 1.5238478219178082
# 最近鄰居中預測值為1的前5筆索引:
# [135, 71, 9, 109, 127]
# 135    飛宏
# 71     D 復盛
# 9      威盛
# 109     禾伸堂
# 127    鑽全
# Name: 簡稱, dtype: object
# 135    155.9271
# 71      65.0935
# 9       28.5075
# 109     46.1834
# 127      8.2527
# Name: Return, dtype: float64
# 1.6079284
# confusion_matrix:
# [[67 51]
#  [54 28]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.55      0.57      0.56       118
#            1       0.35      0.34      0.35        82
#
#     accuracy                           0.48       200
#    macro avg       0.45      0.45      0.45       200
# weighted avg       0.47      0.47      0.47       200
#
# 新數據的預測準確率: 0.475
# 選擇股票:
# 3      鴻海
# 4       聯發科
# 5       台灣大
# 14     仁寶
# 17      台達電
#           ...
# 182    中碳
# 185    健鼎
# 187    嘉泥
# 188    訊連
# 196     潤泰新
# Name: 簡稱, Length: 79, dtype: object
# 0.8435692658227848
# 最近鄰居中預測值為1的前5筆索引:
# [129, 100, 71, 118, 119]
# 129    崇越
# 100     三商行
# 71     台肥
# 118    迎廣
# 119    云辰
# Name: 簡稱, dtype: object
# 129   -27.2886
# 100   -33.8859
# 71    -10.9445
# 118   -64.2834
# 119   -52.2576
# Name: Return, dtype: float64
# 0.62268
# confusion_matrix:
# [[75 41]
#  [59 25]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.56      0.65      0.60       116
#            1       0.38      0.30      0.33        84
#
#     accuracy                           0.50       200
#    macro avg       0.47      0.47      0.47       200
# weighted avg       0.48      0.50      0.49       200
#
# 新數據的預測準確率: 0.5
# 選擇股票:
# 0       台積電
# 3      鴻海
# 8      廣達
# 9       聯發科
# 10      台灣大
#           ...
# 188    毅嘉
# 191    崇越
# 195    神基
# 198    國聯
# 199    普安
# Name: 簡稱, Length: 66, dtype: object
# 1.2518522393939393
# 最近鄰居中預測值為1的前5筆索引:
# [100, 133, 9, 14, 89]
# 100    正崴
# 133    遠雄
# 9       聯發科
# 14     中華
# 89      晶豪科
# Name: 簡稱, dtype: object
# 100    24.59600
# 133    30.76070
# 9      58.82350
# 14     -0.75205
# 89    -19.08210
# Name: Return, dtype: float64
# 1.1886921
# confusion_matrix:
# [[65 33]
#  [61 41]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.52      0.66      0.58        98
#            1       0.55      0.40      0.47       102
#
#     accuracy                           0.53       200
#    macro avg       0.53      0.53      0.52       200
# weighted avg       0.54      0.53      0.52       200
#
# 新數據的預測準確率: 0.53
# 選擇股票:
# 4      鴻海
# 5      南亞
# 7      中鋼
# 9      廣達
# 10      聯發科
#           ...
# 188    泰豐
# 190    憶聲
# 192    健鼎
# 194     宏正科
# 196    春源
# Name: 簡稱, Length: 74, dtype: object
# 1.0394669743243243
# 最近鄰居中預測值為1的前5筆索引:
# [98, 40, 9, 104, 25]
# 98     創見
# 40     萬海
# 9      廣達
# 104    力成
# 25     遠傳
# Name: 簡稱, dtype: object
# 98     19.7101
# 40     21.0459
# 9     -21.4692
# 104    49.8310
# 25     74.4994
# Name: Return, dtype: float64
# 1.2872344
# confusion_matrix:
# [[87 43]
#  [41 29]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.68      0.67      0.67       130
#            1       0.40      0.41      0.41        70
#
#     accuracy                           0.58       200
#    macro avg       0.54      0.54      0.54       200
# weighted avg       0.58      0.58      0.58       200
#
# 新數據的預測準確率: 0.58
# 選擇股票:
# 2       台塑化
# 3      鴻海
# 5      中鋼
# 6      南亞
# 7      台化
#           ...
# 186    世平
# 187    亞翔
# 192    成霖
# 193    威剛
# 196    華立
# Name: 簡稱, Length: 72, dtype: object
# 1.2527236958333332
# 最近鄰居中預測值為1的前5筆索引:
# [133, 72, 8, 10, 120]
# 133    景碩
# 72     勝華
# 8      台塑
# 10     華碩
# 120     晶豪科
# Name: 簡稱, dtype: object
# 133    163.1637
# 72      89.4196
# 8        7.6672
# 10      35.7677
# 120    -32.6188
# Name: Return, dtype: float64
# 1.5267988
# confusion_matrix:
# [[72 40]
#  [59 29]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.55      0.64      0.59       112
#            1       0.42      0.33      0.37        88
#
#     accuracy                           0.51       200
#    macro avg       0.48      0.49      0.48       200
# weighted avg       0.49      0.51      0.49       200
#
# 新數據的預測準確率: 0.505
# 選擇股票:
# 0       台積電
# 1      鴻海
# 3      南亞
# 4       聯發科
# 5      華碩
#           ...
# 186     興富發
# 187    中鼎
# 189    矽創
# 195    育富
# 198    群聯
# Name: 簡稱, Length: 69, dtype: object
# 1.2519948472463769
# 最近鄰居中預測值為1的前5筆索引:
# [100, 4, 77, 48, 26]
# 100    長興
# 4       聯發科
# 77     瑞儀
# 48     力成
# 26     可成
# Name: 簡稱, dtype: object
# 100    121.5729
# 4        1.2951
# 77     -24.8293
# 48      52.9836
# 26      69.8244
# Name: Return, dtype: float64
# 1.4416934
# confusion_matrix:
# [[83 32]
#  [55 30]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.60      0.72      0.66       115
#            1       0.48      0.35      0.41        85
#
#     accuracy                           0.56       200
#    macro avg       0.54      0.54      0.53       200
# weighted avg       0.55      0.56      0.55       200
#
# 新數據的預測準確率: 0.565
# 選擇股票:
# 2       台塑化
# 4      南亞
# 8       聯發科
# 12      宏達電
# 15      台達電
#           ...
# 190    鄉林
# 191    普安
# 192    華固
# 194     大聯大
# 197     金像電
# Name: 簡稱, Length: 62, dtype: object
# 1.1398821048387098
# 最近鄰居中預測值為1的前5筆索引:
# [100, 72, 8, 43, 90]
# 100    立錡
# 72     凌陽
# 8       聯發科
# 43     台肥
# 90     億光
# Name: 簡稱, dtype: object
# 100    32.4277
# 72    -21.0797
# 8      37.0692
# 43     32.8709
# 90     39.8760
# Name: Return, dtype: float64
# 1.2423282
# confusion_matrix:
# [[73 39]
#  [48 40]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.60      0.65      0.63       112
#            1       0.51      0.45      0.48        88
#
#     accuracy                           0.56       200
#    macro avg       0.55      0.55      0.55       200
# weighted avg       0.56      0.56      0.56       200
#
# 新數據的預測準確率: 0.565
# 選擇股票:
# 2       台塑化
# 3      南亞
# 5      台塑
# 7      友達
# 9       聯發科
#           ...
# 190    鈊象
# 192    晶技
# 193    佰鴻
# 195     海韻電
# 196    華立
# Name: 簡稱, Length: 79, dtype: object
# 0.5196795443037975
# 最近鄰居中預測值為1的前5筆索引:
# [100, 133, 9, 43, 118]
# 100    台橡
# 133    建漢
# 9       聯發科
# 43     裕民
# 118    義隆
# Name: 簡稱, dtype: object
# 100   -36.7860
# 133   -62.8692
# 9     -42.2294
# 43    -50.3668
# 118   -62.6953
# Name: Return, dtype: float64
# 0.49010660000000006
# confusion_matrix:
# [[86 31]
#  [51 32]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.63      0.74      0.68       117
#            1       0.51      0.39      0.44        83
#
#     accuracy                           0.59       200
#    macro avg       0.57      0.56      0.56       200
# weighted avg       0.58      0.59      0.58       200
#
# 新數據的預測準確率: 0.59
# 選擇股票:
# 3      鴻海
# 6      台塑
# 7       宏達電
# 13      台達電
# 14     廣達
#           ...
# 183     震旦行
# 187    信義
# 191    特力
# 194     順達科
# 199     中聯資
# Name: 簡稱, Length: 63, dtype: object
# 2.1393934285714287
# 最近鄰居中預測值為1的前5筆索引:
# [71, 109, 14, 118, 95]
# 71     聯詠
# 109     中光電
# 14     廣達
# 118    兆赫
# 95     中鼎
# Name: 簡稱, dtype: object
# 71     264.2523
# 109    189.3970
# 14     114.1784
# 118     78.6602
# 95      53.1234
# Name: Return, dtype: float64
# 2.3992226
# confusion_matrix:
# [[121  79]
#  [  0   0]]
# classification_report
#               precision    recall  f1-score   support
#
#         -1.0       1.00      0.60      0.75       200
#          1.0       0.00      0.00      0.00         0
#
#     accuracy                           0.60       200
#    macro avg       0.50      0.30      0.38       200
# weighted avg       1.00      0.60      0.75       200
#
# 新數據的預測準確率: 0.605
# 選擇股票:
# 1      鴻海
# 2       台塑化
# 4       聯發科
# 10      宏達電
# 11     廣達
#           ...
# 191    川湖
# 192    國喬
# 196    長虹
# 198    太子
# 199    志超
# Name: 簡稱, Length: 79, dtype: object
# 0.0
# 最近鄰居中預測值為1的前5筆索引:
# [100, 14, 120, 25, 26]
# 100     揚明光
# 14      台灣大
# 120    威剛
# 25     正新
# 26     鴻準
# Name: 簡稱, dtype: object
# 100   -100
# 14    -100
# 120   -100
# 25    -100
# 26    -100
# Name: Return, dtype: int64
# 0.0
# {1998: 1.2633527666666666, 1999: 0.5774814142857143, 2000: 1.5238478219178082, 2001: 0.8435692658227848, 2002: 1.2518522393939393, 2003: 1.0394669743243243, 2004: 1.2527236958333332, 2005: 1.2519948472463769, 2006: 1.1398821048387098, 2007: 0.5196795443037975, 2008: 2.1393934285714287, 2009: 0.0}
# 複利為:2.425676103974208
#
#
# {1998: 1.7507300000000001, 1999: 0.6018422000000001, 2000: 1.6079284, 2001: 0.62268, 2002: 1.1886921, 2003: 1.2872344, 2004: 1.5267988, 2005: 1.4416934, 2006: 1.2423282, 2007: 0.49010660000000006, 2008: 2.3992226, 2009: 0.0}
# 複利為:5.190540750171448
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#         本益比     股價淨值比  資產報酬率ROA    負債/淨值比     M速動比率  M營業利益成長率  M稅後淨利成長率
# 0 -0.060623 -0.370416  1.423924 -0.611436  0.525878 -0.105409 -0.413608
# 1 -0.038129 -0.264764  0.519556 -1.081365  1.744121 -0.110777 -0.292221
# 2 -0.063967 -0.521471  0.409282 -0.228851 -0.926561 -0.090981 -0.169907
# 3 -0.048133 -0.411517 -0.019304  1.725653 -0.406180 -0.099229 -0.440858
# 4 -0.046297  0.106755  2.969858 -1.317535  3.415131 -0.089208 -0.095057
#           本益比     股價淨值比  資產報酬率ROA    負債/淨值比     M速動比率  M營業利益成長率  M稅後淨利成長率
# 0   -0.060623 -0.370416  1.423924 -0.611436  0.525878 -0.105409 -0.413608
# 1   -0.038129 -0.264764  0.519556 -1.081365  1.744121 -0.110777 -0.292221
# 2   -0.063967 -0.521471  0.409282 -0.228851 -0.926561 -0.090981 -0.169907
# 3   -0.048133 -0.411517 -0.019304  1.725653 -0.406180 -0.099229 -0.440858
# 4   -0.046297  0.106755  2.969858 -1.317535  3.415131 -0.089208 -0.095057
# ..        ...       ...       ...       ...       ...       ...       ...
# 195 -0.020360 -0.198700 -0.027917 -1.410935  0.785153 -0.086363  0.122768
# 196 -0.029794 -0.385355 -0.311369 -0.512907  0.071183 -0.099656 -0.406504
# 197 -0.045048 -0.456510 -0.250462 -1.404532  3.139652 -0.113323 -0.440274
# 198  0.015946 -0.322633 -0.691468  0.453777 -0.971799  0.035129  5.493014
# 199 -0.048958 -0.456397 -0.346866  0.838329  0.709820 -0.114375 -0.538325
#
# [200 rows x 7 columns]
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 195   -1.0
# 196    1.0
# 197    1.0
# 198    1.0
# 199    1.0
# Name: ReturnMean_year_Label, Length: 200, dtype: float64
#           本益比     股價淨值比  資產報酬率ROA    負債/淨值比     M速動比率  M營業利益成長率  M稅後淨利成長率
# 85  -0.021605 -0.377904 -0.485080  0.325143 -0.264775 -0.054000 -0.369337
# 183  0.006969  0.180733 -0.088660  2.809496 -1.043756  0.061530  5.236375
# 127  0.069751 -0.097387 -0.580857 -1.219546 -0.723424 -0.099965 -0.325751
# 53   0.101419  0.180340 -0.496201  1.443121  0.392093 -0.131441 -0.415530
# 100  0.026539 -0.416501 -0.843310  0.199479 -0.405601 -0.061074 -0.487669
# ..        ...       ...       ...       ...       ...       ...       ...
# 63  -0.030793 -0.389404 -0.420958  2.216083 -0.558773 -0.093226  0.285029
# 70  -0.045646 -0.364211  0.158320 -0.982836 -0.762972 -0.099711 -0.270600
# 81   0.006834  0.282720  0.257219 -0.088646  0.003953 -0.086268 -0.222828
# 11   0.730437  2.303706 -0.687045  0.817694 -0.721399 -0.129059 -0.578032
# 95  -0.198790 -0.255138 -1.533502 -0.607059 -0.443315 -0.117340 -0.893083
#
# [140 rows x 7 columns] 85    -1.0
# 183    1.0
# 127   -1.0
# 53    -1.0
# 100   -1.0
#       ...
# 63     1.0
# 70     1.0
# 81     1.0
# 11     1.0
# 95    -1.0
# Name: ReturnMean_year_Label, Length: 140, dtype: float64
# Optimal k value for minimum error rate: 44
# Minimum Error Rate: 0.31666666666666665
# confusion_matrix:
# [[115  11]
#  [ 59  15]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.66      0.91      0.77       126
#            1       0.58      0.20      0.30        74
#
#     accuracy                           0.65       200
#    macro avg       0.62      0.56      0.53       200
# weighted avg       0.63      0.65      0.59       200
#
# 新數據的預測準確率: 0.65
# 選擇股票:
# 0       台積電
# 1      華碩
# 5      鴻海
# 10     華通
# 11     仁寶
# 17      台達電
# 21     華宇
# 40     技嘉
# 51     矽統
# 72     微星
# 97     國聯
# 111    泰豐
# 112    豐泰
# 121    致茂
# 122    建大
# 137    云辰
# 138    力山
# 156    合勤
# 160    金緯
# 161    亞聚
# 175    國電
# 176    虹光
# 182    大華
# 191     劍湖山
# 192    高林
# 199    東泥
# Name: 簡稱, dtype: object
# 1.3451045
# 最近鄰居中預測值為1的前5筆索引:
# [0, 72, 10, 11, 111]
# 0       台積電
# 72     微星
# 10     華通
# 11     仁寶
# 111    泰豐
# Name: 簡稱, dtype: object
# 0      193.2025
# 72      81.6998
# 10       5.8307
# 11      39.4893
# 111    -35.1935
# Name: Return, dtype: float64
# 1.5700575999999997
# confusion_matrix:
# [[94 17]
#  [67 22]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.85      0.69       111
#            1       0.56      0.25      0.34        89
#
#     accuracy                           0.58       200
#    macro avg       0.57      0.55      0.52       200
# weighted avg       0.58      0.58      0.54       200
#
# 新數據的預測準確率: 0.58
# 選擇股票:
# 2      華碩
# 5      廣達
# 6      鴻海
# 7       日月光
# 9      茂德
# 12     中環
# 15     仁寶
# 19      台達電
# 22      英業達
# 26      統一超
# 31     華宇
# 35     金寶
# 39     凌陽
# 40     技嘉
# 41     環電
# 48     研華
# 49     萬海
# 53     國電
# 57     飛瑞
# 60     精碟
# 62     瑞昱
# 63     智原
# 66     勝華
# 68     遠雄
# 69     年興
# 76     精英
# 78     兆赫
# 79     台揚
# 82      普立爾
# 117    可成
# 128    思源
# 130    國聯
# 136    中鼎
# 142     友立資
# 146    亞聚
# 154    鑽全
# 174    漢唐
# 183    巨大
# 192    佳格
# Name: 簡稱, dtype: object
# 0.6183608205128205
# 最近鄰居中預測值為1的前5筆索引:
# [66, 82, 53, 26, 63]
# 66    勝華
# 82     普立爾
# 53    國電
# 26     統一超
# 63    智原
# Name: 簡稱, dtype: object
# 66   -42.8671
# 82   -43.5337
# 53   -13.9989
# 26   -22.9665
# 63   -15.1771
# Name: Return, dtype: float64
# 0.7229133999999999
# confusion_matrix:
# [[101  26]
#  [ 53  20]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.66      0.80      0.72       127
#            1       0.43      0.27      0.34        73
#
#     accuracy                           0.60       200
#    macro avg       0.55      0.53      0.53       200
# weighted avg       0.58      0.60      0.58       200
#
# 新數據的預測準確率: 0.605
# 選擇股票:
# 0       台積電
# 2      聯電
# 3      鴻海
# 7      華碩
# 8      廣達
# 9      威盛
# 11     旺宏
# 12      台達電
# 18     仁寶
# 23     凌陽
# 29      英業達
# 48     瑞昱
# 49     研華
# 50     智原
# 56     飛瑞
# 57     台揚
# 58      光寶科
# 64     微星
# 71     D 復盛
# 74      敦陽科
# 76     巨大
# 78     云辰
# 85     亞光
# 95     虹光
# 109     禾伸堂
# 110    思源
# 111    精英
# 117    華紙
# 121     偉詮電
# 126    松翰
# 127    鑽全
# 130    建碁
# 135    飛宏
# 136    漢磊
# 137     好樂迪
# 141    友旺
# 144    關貿
# 146     美隆電
# 151      第一金投
# 152    訊連
# 153    兆赫
# 162    遠見
# 163    台南
# 170     遠雄港
# 176      匯僑工業
# 198    強茂
# Name: 簡稱, dtype: object
# 1.6044233043478262
# 最近鄰居中預測值為1的前5筆索引:
# [0, 71, 9, 109, 127]
# 0       台積電
# 71     D 復盛
# 9      威盛
# 109     禾伸堂
# 127    鑽全
# Name: 簡稱, dtype: object
# 0      59.7499
# 71     65.0935
# 9      28.5075
# 109    46.1834
# 127     8.2527
# Name: Return, dtype: float64
# 1.4155739999999999
# confusion_matrix:
# [[84 34]
#  [68 14]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.55      0.71      0.62       118
#            1       0.29      0.17      0.22        82
#
#     accuracy                           0.49       200
#    macro avg       0.42      0.44      0.42       200
# weighted avg       0.45      0.49      0.46       200
#
# 新數據的預測準確率: 0.49
# 選擇股票:
# 3      鴻海
# 4       聯發科
# 5       台灣大
# 14     仁寶
# 21     精英
# 22     微星
# 23     瑞昱
# 24     凌陽
# 31     技嘉
# 32      英業達
# 39     國電
# 41      建興電
# 42     智邦
# 43      光寶科
# 52     亞光
# 54      普立爾
# 60     研華
# 61     智原
# 67     D 復盛
# 72      敦陽科
# 74      中光電
# 78     必翔
# 80     台揚
# 83     中保
# 87     飛宏
# 88     瑞軒
# 94      第一店
# 98     創見
# 100     三商行
# 104    百略
# 107    松翰
# 118    迎廣
# 123     偉詮電
# 124    華立
# 126    思源
# 128    友旺
# 129    崇越
# 144     美隆電
# 146    特力
# 151    神腦
# 152    億豐
# 154    大田
# 168    遠見
# 173    鑽全
# 177    科風
# 182    中碳
# 185    健鼎
# 188    訊連
# Name: 簡稱, dtype: object
# 0.803711
# 最近鄰居中預測值為1的前5筆索引:
# [129, 100, 107, 43, 118]
# 129    崇越
# 100     三商行
# 107    松翰
# 43      光寶科
# 118    迎廣
# Name: 簡稱, dtype: object
# 129   -27.2886
# 100   -33.8859
# 107   -30.2349
# 43      5.6481
# 118   -64.2834
# Name: Return, dtype: float64
# 0.6999106
# confusion_matrix:
# [[111   5]
#  [ 80   4]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.96      0.72       116
#            1       0.44      0.05      0.09        84
#
#     accuracy                           0.57       200
#    macro avg       0.51      0.50      0.40       200
# weighted avg       0.52      0.57      0.46       200
#
# 新數據的預測準確率: 0.575
# 選擇股票:
# 75      大立光
# 90     億豐
# 99     飛瑞
# 158    鑽全
# 168    松翰
# 170    橘子
# 172    廣宇
# 184     偉詮電
# 199    普安
# Name: 簡稱, dtype: object
# 1.3784709555555557
# 最近鄰居中預測值為1的前5筆索引:
# [90, 99]
# 90    億豐
# 99    飛瑞
# Name: 簡稱, dtype: object
# 90    14.5258
# 99    61.2507
# Name: Return, dtype: float64
# 1.3788825
# confusion_matrix:
# [[76 22]
#  [75 27]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.50      0.78      0.61        98
#            1       0.55      0.26      0.36       102
#
#     accuracy                           0.52       200
#    macro avg       0.53      0.52      0.48       200
# weighted avg       0.53      0.52      0.48       200
#
# 新數據的預測準確率: 0.515
# 選擇股票:
# 4      鴻海
# 6      台塑
# 7      中鋼
# 8      台化
# 10      聯發科
# 11     友達
# 14      台灣大
# 25     遠傳
# 32      建興電
# 40     萬海
# 42      統一超
# 61     D 復盛
# 62     聯詠
# 67     雅新
# 68     廣明
# 69      宏達電
# 74     東聯
# 83     國建
# 84     群光
# 87     東陽
# 89     必翔
# 90     可成
# 93     飛瑞
# 96     智原
# 98     創見
# 104    力成
# 110    億豐
# 114    康舒
# 116    普安
# 129    瑞儀
# 130    巨大
# 135    啟碁
# 140    綠點
# 144     晶豪科
# 149    思源
# 150    建漢
# 151    亞翔
# 152    晶電
# 155    超豐
# 159    立錡
# 170    鑽全
# 171    智冠
# 172     美隆電
# 175    漢唐
# 178    華立
# 180    中碳
# 185     華晶科
# 188    泰豐
# 190    憶聲
# Name: 簡稱, dtype: object
# 1.0213293530612244
# 最近鄰居中預測值為1的前5筆索引:
# [68, 40, 8, 74, 25]
# 68    廣明
# 40    萬海
# 8     台化
# 74    東聯
# 25    遠傳
# Name: 簡稱, dtype: object
# 68   -73.42570
# 40    21.04590
# 8     20.12850
# 74    -0.56497
# 25    74.49940
# Name: Return, dtype: float64
# 1.08336626
# confusion_matrix:
# [[101  29]
#  [ 50  20]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.67      0.78      0.72       130
#            1       0.41      0.29      0.34        70
#
#     accuracy                           0.60       200
#    macro avg       0.54      0.53      0.53       200
# weighted avg       0.58      0.60      0.58       200
#
# 新數據的預測準確率: 0.605
# 選擇股票:
# 2       台塑化
# 5      中鋼
# 6      南亞
# 7      台化
# 8      台塑
# 13      聯發科
# 22      台達電
# 25     長榮
# 27     陽明
# 37     萬海
# 39     大同
# 44     聯詠
# 50     裕民
# 59     D 復盛
# 65     雅新
# 74     力成
# 76     東聯
# 78     華寶
# 80     豐興
# 85     可成
# 87     創見
# 94     瑞儀
# 100    綠點
# 102    新興
# 113    智原
# 114    帝寶
# 116    盛餘
# 122    康舒
# 126    普安
# 131    健鼎
# 132    元太
# 133    景碩
# 134    思源
# 137    正文
# 144    鑽全
# 151    台航
# 156    中碳
# 158    美律
# 159    京城
# 161    信義
# 163     嘉聯益
# 167    茂迪
# 170    敦南
# 176     新光鋼
# 184     四維航
# 187    亞翔
# 190     禾伸堂
# 193    威剛
# 196    華立
# Name: 簡稱, dtype: object
# 1.2866220714285714
# 最近鄰居中預測值為1的前5筆索引:
# [133, 8, 137, 76, 80]
# 133    景碩
# 8      台塑
# 137    正文
# 76     東聯
# 80     豐興
# Name: 簡稱, dtype: object
# 133    163.1637
# 8        7.6672
# 137    -24.8707
# 76     -24.2252
# 80     -30.3218
# Name: Return, dtype: float64
# 1.1828264000000002
# confusion_matrix:
# [[88 24]
#  [65 23]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.79      0.66       112
#            1       0.49      0.26      0.34        88
#
#     accuracy                           0.56       200
#    macro avg       0.53      0.52      0.50       200
# weighted avg       0.54      0.56      0.52       200
#
# 新數據的預測準確率: 0.555
# 選擇股票:
# 0       台積電
# 3      南亞
# 4       聯發科
# 7      台塑
# 8      中鋼
# 10      宏達電
# 19     矽品
# 26     可成
# 28     長榮
# 33     華寶
# 36     亞光
# 41     陽明
# 43     勝華
# 48     力成
# 57     台肥
# 59      裕日車
# 68     健鼎
# 71     裕民
# 77     瑞儀
# ...
# 43     台肥
# 120    群聯
# Name: 簡稱, dtype: object
# 0      -2.0470
# 100    32.4277
# 105   -10.0237
# 43     32.8709
# 120    -1.9618
# Name: Return, dtype: float64
# 1.1025322
# confusion_matrix:
# [[88 24]
#  [71 17]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.55      0.79      0.65       112
#            1       0.41      0.19      0.26        88
#
#     accuracy                           0.53       200
#    macro avg       0.48      0.49      0.46       200
# weighted avg       0.49      0.53      0.48       200
#
# 新數據的預測準確率: 0.525
# 選擇股票:
# 2       台塑化
# 9       聯發科
# 11      宏達電
# 15      台達電
# 18     矽品
# 33     可成
# 43     裕民
# 44     彩晶
# 47     聯詠
# 48     力成
# 65     健鼎
# 70     華寶
# 76     億光
# 78     友訊
# 82     立錡
# 86     伍豐
# 91     群光
# 93     新普
# 94      英華達
# 96     原相
# 98     兆赫
# 100    台橡
# 103     信昌化
# 106    新興
# 112    智原
# 115    中航
# 122     新日興
# 124    群聯
# 127    佳能
# 134    致茂
# 139    閎暉
# 142    華擎
# 148     四維航
# 152    中碳
# 157    信義
# 161    鄉林
# 184    奇偶
# 188    訊連
# 190    鈊象
# 192    晶技
# 195     海韻電
# Name: 簡稱, dtype: object
# 0.4778620487804879
# 最近鄰居中預測值為1的前5筆索引:
# [100, 9, 11, 43, 82]
# 100    台橡
# 9       聯發科
# 11      宏達電
# 43     裕民
# 82     立錡
# Name: 簡稱, dtype: object
# 100   -36.7860
# 9     -42.2294
# 11    -24.3114
# 43    -50.3668
# 82    -48.1553
# Name: Return, dtype: float64
# 0.5963022
# confusion_matrix:
# [[99 18]
#  [67 16]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.60      0.85      0.70       117
#            1       0.47      0.19      0.27        83
#
#     accuracy                           0.57       200
#    macro avg       0.53      0.52      0.49       200
# weighted avg       0.54      0.57      0.52       200
#
# 新數據的預測準確率: 0.575
# 選擇股票:
# 7       宏達電
# 40     力成
# 41     裕民
# 53      大立光
# 55     研華
# 65     茂迪
# 74     群光
# 76     新興
# 78     台航
# 80     新普
# 81     台橡
# 97     原相
# 98     景碩
# 104    中航
# 113     四維航
# 115    中碳
# 117    正文
# 118    兆赫
# 135     新日興
# 140    超豐
# 145     華晶科
# 157    佳能
# 160    明泰
# 161    雷凌
# 163    鈊象
# 169    陞泰
# 170    網龍
# 171    華固
# 174    神腦
# 184    益航
# 187    信義
# 194     順達科
# 197    川湖
# 199     中聯資
# Name: 簡稱, dtype: object
# 2.0864882647058822
# 最近鄰居中預測值為1的前5筆索引:
# [65, 135, 76, 53, 118]
# 65     茂迪
# 135     新日興
# 76     新興
# 53      大立光
# 118    兆赫
# Name: 簡稱, dtype: object
# 65     141.4094
# 135    116.9515
# 76      51.3503
# 53     116.2898
# 118     78.6602
# Name: Return, dtype: float64
# 2.0093224000000003
# confusion_matrix:
# [[162  38]
#  [  0   0]]
# classification_report
#               precision    recall  f1-score   support
#
#         -1.0       1.00      0.81      0.90       200
#          1.0       0.00      0.00      0.00         0
#
#     accuracy                           0.81       200
#    macro avg       0.50      0.41      0.45       200
# weighted avg       1.00      0.81      0.90       200
#
# 新數據的預測準確率: 0.81
# 選擇股票:
# 4       聯發科
# 10      宏達電
# 14      台灣大
# 15      台達電
# 25     正新
# 29     台肥
# 43     聯詠
# 44     旺宏
# 48     裕民
# 54     創見
# 55     遠雄
# 56      大聯大
# 59     洋華
# 60     群光
# 64     新普
# 71     群聯
# 74     網龍
# 93     長興
# 103    佳能
# 109    台橡
# 115     華晶科
# 117    新興
# 118    中保
# 119     新日興
# 120    威剛
# 127    中航
# 138    士電
# 139    建大
# 144    中碳
# 147    閎暉
# 150    華固
# 160    信義
# 165    鈊象
# 169    矽統
# 170    廣明
# 173    晶技
# 180    普安
# 192    國喬
# Name: 簡稱, dtype: object
# 0.0
# 最近鄰居中預測值為1的前5筆索引:
# [74, 43, 109, 120, 25]
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 74     網龍
# 43     聯詠
# 109    台橡
# 120    威剛
# 25     正新
# Name: 簡稱, dtype: object
# 74    -100
# 43    -100
# 109   -100
# 120   -100
# 25    -100
# Name: Return, dtype: int64
# 0.0
# {1998: 1.3451045, 1999: 0.6183608205128205, 2000: 1.6044233043478262, 2001: 0.803711, 2002: 1.3784709555555557, 2003: 1.0213293530612244, 2004: 1.2866220714285714, 2005: 1.2865001936170213, 2006: 1.0372639516129032, 2007: 0.4778620487804879, 2008: 2.0864882647058822, 2009: 0.0}
# 複利為:2.5849308114139897
#
#
# {1998: 1.5700575999999997, 1999: 0.7229133999999999, 2000: 1.4155739999999999, 2001: 0.6999106, 2002: 1.3788825, 2003: 1.08336626, 2004: 1.1828264000000002, 2005: 1.2405508, 2006: 1.1025322, 2007: 0.5963022, 2008: 2.0093224000000003, 2009: 0.0}
# 複利為:3.2562853563553804
#         本益比     股價淨值比  資產報酬率ROA    負債/淨值比  M存貨週轉率 (次)  M應收帳款週轉次  M營業利益成長率
# 0 -0.060623 -0.370416  1.423924 -0.611436   -0.088286 -0.248544 -0.105409
# 1 -0.038129 -0.264764  0.519556 -1.081365   -0.113169 -0.224163 -0.110777
# 2 -0.063967 -0.521471  0.409282 -0.228851   -0.153606  0.603203 -0.090981
# 3 -0.048133 -0.411517 -0.019304  1.725653   -0.144620 -0.213562 -0.099229
# 4 -0.046297  0.106755  2.969858 -1.317535   -0.032643  0.683767 -0.089208
#           本益比     股價淨值比  資產報酬率ROA    負債/淨值比  M存貨週轉率 (次)  M應收帳款週轉次  M營業利益成長率
# 0   -0.060623 -0.370416  1.423924 -0.611436   -0.088286 -0.248544 -0.105409
# 1   -0.038129 -0.264764  0.519556 -1.081365   -0.113169 -0.224163 -0.110777
# 2   -0.063967 -0.521471  0.409282 -0.228851   -0.153606  0.603203 -0.090981
# 3   -0.048133 -0.411517 -0.019304  1.725653   -0.144620 -0.213562 -0.099229
# 4   -0.046297  0.106755  2.969858 -1.317535   -0.032643  0.683767 -0.089208
# ..        ...       ...       ...       ...         ...       ...       ...
# 195 -0.020360 -0.198700 -0.027917 -1.410935    0.002955 -0.423451 -0.086363
# 196 -0.029794 -0.385355 -0.311369 -0.512907   -0.295305 -0.313736 -0.099656
# 197 -0.045048 -0.456510 -0.250462 -1.404532   -0.212359 -0.356138 -0.113323
# 198  0.015946 -0.322633 -0.691468  0.453777   -0.288047 -0.342888  0.035129
# 199 -0.048958 -0.456397 -0.346866  0.838329   -0.033680 -0.321157 -0.114375
#
# [200 rows x 7 columns]
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 195   -1.0
# 196    1.0
# 197    1.0
# 198    1.0
# 199    1.0
# Name: ReturnMean_year_Label, Length: 200, dtype: float64
#           本益比     股價淨值比  資產報酬率ROA    負債/淨值比  M存貨週轉率 (次)  M應收帳款週轉次  M營業利益成長率
# 85  -0.021605 -0.377904 -0.485080  0.325143   -0.108331 -0.116038 -0.054000
# 183  0.006969  0.180733 -0.088660  2.809496   -0.255906  0.329181  0.061530
# 127  0.069751 -0.097387 -0.580857 -1.219546   -0.220654 -0.003143 -0.099965
# 53   0.101419  0.180340 -0.496201  1.443121   -0.094161 -0.321157 -0.131441
# 100  0.026539 -0.416501 -0.843310  0.199479   -0.190240 -0.290415 -0.061074
# ..        ...       ...       ...       ...         ...       ...       ...
# 63  -0.030793 -0.389404 -0.420958  2.216083   -0.019510 -0.033354 -0.093226
# 70  -0.045646 -0.364211  0.158320 -0.982836   -0.284591  0.326001 -0.099711
# 81   0.006834  0.282720  0.257219 -0.088646   -0.016745  0.102332 -0.086268
# 11   0.730437  2.303706 -0.687045  0.817694   -0.208903 -0.284585 -0.129059
# 95  -0.198790 -0.255138 -1.533502 -0.607059   -0.288047  0.005867 -0.117340
#
# [140 rows x 7 columns] 85    -1.0
# 183    1.0
# 127   -1.0
# 53    -1.0
# 100   -1.0
#       ...
# 63     1.0
# 70     1.0
# 81     1.0
# 11     1.0
# 95    -1.0
# Name: ReturnMean_year_Label, Length: 140, dtype: float64
# Optimal k value for minimum error rate: 37
# Minimum Error Rate: 0.2833333333333333
# confusion_matrix:
# [[110  16]
#  [ 59  15]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.65      0.87      0.75       126
#            1       0.48      0.20      0.29        74
#
#     accuracy                           0.62       200
#    macro avg       0.57      0.54      0.52       200
# weighted avg       0.59      0.62      0.58       200
#
# 新數據的預測準確率: 0.625
# 選擇股票:
# 1      華碩
# 3      中鋼
# 5      鴻海
# 6       英業達
# 10     華通
# 11     仁寶
# 15     裕隆
# 16     中華
# 17      台達電
# 18     矽品
# 21     華宇
# 24     寶成
# 40     技嘉
# 41     三陽
# 48     金寶
# 49     凌陽
# 50      楠梓電
# 51     矽統
# 72     微星
# 103    耀文
# 111    泰豐
# 112    豐泰
# 117    東陽
# 126    德寶
# 138    力山
# 160    金緯
# 166     大台北
# 175    國電
# 176    虹光
# 178    力麒
# 191     劍湖山
# Name: 簡稱, dtype: object
# 1.2184211612903226
# 最近鄰居中預測值為1的前5筆索引:
# [5, 10, 15, 16, 24]
# 5     鴻海
# 10    華通
# 15    裕隆
# 16    中華
# 24    寶成
# Name: 簡稱, dtype: object
# 5     87.7049
# 10     5.8307
# 15   -45.9188
# 16   -41.7879
# 24    25.5390
# Name: Return, dtype: float64
# 1.0627358
# confusion_matrix:
# [[87 24]
#  [61 28]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.78      0.67       111
#            1       0.54      0.31      0.40        89
#
#     accuracy                           0.57       200
#    macro avg       0.56      0.55      0.53       200
# weighted avg       0.57      0.57      0.55       200
#
# 新數據的預測準確率: 0.575
# 選擇股票:
# 0       台積電
# 2      華碩
# 5      廣達
# 6      鴻海
# 7       日月光
# 9      茂德
# 12     中環
# 15     仁寶
# 17     錸德
# 19      台達電
# 22      英業達
# 25     聯強
# 26      統一超
# 28     精業
# 31     華宇
# 35     金寶
# 39     凌陽
# 40     技嘉
# 41     環電
# 44     中華
# 48     研華
# 49     萬海
# 53     國電
# 57     飛瑞
# 60     精碟
# 62     瑞昱
# 63     智原
# 66     勝華
# 67     台苯
# 68     遠雄
# 69     年興
# 76     精英
# 78     兆赫
# 79     台揚
# 82      普立爾
# 86     云辰
# 89     聯成
# 94     東訊
# 101    倚天
# 116    福聚
# 117    可成
# 124    和泰
# 128    思源
# 130    國聯
# 136    中鼎
# 143     偉詮電
# 154    鑽全
# 170    環科
# 173    永記
# 174    漢唐
# 180    瑞軒
# 192    佳格
# Name: 簡稱, dtype: object
# 0.5943073076923078
# 最近鄰居中預測值為1的前5筆索引:
# [66, 9, 44, 25, 28]
# 66    勝華
# 9     茂德
# 44    中華
# 25    聯強
# 28    精業
# Name: 簡稱, dtype: object
# 66   -42.8671
# 9    -59.5213
# 44    18.7081
# 25   -70.0025
# 28   -74.0175
# Name: Return, dtype: float64
# 0.5445994000000001
# confusion_matrix:
# [[101  26]
#  [ 48  25]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.68      0.80      0.73       127
#            1       0.49      0.34      0.40        73
#
#     accuracy                           0.63       200
#    macro avg       0.58      0.57      0.57       200
# weighted avg       0.61      0.63      0.61       200
#
# 新數據的預測準確率: 0.63
# 選擇股票:
# 0       台積電
# 2      聯電
# 3      鴻海
# 7      華碩
# 8      廣達
# 9      威盛
# 11     旺宏
# 12      台達電
# 14     茂德
# 16     華映
# 18     仁寶
# 23     凌陽
# 29      英業達
# 48     瑞昱
# 49     研華
# 50     智原
# 52     年興
# 57     台揚
# 58      光寶科
# 60     聲寶
# 64     微星
# 71     D 復盛
# 74      敦陽科
# 75      普立爾
# 78     云辰
# 84     宏碁
# 85     亞光
# 95     虹光
# 101    毅嘉
# 109     禾伸堂
# 111    精英
# 112     華新科
# 121     偉詮電
# 126    松翰
# 127    鑽全
# 130    建碁
# 135    飛宏
# 136    漢磊
# 137     好樂迪
# 141    友旺
# 146     美隆電
# 151      第一金投
# 152    訊連
# 153    兆赫
# 162    遠見
# 163    台南
# 165    美律
# 170     遠雄港
# 172    瑞軒
# 176      匯僑工業
# 198    強茂
# Name: 簡稱, dtype: object
# 1.6747425490196077
# 最近鄰居中預測值為1的前5筆索引:
# [9, 109, 14, 127, 95]
# 9      威盛
# 109     禾伸堂
# 14     茂德
# 127    鑽全
# 95     虹光
# Name: 簡稱, dtype: object
# 9      28.5075
# 109    46.1834
# 14     26.6324
# 127     8.2527
# 95     27.5474
# Name: Return, dtype: float64
# 1.2742468
# confusion_matrix:
# [[81 37]
#  [66 16]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.55      0.69      0.61       118
#            1       0.30      0.20      0.24        82
#
#     accuracy                           0.48       200
#    macro avg       0.43      0.44      0.42       200
# weighted avg       0.45      0.48      0.46       200
#
# 新數據的預測準確率: 0.485
# 選擇股票:
# 3      鴻海
# 4       聯發科
# 5       台灣大
# 14     仁寶
# 17      台達電
# 21     精英
# 22     微星
# 23     瑞昱
# 24     凌陽
# 31     技嘉
# 32      英業達
# 39     國電
# 41      建興電
# 42     智邦
# 48     聯強
# 52     亞光
# 54      普立爾
# 60     研華
# 61     智原
# 66     建碁
# 67     D 復盛
# 72      敦陽科
# 74      中光電
# 78     必翔
# 80     台揚
# 81     雅新
# 82     年興
# 83     中保
# 86     義隆
# 87     飛宏
# 88     瑞軒
# 95     群光
# 98     創見
# 100     三商行
# 104    百略
# 107    松翰
# 114    虹光
# 118    迎廣
# 124    華立
# 126    思源
# 128    友旺
# 129    崇越
# 144     美隆電
# 146    特力
# 151    神腦
# 152    億豐
# 154    大田
# 168    遠見
# 173    鑽全
# 177    科風
# 182    中碳
# 185    健鼎
# 192    友通
# Name: 簡稱, dtype: object
# 0.8140732830188679
# 最近鄰居中預測值為1的前5筆索引:
# [100, 74, 82, 118, 126]
# 100     三商行
# 74      中光電
# 82     年興
# 118    迎廣
# 126    思源
# Name: 簡稱, dtype: object
# 100   -33.8859
# 74    -46.1036
# 82     45.2922
# 118   -64.2834
# 126   -13.5894
# Name: Return, dtype: float64
# 0.7748598
# confusion_matrix:
# [[107   9]
#  [ 75   9]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.92      0.72       116
#            1       0.50      0.11      0.18        84
#
#     accuracy                           0.58       200
#    macro avg       0.54      0.51      0.45       200
# weighted avg       0.55      0.58      0.49       200
#
# 新數據的預測準確率: 0.58
# 選擇股票:
# 1       中華電
# 9       聯發科
# 22     遠傳
# 66     合勤
# 70     聯詠
# 72     年興
# 74     研華
# 88     智原
# 89      晶豪科
# 92     創見
# 108    中保
# 127     美隆電
# 141    光罩
# 158    鑽全
# 159    鴻準
# 181    揚智
# 193    敦南
# 197    超豐
# Name: 簡稱, dtype: object
# 1.2862613722222223
# 最近鄰居中預測值為1的前5筆索引:
# [70, 9, 74, 89, 92]

# %%
ans
# Out:
# {10: [['本益比', 'M淨值報酬率─稅後'], 6, 1.2353591410566203]}
