# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

csv_file_path='top200_training.xls'
#記得pip install xlrd
df = pd.read_excel(csv_file_path)
#df.head()

# %%
from itertools import product
from itertools import combinations


# 將年月轉換為日期型數據
df['年月'] = pd.to_datetime(df['年月'], format='%Y%m')

# 獲取所有不同的年份
all_years = ['1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008']

# 開始的欄位
start_column = '1997'

# 開始欄位的索引
start_index = all_years.index(start_column)

# 創建一個字典來保存結果
year_combinations_dict = {}

# 生成所有可能的欄位組合
for i in range(1, len(all_years) - start_index + 1):
    for subset in combinations(all_years[start_index:], i):
        selected_columns = list(subset)
        # 將結果存入字典
        year_combinations_dict[len(year_combinations_dict) + 1] = selected_columns

# 打開一個檔案來保存結果
with open('year_combinations.txt', 'w') as file:
    # 遍歷字典，將結果寫入檔案
    for key, value in year_combinations_dict.items():
        file.write(f"Key: {key}, Selected year: {value}\n")
        # 在這裡進行你的分析或模型擬合等操作
        # ...
        file.write("\n" + "="*40 + "\n")

# 提示保存成功
print("Results saved to 'year_combinations.txt'")
# Out:
# Results saved to 'year_combinations.txt'

# %%
from itertools import combinations
from sklearn.model_selection import train_test_split
import json
columns_comb1=['股價淨值比', '股價營收比', 'M營業利益成長率', 'M稅後淨利成長率']
columns_comb2=['股價淨值比', 'M淨值報酬率─稅後', '資產報酬率ROA', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M稅後淨利成長率']
columns_comb3=['股價淨值比', '利潤邊際NPM', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M營業利益成長率', 'M稅後淨利成長率']
columns_comb4=['股價營收比', '營業利益率OPM', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M營業利益成長率', 'M稅後淨利成長率']
columns_comb5=['本益比', '股價淨值比', '股價營收比', 'M淨值報酬率─稅後', '資產報酬率ROA', 'M存貨週轉率 (次)', 'M營業利益成長率']
columns_comb6=['股價淨值比', '股價營收比', 'M淨值報酬率─稅後', '資產報酬率ROA', 'M流動比率', 'M速動比率', 'M應收帳款週轉次']
columns_comb7=['本益比', '股價淨值比', '股價營收比', '資產報酬率ROA', '營業利益率OPM', '利潤邊際NPM', 'M流動比率', 'M應收帳款週轉次', 'M營業利益成長率']
columns_comb8=['本益比', '股價淨值比', '股價營收比', 'M淨值報酬率─稅後', '資產報酬率ROA', '利潤邊際NPM', '負債/淨值比', 'M流動比率', 'M速動比率', 'M營業利益成長率', 'M稅後淨利成長率']
columns_comb9=['股價營收比', '營業利益率OPM', '負債/淨值比', 'M速動比率', 'M存貨週轉率 (次)', 'M營業利益成長率', 'M稅後淨利成長率']
columns_comb10=['本益比', '股價淨值比', '股價營收比', '營業利益率OPM', '利潤邊際NPM', 'M流動比率', 'M速動比率', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M營業利益成長率', 'M稅後淨利成長率']
column_combinations_dict = {}
columns_combinations = [columns_comb1, columns_comb2, columns_comb3, columns_comb4, columns_comb5, columns_comb6, columns_comb7, columns_comb8, columns_comb9, columns_comb10]

for i, columns_comb in enumerate(columns_combinations, start=1):
    column_combinations_dict[i] = columns_comb
print(column_combinations_dict)
# 將字典保存到.txt文件
file_path = 'column_combinations_KNN_train.txt'

with open(file_path, 'w', encoding='utf-8') as file:
    json.dump(column_combinations_dict, file, ensure_ascii=False)
print('Results saved to column_combinations_KNN_train.txt')
# Out:
# {1: ['股價淨值比', '股價營收比', 'M營業利益成長率', 'M稅後淨利成長率'], 2: ['股價淨值比', 'M淨值報酬率─稅後', '資產報酬率ROA', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M稅後淨利成長率'], 3: ['股價淨值比', '利潤邊際NPM', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M營業利益成長率', 'M稅後淨利成長率'], 4: ['股價營收比', '營業利益率OPM', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M營業利益成長率', 'M稅後淨利成長率'], 5: ['本益比', '股價淨值比', '股價營收比', 'M淨值報酬率─稅後', '資產報酬率ROA', 'M存貨週轉率 (次)', 'M營業利益成長率'], 6: ['股價淨值比', '股價營收比', 'M淨值報酬率─稅後', '資產報酬率ROA', 'M流動比率', 'M速動比率', 'M應收帳款週轉次'], 7: ['本益比', '股價淨值比', '股價營收比', '資產報酬率ROA', '營業利益率OPM', '利潤邊際NPM', 'M流動比率', 'M應收帳款週轉次', 'M營業利益成長率'], 8: ['本益比', '股價淨值比', '股價營收比', 'M淨值報酬率─稅後', '資產報酬率ROA', '利潤邊際NPM', '負債/淨值比', 'M流動比率', 'M速動比率', 'M營業利益成長率', 'M稅後淨利成長率'], 9: ['股價營收比', '營業利益率OPM', '負債/淨值比', 'M速動比率', 'M存貨週轉率 (次)', 'M營業利益成長率', 'M稅後淨利成長率'], 10: ['本益比', '股價淨值比', '股價營收比', '營業利益率OPM', '利潤邊際NPM', 'M流動比率', 'M速動比率', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M營業利益成長率', 'M稅後淨利成長率']}
# Results saved to column_combinations_KNN_train.txt

# %%
max_ret=0
ans={}
list_ans=[]
#選擇特定欄位分析
from sklearn.preprocessing import StandardScaler
from itertools import islice

selected_range = islice(year_combinations_dict.items(), 4094) #4094是所有可用來訓練的年份組合
cols=0
#16384
with open('KNN_train_test_result.txt', 'a') as file:
    for key, selected_years in selected_range:
        
        # 選擇訓練集年分
        train_years = [int(year) for year in selected_years]
        #print(train_years)

        #print("---------------------")
        # 選擇測試集年分
        test_years = [int(year) for year in all_years if year not in selected_years]
        print(f'總共有test year:{len(test_years)}')
        
        # 根據年份選擇訓練集
        train_data = df[df['年月'].dt.year.isin(train_years)]
        print(f"Number of rows in train_data: {len(train_data)}")
        #print(train_data)
        
        # 排除指定列，並標準化
        #columns_to_exclude = ['簡稱', '證券代碼', '年月', 'ReturnMean_year_Label', 'Return']
        #features_to_scale_train = train_data.drop(columns=columns_to_exclude)
        #features_to_scale_test = test_data.drop(columns=columns_to_exclude)
    
        for col in range (1,11):#取top10組合
            cols=cols+1
            list_ans=[]
            # 指定要選擇的欄位
            selected_columns = column_combinations_dict[col]
            list_ans.append(selected_columns)
            
            # 選擇指定的欄位
            features_to_scale_train = train_data[selected_columns]

            scaler = StandardScaler()
            scaled_features_train = scaler.fit_transform(features_to_scale_train)
            
            # 轉換為dataframe
            df_feat_train = pd.DataFrame(scaled_features_train, columns=features_to_scale_train.columns)
            
        #---------------------------------------------------------------------------------------------
            # 分割訓練集和測試集
            X_train = df_feat_train
            y_train = train_data['ReturnMean_year_Label']
            
            X_train, X_test, y_train, y_test = train_test_split(X_train,y_train,test_size=0.3,random_state=101)
  
        #--------------------------------------------------------------------------------------------------
            error_rate = []
            from sklearn.neighbors import KNeighborsClassifier
            for i in range(1, 100):
                knn = KNeighborsClassifier(n_neighbors=i, p=2, weights='distance', algorithm='brute')
                knn.fit(X_train, y_train)
                pred_i = knn.predict(X_test)
                error_rate.append(np.mean(pred_i != y_test))

            # 將k=1~60的錯誤率製圖畫出。k=23之後，錯誤率就在5-6%之間震盪。
            #plt.figure(figsize=(10, 6))
            #plt.plot(range(1, 100), error_rate, color='blue', linestyle='dashed', marker='o', markerfacecolor='red', markersize=10)
            #plt.title('Error Rate vs. K Value')
            #plt.xlabel('K')
            #plt.ylabel('Error Rate')
            #plt.show()
        #--------------------------------------------------------------------------------------------------
            min_error = min(error_rate)
            optimal_k = error_rate.index(min_error) + 1  # Adding 1 because Python indexing starts from 0

            print(f"Optimal k value for minimum error rate: {optimal_k}")
            #print(f"Minimum Error Rate: {min_error}")
            list_ans.append(optimal_k)
        #--------------------------------------------------------------------------------------------------
            #使用KNN演算法
            clf=KNeighborsClassifier(n_neighbors=optimal_k,p=2,weights='distance',algorithm='brute')
            clf.fit(X_train,y_train)
        #--------------------------------------------------------------------------------------------------
            predict_label1={}
            predict_k_pre5={}
        #--------------------------------------------------------------------------------------------------

            for year in test_years:
                
                # 選擇特定年份的 test_data
                test_data = df[df['年月'].dt.year == year]
                print(year)
                #print(test_data)
                print(f"Number of rows in test_data: {len(test_data)}")
                
                # 選擇指定的欄位
                features_to_scale_test = test_data[selected_columns]
                # 使用之前訓練好的標準化物件進行標準化
                scaled_features_test = scaler.transform(features_to_scale_test)
                # 將標準化後的特徵資料轉換為 DataFrame
                df_feat_test = pd.DataFrame(scaled_features_test, columns=features_to_scale_test.columns)

                
                # 使用已經訓練好的模型進行預測
                predictions_new = clf.predict(df_feat_test)

                #------------------------------
                #測試KNN演算法的好壞
                from sklearn.metrics import classification_report,confusion_matrix
                #將實際類別分為真正例（True Positive）、真負例（True Negative）、偽正例（False Positive）和偽負例（False Negative）
                print('confusion_matrix:')
                print(confusion_matrix(test_data['ReturnMean_year_Label'],predictions_new))

                #模型的精確度、召回率、F1分數和支持數等指標，用來評估模型對於每個類別的預測性能。
                print('classification_report')
                print(classification_report(test_data['ReturnMean_year_Label'],predictions_new))

                # 比較預測結果
                accuracy_new = clf.score(df_feat_test, test_data['ReturnMean_year_Label'])
                print(f'新數據的預測準確率: {accuracy_new}')
                #---------------------------------------
                #print(predictions_new)

                #predicted_positive_indices = (predictions_new == 1)

                # 獲取股票名稱
                #predicted_positive_stock_names = new.loc[predicted_positive_indices, '簡稱']

                # 設定檔案名稱
                #output_file_name = 'selected_stocks_1998.csv'

                # 匯出成 CSV 檔案
                #predicted_positive_stock_names.to_csv(output_file_name, index=True)

                # 預測要投資的股票名稱
                #print("選擇股票:")
                #print(predicted_positive_stock_names)


                # 選擇預測為1的股票
                selected_stocks = test_data[predictions_new == 1]

                # 計算return
                stock_returns = selected_stocks['Return']

                portfolio_returns = (stock_returns.mean()/100)+1

                print(portfolio_returns)
                predict_label1[year]=portfolio_returns

                # 使用 kneighbors 方法取得最近鄰居的索引和距離
                distances, indices = clf.kneighbors(df_feat_test, n_neighbors=5)

                # 合併所有測試樣本的最近鄰居索引
                all_indices = np.concatenate(indices)
                all_distances = np.concatenate(distances)

                # 將索引和距離組合成一個 2D 陣列，方便排序
                combined_data = np.column_stack((all_indices, all_distances))

                # 按照距離重新排序
                sorted_combined_data = combined_data[np.argsort(combined_data[:, 1])]

                # 選取最近鄰居中預測值為1的前5筆，且不重複
                selected_indices = set()
                i = 0
                while len(selected_indices) < 5 and i < len(sorted_combined_data):
                    index = int(sorted_combined_data[i, 0])
                    if(index>=200):
                        index=index-200
                    elif(index>=400):
                        index=index-400
                    elif(index>=600):
                        index=index-600
                    elif(index>=800):
                        index=index-800
                    elif(index>=1000):
                        index=index-1000
                    elif(index>=1200):
                        index=index-1200
                    elif(index>=1400):
                        index=index-1400
                    elif(index>=1600):
                        index=index-1600
                    elif(index>=1800):
                        index=index-1800
                    elif(index>=2000):
                        index=index-2000
                    prediction = predictions_new[index]
                    if prediction == 1 and index not in selected_indices:
                        selected_indices.add(index)
                    i += 1
                        

                # 將選取的索引轉換成列表
                selected_indices_list = list(selected_indices)

                # 打印最近鄰居中預測值為1的前5筆索引
                print("最近鄰居中預測值為1的前5筆索引:")
                print(selected_indices_list)
                select = pd.read_excel(csv_file_path)
                # 獲取股票名稱
                selects_stock = select.iloc[selected_indices_list]['簡稱']
                print(selects_stock)
                # 獲取股票return
                selects_ret = select.iloc[selected_indices_list]['Return']
                print(selects_ret)
                with open(f'selected_stock_KNN_train/{cols}.txt', 'a') as stockfile:
                    stockfile.write(selects_stock.to_string())
                    stockfile.write('\n')
                    stockfile.write(selects_ret.to_string())
                # 計算return
                stock_returns = (selects_ret.mean() / 100)+1
                portfolio_returns = stock_returns
                print(portfolio_returns)
                predict_k_pre5[year] = portfolio_returns
                #print(stock_returns)
            sum1=1
            sum2=1
            print(predict_label1)
            for k in predict_label1.keys():
                if not (predict_label1[k]==0):
                    sum1=predict_label1[k]*sum1
            print(f'年均化複利為:{sum1/int(len(test_years))}')
            print('\n')
            print(predict_k_pre5)
            for k in predict_k_pre5.keys():
                if not (predict_k_pre5[k]==0):
                    sum2=predict_k_pre5[k]*sum2
            print(f'年均化複利為:{sum2/int(len(test_years))}')
            #list_ans.append(sum2/len(test_data)/200)
            print(f'ori sum2:{sum2}')
            print(f'test years have:{int(len(test_years))}')
            sum2=sum2/int(len(test_years))
            print(f'after sum2:{sum2}')
            list_ans.append(sum2)
            ans[cols]=list_ans
            file.write(f'{cols}:{list_ans}\n\n')
            file.flush()  # 強制將緩衝區內容寫入檔案
            if(sum2>max_ret):
                max_ret=sum2
                with open('max_KNN_train.txt', 'w') as maxfile:
                    maxfile.write(f'max:train_year:{train_years},test_year:{test_years}:{cols}:{list_ans}\n\n')
                    maxfile.flush()  # 強制將緩衝區內容寫入檔案
# Out:
# 總共有test year:11
# Number of rows in train_data: 200
# Optimal k value for minimum error rate: 41
# 1998
# Number of rows in test_data: 200
# confusion_matrix:
# [[71 55]
#  [38 36]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.65      0.56      0.60       126
#            1       0.40      0.49      0.44        74
#
#     accuracy                           0.54       200
#    macro avg       0.52      0.52      0.52       200
# weighted avg       0.56      0.54      0.54       200
#
# 新數據的預測準確率: 0.535
# 1.11534
# 最近鄰居中預測值為1的前5筆索引:
# [109, 46, 117, 24, 126]
# 109     楠梓電
# 46     士紙
# 117     中興電
# 24     中華
# 126    建台
# Name: 簡稱, dtype: object
# 109    62.2231
# 46    -17.5994
# 117   -43.1373
# 24      7.0642
# 126   -48.7382
# Name: Return, dtype: float64
# 0.9196248
# 1999
# Number of rows in test_data: 200
# confusion_matrix:
# [[72 39]
#  [42 47]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.63      0.65      0.64       111
#            1       0.55      0.53      0.54        89
#
#     accuracy                           0.59       200
#    macro avg       0.59      0.59      0.59       200
# weighted avg       0.59      0.59      0.59       200
#
# 新數據的預測準確率: 0.595
# 0.6141104186046512
# 最近鄰居中預測值為1的前5筆索引:
# [103, 109, 49, 60, 125]
# 103    D 復盛
# 109     楠梓電
# 49     遠航
# 60     環電
# 125    桂宏
# Name: 簡稱, dtype: object
# 103    -8.6990
# 109    62.2231
# 49    -41.3492
# 60     -4.7036
# 125   -35.0797
# Name: Return, dtype: float64
# 0.9447832
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[50 77]
#  [20 53]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.71      0.39      0.51       127
#            1       0.41      0.73      0.52        73
#
#     accuracy                           0.52       200
#    macro avg       0.56      0.56      0.51       200
# weighted avg       0.60      0.52      0.51       200
#
# 新數據的預測準確率: 0.515
# 1.379558623076923
# 最近鄰居中預測值為1的前5筆索引:
# [8, 46, 112, 125, 31]
# 8      台化
# 46     士紙
# 112    豐興
# 125    桂宏
# 31     台玻
# Name: 簡稱, dtype: object
# 8     -23.2413
# 46    -17.5994
# 112   -56.3989
# 125   -35.0797
# 31    -13.5007
# Name: Return, dtype: float64
# 0.7083600000000001
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[83 35]
#  [23 59]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.78      0.70      0.74       118
#            1       0.63      0.72      0.67        82
#
#     accuracy                           0.71       200
#    macro avg       0.71      0.71      0.71       200
# weighted avg       0.72      0.71      0.71       200
#
# 新數據的預測準確率: 0.71
# 1.1157145170212766
# 最近鄰居中預測值為1的前5筆索引:
# [8, 46, 88, 125, 31]
# 8      台化
# 46     士紙
# 88     中強
# 125    桂宏
# 31     台玻
# Name: 簡稱, dtype: object
# 8     -23.2413
# 46    -17.5994
# 88    -15.2596
# 125   -35.0797
# 31    -13.5007
# Name: Return, dtype: float64
# 0.7906386
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[47 69]
#  [31 53]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.60      0.41      0.48       116
#            1       0.43      0.63      0.51        84
#
#     accuracy                           0.50       200
#    macro avg       0.52      0.52      0.50       200
# weighted avg       0.53      0.50      0.50       200
#
# 新數據的預測準確率: 0.5
# 1.334907095819672
# 最近鄰居中預測值為1的前5筆索引:
# [133, 7, 19, 90, 60]
# 133    台紙
# 7      大同
# 19     華航
# 90      嘉食化
# 60     環電
# Name: 簡稱, dtype: object
# 133   -40.7609
# 7       1.5517
# 19    -14.8559
# 90    -13.4908
# 60     -4.7036
# Name: Return, dtype: float64
# 0.8554809999999999
# 2003
# Number of rows in test_data: 200
# confusion_matrix:
# [[56 42]
#  [41 61]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.57      0.57        98
#            1       0.59      0.60      0.60       102
#
#     accuracy                           0.58       200
#    macro avg       0.58      0.58      0.58       200
# weighted avg       0.58      0.58      0.58       200
#
# 新數據的預測準確率: 0.585
# 1.0772141650485436
# 最近鄰居中預測值為1的前5筆索引:
# [133, 76, 109, 60, 31]
# 133    台紙
# 76     飛瑞
# 109     楠梓電
# 60     環電
# 31     台玻
# Name: 簡稱, dtype: object
# 133   -40.7609
# 76      6.8826
# 109    62.2231
# 60     -4.7036
# 31    -13.5007
# Name: Return, dtype: float64
# 1.020281
# 2004
# Number of rows in test_data: 200
# confusion_matrix:
# [[59 71]
#  [32 38]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.65      0.45      0.53       130
#            1       0.35      0.54      0.42        70
#
#     accuracy                           0.48       200
#    macro avg       0.50      0.50      0.48       200
# weighted avg       0.54      0.48      0.50       200
#
# 新數據的預測準確率: 0.485
# 1.1316295733944954
# 最近鄰居中預測值為1的前5筆索引:
# [66, 6, 109, 20, 123]
# 66     大榮
# 6       日月光
# 109     楠梓電
# 20     亞泥
# 123    華榮
# Name: 簡稱, dtype: object
# 66    -38.3127
# 6     -17.5732
# 109    62.2231
# 20    -10.7026
# 123   -18.5047
# Name: Return, dtype: float64
# 0.9542598
# 2005
# Number of rows in test_data: 200
# confusion_matrix:
# [[70 42]
#  [41 47]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.63      0.62      0.63       112
#            1       0.53      0.53      0.53        88
#
#     accuracy                           0.58       200
#    macro avg       0.58      0.58      0.58       200
# weighted avg       0.59      0.58      0.59       200
#
# 新數據的預測準確率: 0.585
# 1.3636826103370785
# 最近鄰居中預測值為1的前5筆索引:
# [8, 74, 60, 93, 127]
# 8      台化
# 74     國豐
# 60     環電
# 93     嘉泥
# 127    福益
# Name: 簡稱, dtype: object
# 8     -23.2413
# 74    -28.3462
# 60     -4.7036
# 93    -27.6940
# 127   -67.2741
# Name: Return, dtype: float64
# 0.6974815999999999
# 2006
# Number of rows in test_data: 200
# confusion_matrix:
# [[74 41]
#  [52 33]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.64      0.61       115
#            1       0.45      0.39      0.42        85
#
#     accuracy                           0.54       200
#    macro avg       0.52      0.52      0.51       200
# weighted avg       0.53      0.54      0.53       200
#
# 新數據的預測準確率: 0.535
# 1.1568743662162162
# 最近鄰居中預測值為1的前5筆索引:
# [45, 46, 47, 49, 30]
# 45    南紡
# 46    士紙
# 47    國產
# 49    遠航
# 30    三陽
# Name: 簡稱, dtype: object
# 45   -26.0263
# 46   -17.5994
# 47   -45.9510
# 49   -41.3492
# 30   -35.3336
# Name: Return, dtype: float64
# 0.6674810000000001
# 2007
# Number of rows in test_data: 200
# confusion_matrix:
# [[86 26]
#  [53 35]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.62      0.77      0.69       112
#            1       0.57      0.40      0.47        88
#
#     accuracy                           0.60       200
#    macro avg       0.60      0.58      0.58       200
# weighted avg       0.60      0.60      0.59       200
#
# 新數據的預測準確率: 0.605
# 0.5469464672131148
# 最近鄰居中預測值為1的前5筆索引:
# [117, 24, 92, 126, 95]
# 117     中興電
# 24     中華
# 92     東聯
# 126    建台
# 95     寶祥
# Name: 簡稱, dtype: object
# 117   -43.1373
# 24      7.0642
# 92    -29.7543
# 126   -48.7382
# 95    -57.9195
# Name: Return, dtype: float64
# 0.6550297999999999
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[56 61]
#  [27 56]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.67      0.48      0.56       117
#            1       0.48      0.67      0.56        83
#
#     accuracy                           0.56       200
#    macro avg       0.58      0.58      0.56       200
# weighted avg       0.59      0.56      0.56       200
#
# 新數據的預測準確率: 0.56
# 2.1301243675213675
# 最近鄰居中預測值為1的前5筆索引:
# [100, 9, 19, 60, 31]
# 100    正隆
# 9      統一
# 19     華航
# 60     環電
# 31     台玻
# Name: 簡稱, dtype: object
# 100   -33.2625
# 9     -11.7468
# 19    -14.8559
# 60     -4.7036
# 31    -13.5007
# Name: Return, dtype: float64
# 0.843861
# {1998: 1.11534, 1999: 0.6141104186046512, 2000: 1.379558623076923, 2001: 1.1157145170212766, 2002: 1.334907095819672, 2003: 1.0772141650485436, 2004: 1.1316295733944954, 2005: 1.3636826103370785, 2006: 1.1568743662162162, 2007: 0.5469464672131148, 2008: 2.1301243675213675}
# 年均化複利為:0.2866559564774944
#
#
# {1998: 0.9196248, 1999: 0.9447832, 2000: 0.7083600000000001, 2001: 0.7906386, 2002: 0.8554809999999999, 2003: 1.020281, 2004: 0.9542598, 2005: 0.6974815999999999, 2006: 0.6674810000000001, 2007: 0.6550297999999999, 2008: 0.843861}
# 年均化複利為:0.009481621787552894
# ori sum2:0.10429783966308183
# test years have:11
# after sum2:0.009481621787552894
# Optimal k value for minimum error rate: 19
# 1998
# Number of rows in test_data: 200
# confusion_matrix:
# [[73 53]
#  [39 35]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.65      0.58      0.61       126
#            1       0.40      0.47      0.43        74
#
#     accuracy                           0.54       200
#    macro avg       0.52      0.53      0.52       200
# weighted avg       0.56      0.54      0.55       200
#
# 新數據的預測準確率: 0.54
# 1.144121840909091
# 最近鄰居中預測值為1的前5筆索引:
# [10, 77, 49, 24, 126]
# 10     鴻海
# 77     昱成
# 49     遠航
# 24     中華
# 126    建台
# Name: 簡稱, dtype: object
# 10     54.5701
# 77    -84.8007
# 49    -41.3492
# 24      7.0642
# 126   -48.7382
# Name: Return, dtype: float64
# 0.7734924
# 1999
# Number of rows in test_data: 200
# confusion_matrix:
# [[76 35]
#  [39 50]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.66      0.68      0.67       111
#            1       0.59      0.56      0.57        89
#
#     accuracy                           0.63       200
#    macro avg       0.62      0.62      0.62       200
# weighted avg       0.63      0.63      0.63       200
#
# 新數據的預測準確率: 0.63
# 0.6230220352941176
# 最近鄰居中預測值為1的前5筆索引:
# [131, 5, 109, 14, 28]
# 131    寶建
# 5      台塑
# 109     楠梓電
# 14     裕隆
# 28     東元
# Name: 簡稱, dtype: object
# 131   -18.7251
# 5     -15.9817
# 109    62.2231
# 14      1.1003
# 28    -25.7937
# Name: Return, dtype: float64
# 1.0056458
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[66 61]
#  [29 44]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.69      0.52      0.59       127
#            1       0.42      0.60      0.49        73
#
#     accuracy                           0.55       200
#    macro avg       0.56      0.56      0.54       200
# weighted avg       0.59      0.55      0.56       200
#
# 新數據的預測準確率: 0.55
# 1.4420691047619048
# 最近鄰居中預測值為1的前5筆索引:
# [0, 4, 69, 9, 28]
# 0      台積電
# 4     華碩
# 69     永豐餘
# 9     統一
# 28    東元
# Name: 簡稱, dtype: object
# 0     -6.3648
# 4     46.2737
# 69   -27.8824
# 9    -11.7468
# 28   -25.7937
# Name: Return, dtype: float64
# 0.948972
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[61 57]
#  [50 32]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.55      0.52      0.53       118
#            1       0.36      0.39      0.37        82
#
#     accuracy                           0.47       200
#    macro avg       0.45      0.45      0.45       200
# weighted avg       0.47      0.47      0.47       200
#
# 新數據的預測準確率: 0.465
# 0.9087209775280899
# 最近鄰居中預測值為1的前5筆索引:
# [9, 109, 55, 24, 88]
# 9      統一
# 109     楠梓電
# 55      震旦行
# 24     中華
# 88     中強
# Name: 簡稱, dtype: object
# 9     -11.7468
# 109    62.2231
# 55    -16.1681
# 24      7.0642
# 88    -15.2596
# Name: Return, dtype: float64
# 1.0522256
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[53 63]
#  [48 36]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.52      0.46      0.49       116
#            1       0.36      0.43      0.39        84
#
#     accuracy                           0.45       200
#    macro avg       0.44      0.44      0.44       200
# weighted avg       0.46      0.45      0.45       200
#
# 新數據的預測準確率: 0.445
# 1.263905496868687
# 最近鄰居中預測值為1的前5筆索引:
# [8, 41, 74, 22, 26]
# 8     台化
# 41    中工
# 74    國豐
# 22    華通
# 26    矽品
# Name: 簡稱, dtype: object
# 8    -23.2413
# 41   -48.5844
# 74   -28.3462
# 22    57.1229
# 26     2.0266
# Name: Return, dtype: float64
# 0.9179552
# 2003
# Number of rows in test_data: 200
# confusion_matrix:
# [[40 58]
#  [37 65]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.52      0.41      0.46        98
#            1       0.53      0.64      0.58       102
#
#     accuracy                           0.53       200
#    macro avg       0.52      0.52      0.52       200
# weighted avg       0.52      0.53      0.52       200
#
# 新數據的預測準確率: 0.525
# 0.9990621739837399
# 最近鄰居中預測值為1的前5筆索引:
# [5, 135, 22, 28, 61]
# 5      台塑
# 135    鴻友
# 22     華通
# 28     東元
# 61     南港
# Name: 簡稱, dtype: object
# 5     -15.9817
# 135   -48.8145
# 22     57.1229
# 28    -25.7937
# 61    -12.8136
# Name: Return, dtype: float64
# 0.9074388
# 2004
# Number of rows in test_data: 200
# confusion_matrix:
# [[56 74]
#  [19 51]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.75      0.43      0.55       130
#            1       0.41      0.73      0.52        70
#
#     accuracy                           0.54       200
#    macro avg       0.58      0.58      0.53       200
# weighted avg       0.63      0.54      0.54       200
#
# 新數據的預測準確率: 0.535
# 1.2326216008
# 最近鄰居中預測值為1的前5筆索引:
# [0, 133, 55, 24, 25]
# 0       台積電
# 133    台紙
# 55      震旦行
# 24     中華
# 25      國產車
# Name: 簡稱, dtype: object
# 0       -6.3648
# 133    -40.7609
# 55     -16.1681
# 24       7.0642
# 25    -100.0000
# Name: Return, dtype: float64
# 0.6875408000000001
# 2005
# Number of rows in test_data: 200
# confusion_matrix:
# [[43 69]
#  [36 52]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.54      0.38      0.45       112
#            1       0.43      0.59      0.50        88
#
#     accuracy                           0.48       200
#    macro avg       0.49      0.49      0.47       200
# weighted avg       0.49      0.47      0.47       200
#
# 新數據的預測準確率: 0.475
# 1.2540711076033058
# 最近鄰居中預測值為1的前5筆索引:
# [0, 66, 74, 19, 123]
# 0       台積電
# 66     大榮
# 74     國豐
# 19     華航
# 123    華榮
# Name: 簡稱, dtype: object
# 0      -6.3648
# 66    -38.3127
# 74    -28.3462
# 19    -14.8559
# 123   -18.5047
# Name: Return, dtype: float64
# 0.7872314
# 2006
# Number of rows in test_data: 200
# confusion_matrix:
# [[45 70]
#  [29 56]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.61      0.39      0.48       115
#            1       0.44      0.66      0.53        85
#
#     accuracy                           0.51       200
#    macro avg       0.53      0.53      0.50       200
# weighted avg       0.54      0.51      0.50       200
#
# 新數據的預測準確率: 0.505
# 1.0957643373015873
# 最近鄰居中預測值為1的前5筆索引:
# [0, 6, 9, 17, 28]
# 0      台積電
# 6      日月光
# 9     統一
# 17    太電
# 28    東元
# Name: 簡稱, dtype: object
# 0     -6.3648
# 6    -17.5732
# 9    -11.7468
# 17   -31.3760
# 28   -25.7937
# Name: Return, dtype: float64
# 0.814291
# 2007
# Number of rows in test_data: 200
# confusion_matrix:
# [[35 77]
#  [35 53]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.50      0.31      0.38       112
#            1       0.41      0.60      0.49        88
#
#     accuracy                           0.44       200
#    macro avg       0.45      0.46      0.44       200
# weighted avg       0.46      0.44      0.43       200
#
# 新數據的預測準確率: 0.44
# 0.4794423630769231
# 最近鄰居中預測值為1的前5筆索引:
# [103, 9, 24, 123, 60]
# 103    D 復盛
# 9      統一
# 24     中華
# 123    華榮
# 60     環電
# Name: 簡稱, dtype: object
# 103    -8.6990
# 9     -11.7468
# 24      7.0642
# 123   -18.5047
# 60     -4.7036
# Name: Return, dtype: float64
# 0.9268202
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[62 55]
#  [32 51]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.66      0.53      0.59       117
#            1       0.48      0.61      0.54        83
#
#     accuracy                           0.56       200
#    macro avg       0.57      0.57      0.56       200
# weighted avg       0.59      0.56      0.57       200
#
# 新數據的預測準確率: 0.565
# 2.093774103773585
# 最近鄰居中預測值為1的前5筆索引:
# [0, 98, 103, 22, 94]
# 0       台積電
# 98     信大
# 103    D 復盛
# 22     華通
# 94     德寶
# Name: 簡稱, dtype: object
# 0      -6.3648
# 98    -41.2002
# 103    -8.6990
# 22     57.1229
# 94    -32.8149
# Name: Return, dtype: float64
# 0.936088
# {1998: 1.144121840909091, 1999: 0.6230220352941176, 2000: 1.4420691047619048, 2001: 0.9087209775280899, 2002: 1.263905496868687, 2003: 0.9990621739837399, 2004: 1.2326216008, 2005: 1.2540711076033058, 2006: 1.0957643373015873, 2007: 0.4794423630769231, 2008: 2.093774103773585}
# 年均化複利為:0.1823232572293316
#
#
# {1998: 0.7734924, 1999: 1.0056458, 2000: 0.948972, 2001: 1.0522256, 2002: 0.9179552, 2003: 0.9074388, 2004: 0.6875408000000001, 2005: 0.7872314, 2006: 0.814291, 2007: 0.9268202, 2008: 0.936088}
# 年均化複利為:0.022490659468132005
# ori sum2:0.24739725414945204
# test years have:11
# after sum2:0.022490659468132005
# Optimal k value for minimum error rate: 74
# 1998
# Number of rows in test_data: 200
# confusion_matrix:
# [[104  22]
#  [ 57  17]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.65      0.83      0.72       126
#            1       0.44      0.23      0.30        74
#
#     accuracy                           0.60       200
#    macro avg       0.54      0.53      0.51       200
# weighted avg       0.57      0.60      0.57       200
#
# 新數據的預測準確率: 0.605
# 1.317691794871795
# 最近鄰居中預測值為1的前5筆索引:
# [65, 17, 49, 20, 126]
# 65      光寶科
# 17     太電
# 49     遠航
# 20     亞泥
# 126    建台
# Name: 簡稱, dtype: object
# 65    -53.2099
# 17    -31.3760
# 49    -41.3492
# 20    -10.7026
# 126   -48.7382
# Name: Return, dtype: float64
# 0.6292481999999999
# 1999
# Number of rows in test_data: 200
# confusion_matrix:
# [[94 17]
#  [77 12]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.55      0.85      0.67       111
#            1       0.41      0.13      0.20        89
#
#     accuracy                           0.53       200
#    macro avg       0.48      0.49      0.44       200
# weighted avg       0.49      0.53      0.46       200
#
# 新數據的預測準確率: 0.53
# 0.5365678620689656
# 最近鄰居中預測值為1的前5筆索引:
# [3, 6, 108, 19, 60]
# 3      南亞
# 6       日月光
# 108    新保
# 19     華航
# 60     環電
# Name: 簡稱, dtype: object
# 3     -12.0864
# 6     -17.5732
# 108   -28.3389
# 19    -14.8559
# 60     -4.7036
# Name: Return, dtype: float64
# 0.844884
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[98 29]
#  [53 20]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.65      0.77      0.71       127
#            1       0.41      0.27      0.33        73
#
#     accuracy                           0.59       200
#    macro avg       0.53      0.52      0.52       200
# weighted avg       0.56      0.59      0.57       200
#
# 新數據的預測準確率: 0.59
# 1.2993250204081632
# 最近鄰居中預測值為1的前5筆索引:
# [0, 121, 4, 133, 25]
# 0       台積電
# 121    台火
# 4      華碩
# 133    台紙
# 25      國產車
# Name: 簡稱, dtype: object
# 0       -6.3648
# 121    -39.6430
# 4       46.2737
# 133    -40.7609
# 25    -100.0000
# Name: Return, dtype: float64
# 0.7190099999999999
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[103  15]
#  [ 61  21]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.63      0.87      0.73       118
#            1       0.58      0.26      0.36        82
#
#     accuracy                           0.62       200
#    macro avg       0.61      0.56      0.54       200
# weighted avg       0.61      0.62      0.58       200
#
# 新數據的預測準確率: 0.62
# 1.0693598333333334
# 最近鄰居中預測值為1的前5筆索引:
# [41, 49, 17, 91, 126]
# 41     中工
# 49     遠航
# 17     太電
# 91     立榮
# 126    建台
# Name: 簡稱, dtype: object
# 41    -48.5844
# 49    -41.3492
# 17    -31.3760
# 91    -25.2783
# 126   -48.7382
# Name: Return, dtype: float64
# 0.6093477999999999
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[93 23]
#  [63 21]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.60      0.80      0.68       116
#            1       0.48      0.25      0.33        84
#
#     accuracy                           0.57       200
#    macro avg       0.54      0.53      0.51       200
# weighted avg       0.55      0.57      0.53       200
#
# 新數據的預測準確率: 0.57
# 1.3457701022727273
# 最近鄰居中預測值為1的前5筆索引:
# [100, 8, 9, 111, 54]
# 100    正隆
# 8      台化
# 9      統一
# 111    燁輝
# 54     長億
# Name: 簡稱, dtype: object
# 100   -33.2625
# 8     -23.2413
# 9     -11.7468
# 111   -27.8249
# 54    -44.5789
# Name: Return, dtype: float64
# 0.7186912000000001
# 2003
# Number of rows in test_data: 200
# confusion_matrix:
# [[78 20]
#  [80 22]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.49      0.80      0.61        98
#            1       0.52      0.22      0.31       102
#
#     accuracy                           0.50       200
#    macro avg       0.51      0.51      0.46       200
# weighted avg       0.51      0.50      0.45       200
#
# 新數據的預測準確率: 0.5
# 1.0049693595238096
# 最近鄰居中預測值為1的前5筆索引:
# [2, 99, 5, 109, 22]
# 2      中鋼
# 99     威致
# 5      台塑
# 109     楠梓電
# 22     華通
# Name: 簡稱, dtype: object
# 2      -9.2224
# 99    -66.3043
# 5     -15.9817
# 109    62.2231
# 22     57.1229
# Name: Return, dtype: float64
# 1.0556752
# 2004
# Number of rows in test_data: 200
# confusion_matrix:
# [[109  21]
#  [ 54  16]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.67      0.84      0.74       130
#            1       0.43      0.23      0.30        70
#
#     accuracy                           0.62       200
#    macro avg       0.55      0.53      0.52       200
# weighted avg       0.59      0.62      0.59       200
#
# 新數據的預測準確率: 0.625
# 1.2212303243243243
# 最近鄰居中預測值為1的前5筆索引:
# [73, 118, 60, 94, 31]
# 73     聲寶
# 118    友訊
# 60     環電
# 94     德寶
# 31     台玻
# Name: 簡稱, dtype: object
# 73     30.3630
# 118    51.1769
# 60     -4.7036
# 94    -32.8149
# 31    -13.5007
# Name: Return, dtype: float64
# 1.0610414
# 2005
# Number of rows in test_data: 200
# confusion_matrix:
# [[104   8]
#  [ 65  23]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.62      0.93      0.74       112
#            1       0.74      0.26      0.39        88
#
#     accuracy                           0.64       200
#    macro avg       0.68      0.59      0.56       200
# weighted avg       0.67      0.64      0.58       200
#
# 新數據的預測準確率: 0.635
# 1.5120593838709677
# 最近鄰居中預測值為1的前5筆索引:
# [100, 6, 41, 126, 127]
# 100    正隆
# 6       日月光
# 41     中工
# 126    建台
# 127    福益
# Name: 簡稱, dtype: object
# 100   -33.2625
# 6     -17.5732
# 41    -48.5844
# 126   -48.7382
# 127   -67.2741
# Name: Return, dtype: float64
# 0.5691352000000001
# 2006
# Number of rows in test_data: 200
# confusion_matrix:
# [[99 16]
#  [71 14]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.86      0.69       115
#            1       0.47      0.16      0.24        85
#
#     accuracy                           0.56       200
#    macro avg       0.52      0.51      0.47       200
# weighted avg       0.53      0.56      0.50       200
#
# 新數據的預測準確率: 0.565
# 1.1380968333333334
# 最近鄰居中預測值為1的前5筆索引:
# [68, 6, 43, 54, 28]
# 68    新纖
# 6      日月光
# 43    太設
# 54    長億
# 28    東元
# Name: 簡稱, dtype: object
# 68   -23.9447
# 6    -17.5732
# 43   -45.7298
# 54   -44.5789
# 28   -25.7937
# Name: Return, dtype: float64
# 0.6847594
# 2007
# Number of rows in test_data: 200
# confusion_matrix:
# [[109   3]
#  [ 71  17]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.61      0.97      0.75       112
#            1       0.85      0.19      0.31        88
#
#     accuracy                           0.63       200
#    macro avg       0.73      0.58      0.53       200
# weighted avg       0.71      0.63      0.56       200
#
# 新數據的預測準確率: 0.63
# 0.610827775
# 最近鄰居中預測值為1的前5筆索引:
# [2, 66, 137, 43, 126]
# 2      中鋼
# 66     大榮
# 137    宏普
# 43     太設
# 126    建台
# Name: 簡稱, dtype: object
# 2      -9.2224
# 66    -38.3127
# 137   -52.5500
# 43    -45.7298
# 126   -48.7382
# Name: Return, dtype: float64
# 0.6108937999999999
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[106  11]
#  [ 76   7]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.91      0.71       117
#            1       0.39      0.08      0.14        83
#
#     accuracy                           0.56       200
#    macro avg       0.49      0.50      0.42       200
# weighted avg       0.50      0.56      0.47       200
#
# 新數據的預測準確率: 0.565
# 2.003958777777778
# 最近鄰居中預測值為1的前5筆索引:
# [104, 41, 20, 54, 127]
# 104    聯華
# 41     中工
# 20     亞泥
# 54     長億
# 127    福益
# Name: 簡稱, dtype: object
# 104   -13.6036
# 41    -48.5844
# 20    -10.7026
# 54    -44.5789
# 127   -67.2741
# Name: Return, dtype: float64
# 0.6305128
# {1998: 1.317691794871795, 1999: 0.5365678620689656, 2000: 1.2993250204081632, 2001: 1.0693598333333334, 2002: 1.3457701022727273, 2003: 1.0049693595238096, 2004: 1.2212303243243243, 2005: 1.5120593838709677, 2006: 1.1380968333333334, 2007: 0.610827775, 2008: 2.003958777777778}
# 年均化複利為:0.3107165467182911
#
#
# {1998: 0.6292481999999999, 1999: 0.844884, 2000: 0.7190099999999999, 2001: 0.6093477999999999, 2002: 0.7186912000000001, 2003: 1.0556752, 2004: 1.0610414, 2005: 0.5691352000000001, 2006: 0.6847594, 2007: 0.6108937999999999, 2008: 0.6305128}
# 年均化複利為:0.002558848720779536
# ori sum2:0.028147335928574897
# test years have:11
# after sum2:0.002558848720779536
# Optimal k value for minimum error rate: 4
# 1998
# Number of rows in test_data: 200
# confusion_matrix:
# [[66 60]
#  [36 38]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.65      0.52      0.58       126
#            1       0.39      0.51      0.44        74
#
#     accuracy                           0.52       200
#    macro avg       0.52      0.52      0.51       200
# weighted avg       0.55      0.52      0.53       200
#
# 新數據的預測準確率: 0.52
# 1.1759891224489796
# 最近鄰居中預測值為1的前5筆索引:
# [10, 19, 123, 29, 127]
# 10     鴻海
# 19     華航
# 123    華榮
# 29     國揚
# 127    福益
# Name: 簡稱, dtype: object
# 10      54.5701
# 19     -14.8559
# 123    -18.5047
# 29    -100.0000
# 127    -67.2741
# Name: Return, dtype: float64
# 0.7078708
# 1999
# Number of rows in test_data: 200
# confusion_matrix:
# [[71 40]
#  [36 53]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.66      0.64      0.65       111
#            1       0.57      0.60      0.58        89
#
#     accuracy                           0.62       200
#    macro avg       0.62      0.62      0.62       200
# weighted avg       0.62      0.62      0.62       200
#
# 新數據的預測準確率: 0.62
# 0.5894919569892474
# 最近鄰居中預測值為1的前5筆索引:
# [9, 109, 83, 31, 95]
# 9      統一
# 109     楠梓電
# 83     東鋼
# 31     台玻
# 95     寶祥
# Name: 簡稱, dtype: object
# 9     -11.7468
# 109    62.2231
# 83    -30.7411
# 31    -13.5007
# 95    -57.9195
# Name: Return, dtype: float64
# 0.89663
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[56 71]
#  [24 49]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.70      0.44      0.54       127
#            1       0.41      0.67      0.51        73
#
#     accuracy                           0.53       200
#    macro avg       0.55      0.56      0.52       200
# weighted avg       0.59      0.53      0.53       200
#
# 新數據的預測準確率: 0.525
# 1.3880518166666667
# 最近鄰居中預測值為1的前5筆索引:
# [8, 108, 23, 127, 31]
# 8      台化
# 108    新保
# 23     國建
# 127    福益
# 31     台玻
# Name: 簡稱, dtype: object
# 8     -23.2413
# 108   -28.3389
# 23    -41.5319
# 127   -67.2741
# 31    -13.5007
# Name: Return, dtype: float64
# 0.6522262
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[61 57]
#  [40 42]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.60      0.52      0.56       118
#            1       0.42      0.51      0.46        82
#
#     accuracy                           0.52       200
#    macro avg       0.51      0.51      0.51       200
# weighted avg       0.53      0.52      0.52       200
#
# 新數據的預測準確率: 0.515
# 0.9502648575757576
# 最近鄰居中預測值為1的前5筆索引:
# [98, 100, 77, 23, 87]
# 98     信大
# 100    正隆
# 77     昱成
# 23     國建
# 87     美式
# Name: 簡稱, dtype: object
# 98    -41.2002
# 100   -33.2625
# 77    -84.8007
# 23    -41.5319
# 87      4.9370
# Name: Return, dtype: float64
# 0.6082833999999999
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[55 61]
#  [38 46]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.47      0.53       116
#            1       0.43      0.55      0.48        84
#
#     accuracy                           0.51       200
#    macro avg       0.51      0.51      0.50       200
# weighted avg       0.52      0.51      0.51       200
#
# 新數據的預測準確率: 0.505
# 1.314783423271028
# 最近鄰居中預測值為1的前5筆索引:
# [100, 133, 8, 10, 121]
# 100    正隆
# 133    台紙
# 8      台化
# 10     鴻海
# 121    台火
# Name: 簡稱, dtype: object
# 100   -33.2625
# 133   -40.7609
# 8     -23.2413
# 10     54.5701
# 121   -39.6430
# Name: Return, dtype: float64
# 0.8353248
# 2003
# Number of rows in test_data: 200
# confusion_matrix:
# [[47 51]
#  [49 53]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.49      0.48      0.48        98
#            1       0.51      0.52      0.51       102
#
#     accuracy                           0.50       200
#    macro avg       0.50      0.50      0.50       200
# weighted avg       0.50      0.50      0.50       200
#
# 新數據的預測準確率: 0.5
# 1.0214744076923077
# 最近鄰居中預測值為1的前5筆索引:
# [133, 109, 17, 82, 127]
# 133    台紙
# 109     楠梓電
# 17     太電
# 82     冠德
# 127    福益
# Name: 簡稱, dtype: object
# 133   -40.7609
# 109    62.2231
# 17    -31.3760
# 82    -35.4419
# 127   -67.2741
# Name: Return, dtype: float64
# 0.7747404
# 2004
# Number of rows in test_data: 200
# confusion_matrix:
# [[59 71]
#  [25 45]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.70      0.45      0.55       130
#            1       0.39      0.64      0.48        70
#
#     accuracy                           0.52       200
#    macro avg       0.55      0.55      0.52       200
# weighted avg       0.59      0.52      0.53       200
#
# 新數據的預測準確率: 0.52
# 1.2217845698275862
# 最近鄰居中預測值為1的前5筆索引:
# [4, 75, 118, 120, 31]
# 4      華碩
# 75     長興
# 118    友訊
# 120    尖美
# 31     台玻
# Name: 簡稱, dtype: object
# 4      46.2737
# 75    -18.1818
# 118    51.1769
# 120   -14.7742
# 31    -13.5007
# Name: Return, dtype: float64
# 1.1019878
# 2005
# Number of rows in test_data: 200
# confusion_matrix:
# [[49 63]
#  [38 50]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.56      0.44      0.49       112
#            1       0.44      0.57      0.50        88
#
#     accuracy                           0.49       200
#    macro avg       0.50      0.50      0.49       200
# weighted avg       0.51      0.49      0.49       200
#
# 新數據的預測準確率: 0.495
# 1.2980416539823008
# 最近鄰居中預測值為1的前5筆索引:
# [66, 100, 4, 133, 75]
# 66     大榮
# 100    正隆
# 4      華碩
# 133    台紙
# 75     長興
# Name: 簡稱, dtype: object
# 66    -38.3127
# 100   -33.2625
# 4      46.2737
# 133   -40.7609
# 75    -18.1818
# Name: Return, dtype: float64
# 0.8315116
# 2006
# Number of rows in test_data: 200
# confusion_matrix:
# [[46 69]
#  [35 50]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.57      0.40      0.47       115
#            1       0.42      0.59      0.49        85
#
#     accuracy                           0.48       200
#    macro avg       0.49      0.49      0.48       200
# weighted avg       0.51      0.48      0.48       200
#
# 新數據的預測準確率: 0.48
# 1.098110206722689
# 最近鄰居中預測值為1的前5筆索引:
# [100, 133, 72, 23, 29]
# 100    正隆
# 133    台紙
# 72     凌陽
# 23     國建
# 29     國揚
# Name: 簡稱, dtype: object
# 100    -33.2625
# 133    -40.7609
# 72      21.4721
# 23     -41.5319
# 29    -100.0000
# Name: Return, dtype: float64
# 0.6118336
# 2007
# Number of rows in test_data: 200
# confusion_matrix:
# [[53 59]
#  [38 50]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.47      0.52       112
#            1       0.46      0.57      0.51        88
#
#     accuracy                           0.52       200
#    macro avg       0.52      0.52      0.51       200
# weighted avg       0.53      0.52      0.52       200
#
# 新數據的預測準確率: 0.515
# 0.49404880275229357
# 最近鄰居中預測值為1的前5筆索引:
# [4, 100, 73, 43, 109]
# 4      華碩
# 100    正隆
# 73     聲寶
# 43     太設
# 109     楠梓電
# Name: 簡稱, dtype: object
# 4      46.2737
# 100   -33.2625
# 73     30.3630
# 43    -45.7298
# 109    62.2231
# Name: Return, dtype: float64
# 1.119735
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[58 59]
#  [42 41]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.50      0.53       117
#            1       0.41      0.49      0.45        83
#
#     accuracy                           0.49       200
#    macro avg       0.49      0.49      0.49       200
# weighted avg       0.51      0.49      0.50       200
#
# 新數據的預測準確率: 0.495
# 2.02053607
# 最近鄰居中預測值為1的前5筆索引:
# [4, 74, 19, 20, 60]
# 4     華碩
# 74    國豐
# 19    華航
# 20    亞泥
# 60    環電
# Name: 簡稱, dtype: object
# 4     46.2737
# 74   -28.3462
# 19   -14.8559
# 20   -10.7026
# 60    -4.7036
# Name: Return, dtype: float64
# 0.9753307999999999
# {1998: 1.1759891224489796, 1999: 0.5894919569892474, 2000: 1.3880518166666667, 2001: 0.9502648575757576, 2002: 1.314783423271028, 2003: 1.0214744076923077, 2004: 1.2217845698275862, 2005: 1.2980416539823008, 2006: 1.098110206722689, 2007: 0.49404880275229357, 2008: 2.02053607}
# 年均化複利為:0.1940824265201858
#
#
# {1998: 0.7078708, 1999: 0.89663, 2000: 0.6522262, 2001: 0.6082833999999999, 2002: 0.8353248, 2003: 0.7747404, 2004: 1.1019878, 2005: 0.8315116, 2006: 0.6118336, 2007: 1.119735, 2008: 0.9753307999999999}
# 年均化複利為:0.009070599193076513
# ori sum2:0.09977659112384164
# test years have:11
# after sum2:0.009070599193076513
# Optimal k value for minimum error rate: 47
# 1998
# Number of rows in test_data: 200
# confusion_matrix:
# [[81 45]
#  [36 38]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.69      0.64      0.67       126
#            1       0.46      0.51      0.48        74
#
#     accuracy                           0.59       200
#    macro avg       0.58      0.58      0.58       200
# weighted avg       0.61      0.59      0.60       200
#
# 新數據的預測準確率: 0.595
# 1.2306802409638555
# 最近鄰居中預測值為1的前5筆索引:
# [103, 18, 24, 121, 126]
# 103    D 復盛
# 18     長榮
# 24     中華
# 121    台火
# 126    建台
# Name: 簡稱, dtype: object
# 103    -8.6990
# 18    -16.8475
# 24      7.0642
# 121   -39.6430
# 126   -48.7382
# Name: Return, dtype: float64
# 0.786273
# 1999
# Number of rows in test_data: 200
# confusion_matrix:
# [[75 36]
#  [44 45]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.63      0.68      0.65       111
#            1       0.56      0.51      0.53        89
#
#     accuracy                           0.60       200
#    macro avg       0.59      0.59      0.59       200
# weighted avg       0.60      0.60      0.60       200
#
# 新數據的預測準確率: 0.6
# 0.5914478765432098
# 最近鄰居中預測值為1的前5筆索引:
# [64, 4, 9, 10, 109]
# 64     士電
# 4      華碩
# 9      統一
# 10     鴻海
# 109     楠梓電
# Name: 簡稱, dtype: object
# 64    -12.1348
# 4      46.2737
# 9     -11.7468
# 10     54.5701
# 109    62.2231
# Name: Return, dtype: float64
# 1.2783706
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[66 61]
#  [22 51]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.75      0.52      0.61       127
#            1       0.46      0.70      0.55        73
#
#     accuracy                           0.58       200
#    macro avg       0.60      0.61      0.58       200
# weighted avg       0.64      0.58      0.59       200
#
# 新數據的預測準確率: 0.585
# 1.4669726607142857
# 最近鄰居中預測值為1的前5筆索引:
# [0, 103, 19, 84, 127]
# 0       台積電
# 103    D 復盛
# 19     華航
# 84     廣宇
# 127    福益
# Name: 簡稱, dtype: object
# 0      -6.3648
# 103    -8.6990
# 19    -14.8559
# 84    -74.5739
# 127   -67.2741
# Name: Return, dtype: float64
# 0.6564646000000001
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[64 54]
#  [47 35]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.54      0.56       118
#            1       0.39      0.43      0.41        82
#
#     accuracy                           0.49       200
#    macro avg       0.48      0.48      0.48       200
# weighted avg       0.50      0.49      0.50       200
#
# 新數據的預測準確率: 0.495
# 0.9076352584269662
# 最近鄰居中預測值為1的前5筆索引:
# [100, 24, 121, 126, 95]
# 100    正隆
# 24     中華
# 121    台火
# 126    建台
# 95     寶祥
# Name: 簡稱, dtype: object
# 100   -33.2625
# 24      7.0642
# 121   -39.6430
# 126   -48.7382
# 95    -57.9195
# Name: Return, dtype: float64
# 0.655002
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[49 67]
#  [42 42]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.54      0.42      0.47       116
#            1       0.39      0.50      0.44        84
#
#     accuracy                           0.46       200
#    macro avg       0.46      0.46      0.45       200
# weighted avg       0.47      0.46      0.46       200
#
# 新數據的預測準確率: 0.455
# 1.2799782275229359
# 最近鄰居中預測值為1的前5筆索引:
# [8, 11, 109, 56, 26]
# 8      台化
# 11     茂矽
# 109     楠梓電
# 56     藍天
# 26     矽品
# Name: 簡稱, dtype: object
# 8     -23.2413
# 11    -10.8920
# 109    62.2231
# 56    -49.1160
# 26      2.0266
# Name: Return, dtype: float64
# 0.9620008
# 2003
# Number of rows in test_data: 200
# confusion_matrix:
# [[40 58]
#  [38 64]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.51      0.41      0.45        98
#            1       0.52      0.63      0.57       102
#
#     accuracy                           0.52       200
#    macro avg       0.52      0.52      0.51       200
# weighted avg       0.52      0.52      0.51       200
#
# 新數據的預測準確率: 0.52
# 1.0028950524590163
# 最近鄰居中預測值為1的前5筆索引:
# [4, 6, 120, 123, 125]
# 4      華碩
# 6       日月光
# 120    尖美
# 123    華榮
# 125    桂宏
# Name: 簡稱, dtype: object
# 4      46.2737
# 6     -17.5732
# 120   -14.7742
# 123   -18.5047
# 125   -35.0797
# Name: Return, dtype: float64
# 0.9206837999999999
# 2004
# Number of rows in test_data: 200
# confusion_matrix:
# [[42 88]
#  [16 54]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.72      0.32      0.45       130
#            1       0.38      0.77      0.51        70
#
#     accuracy                           0.48       200
#    macro avg       0.55      0.55      0.48       200
# weighted avg       0.60      0.48      0.47       200
#
# 新數據的預測準確率: 0.48
# 1.2081065992957747
# 最近鄰居中預測值為1的前5筆索引:
# [133, 72, 118, 24, 121]
# 133    台紙
# 72     凌陽
# 118    友訊
# 24     中華
# 121    台火
# Name: 簡稱, dtype: object
# 133   -40.7609
# 72     21.4721
# 118    51.1769
# 24      7.0642
# 121   -39.6430
# Name: Return, dtype: float64
# 0.9986186
# 2005
# Number of rows in test_data: 200
# confusion_matrix:
# [[40 72]
#  [37 51]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.52      0.36      0.42       112
#            1       0.41      0.58      0.48        88
#
#     accuracy                           0.46       200
#    macro avg       0.47      0.47      0.45       200
# weighted avg       0.47      0.46      0.45       200
#
# 新數據的預測準確率: 0.455
# 1.2322172936585365
# 最近鄰居中預測值為1的前5筆索引:
# [103, 135, 74, 109, 19]
# 103    D 復盛
# 135    鴻友
# 74     國豐
# 109     楠梓電
# 19     華航
# Name: 簡稱, dtype: object
# 103    -8.6990
# 135   -48.8145
# 74    -28.3462
# 109    62.2231
# 19    -14.8559
# Name: Return, dtype: float64
# 0.923015
# 2006
# Number of rows in test_data: 200
# confusion_matrix:
# [[42 73]
#  [27 58]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.61      0.37      0.46       115
#            1       0.44      0.68      0.54        85
#
#     accuracy                           0.50       200
#    macro avg       0.53      0.52      0.50       200
# weighted avg       0.54      0.50      0.49       200
#
# 新數據的預測準確率: 0.5
# 1.1022789083969466
# 最近鄰居中預測值為1的前5筆索引:
# [100, 71, 103, 9, 120]
# 100    正隆
# 71     台聚
# 103    D 復盛
# 9      統一
# 120    尖美
# Name: 簡稱, dtype: object
# 100   -33.2625
# 71    -26.2059
# 103    -8.6990
# 9     -11.7468
# 120   -14.7742
# Name: Return, dtype: float64
# 0.8106232
# 2007
# Number of rows in test_data: 200
# confusion_matrix:
# [[34 78]
#  [28 60]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.55      0.30      0.39       112
#            1       0.43      0.68      0.53        88
#
#     accuracy                           0.47       200
#    macro avg       0.49      0.49      0.46       200
# weighted avg       0.50      0.47      0.45       200
#
# 新數據的預測準確率: 0.47
# 0.4962696318840579
# 最近鄰居中預測值為1的前5筆索引:
# [9, 19, 26, 123, 28]
# 9      統一
# 19     華航
# 26     矽品
# 123    華榮
# 28     東元
# Name: 簡稱, dtype: object
# 9     -11.7468
# 19    -14.8559
# 26      2.0266
# 123   -18.5047
# 28    -25.7937
# Name: Return, dtype: float64
# 0.862251
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[66 51]
#  [34 49]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.66      0.56      0.61       117
#            1       0.49      0.59      0.54        83
#
#     accuracy                           0.57       200
#    macro avg       0.57      0.58      0.57       200
# weighted avg       0.59      0.57      0.58       200
#
# 新數據的預測準確率: 0.575
# 2.1143612
# 最近鄰居中預測值為1的前5筆索引:
# [4, 135, 103, 111, 56]
# 4      華碩
# 135    鴻友
# 103    D 復盛
# 111    燁輝
# 56     藍天
# Name: 簡稱, dtype: object
# 4      46.2737
# 135   -48.8145
# 103    -8.6990
# 111   -27.8249
# 56    -49.1160
# Name: Return, dtype: float64
# 0.8236386
# {1998: 1.2306802409638555, 1999: 0.5914478765432098, 2000: 1.4669726607142857, 2001: 0.9076352584269662, 2002: 1.2799782275229359, 2003: 1.0028950524590163, 2004: 1.2081065992957747, 2005: 1.2322172936585365, 2006: 1.1022789083969466, 2007: 0.4962696318840579, 2008: 2.1143612}
# 年均化複利為:0.19473382930312322
#
#
# {1998: 0.786273, 1999: 1.2783706, 2000: 0.6564646000000001, 2001: 0.655002, 2002: 0.9620008, 2003: 0.9206837999999999, 2004: 0.9986186, 2005: 0.923015, 2006: 0.8106232, 2007: 0.862251, 2008: 0.8236386}
# 年均化複利為:0.018466099071826794
# ori sum2:0.20312708979009475
# test years have:11
# after sum2:0.018466099071826794
# Optimal k value for minimum error rate: 10
# 1998
# Number of rows in test_data: 200
# confusion_matrix:
# [[84 42]
#  [38 36]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.69      0.67      0.68       126
#            1       0.46      0.49      0.47        74
#
#     accuracy                           0.60       200
#    macro avg       0.58      0.58      0.58       200
# weighted avg       0.60      0.60      0.60       200
#
# 新數據的預測準確率: 0.6
# 1.1942455
# 最近鄰居中預測值為1的前5筆索引:
# [6, 77, 60, 17, 28]
# 6      日月光
# 77    昱成
# 60    環電
# 17    太電
# 28    東元
# Name: 簡稱, dtype: object
# 6    -17.5732
# 77   -84.8007
# 60    -4.7036
# 17   -31.3760
# 28   -25.7937
# Name: Return, dtype: float64
# 0.6715055999999999
# 1999
# Number of rows in test_data: 200
# confusion_matrix:
# [[64 47]
#  [44 45]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.58      0.58       111
#            1       0.49      0.51      0.50        89
#
#     accuracy                           0.55       200
#    macro avg       0.54      0.54      0.54       200
# weighted avg       0.55      0.55      0.55       200
#
# 新數據的預測準確率: 0.545
# 0.5765984782608695
# 最近鄰居中預測值為1的前5筆索引:
# [69, 133, 87, 89, 60]
# 69      永豐餘
# 133    台紙
# 87     美式
# 89     新紡
# 60     環電
# Name: 簡稱, dtype: object
# 69    -27.8824
# 133   -40.7609
# 87      4.9370
# 89    -46.5983
# 60     -4.7036
# Name: Return, dtype: float64
# 0.7699836
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[64 63]
#  [17 56]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.79      0.50      0.62       127
#            1       0.47      0.77      0.58        73
#
#     accuracy                           0.60       200
#    macro avg       0.63      0.64      0.60       200
# weighted avg       0.67      0.60      0.60       200
#
# 新數據的預測準確率: 0.6
# 1.464445613445378
# 最近鄰居中預測值為1的前5筆索引:
# [4, 133, 109, 77, 60]
# 4      華碩
# 133    台紙
# 109     楠梓電
# 77     昱成
# 60     環電
# Name: 簡稱, dtype: object
# 4      46.2737
# 133   -40.7609
# 109    62.2231
# 77    -84.8007
# 60     -4.7036
# Name: Return, dtype: float64
# 0.9564632
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[67 51]
#  [45 37]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.60      0.57      0.58       118
#            1       0.42      0.45      0.44        82
#
#     accuracy                           0.52       200
#    macro avg       0.51      0.51      0.51       200
# weighted avg       0.53      0.52      0.52       200
#
# 新數據的預測準確率: 0.52
# 0.9387934045454546
# 最近鄰居中預測值為1的前5筆索引:
# [98, 9, 55, 23, 94]
# 98    信大
# 9     統一
# 55     震旦行
# 23    國建
# 94    德寶
# Name: 簡稱, dtype: object
# 98   -41.2002
# 9    -11.7468
# 55   -16.1681
# 23   -41.5319
# 94   -32.8149
# Name: Return, dtype: float64
# 0.7130762
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[57 59]
#  [46 38]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.55      0.49      0.52       116
#            1       0.39      0.45      0.42        84
#
#     accuracy                           0.48       200
#    macro avg       0.47      0.47      0.47       200
# weighted avg       0.49      0.47      0.48       200
#
# 新數據的預測準確率: 0.475
# 1.2586436937113403
# 最近鄰居中預測值為1的前5筆索引:
# [135, 56, 26, 126, 127]
# 135    鴻友
# 56     藍天
# 26     矽品
# 126    建台
# 127    福益
# Name: 簡稱, dtype: object
# 135   -48.8145
# 56    -49.1160
# 26      2.0266
# 126   -48.7382
# 127   -67.2741
# Name: Return, dtype: float64
# 0.5761676
# 2003
# Number of rows in test_data: 200
# confusion_matrix:
# [[40 58]
#  [34 68]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.54      0.41      0.47        98
#            1       0.54      0.67      0.60       102
#
#     accuracy                           0.54       200
#    macro avg       0.54      0.54      0.53       200
# weighted avg       0.54      0.54      0.53       200
#
# 新數據的預測準確率: 0.54
# 1.0183904714285714
# 最近鄰居中預測值為1的前5筆索引:
# [135, 13, 17, 54, 120]
# 135    鴻友
# 13      華邦電
# 17     太電
# 54     長億
# ...
#
#           -1       0.82      0.56      0.67       118
#            1       0.57      0.83      0.67        82
#
#     accuracy                           0.67       200
#    macro avg       0.70      0.69      0.67       200
# weighted avg       0.72      0.67      0.67       200
#
# 新數據的預測準確率: 0.67
# 1.052709705
# 最近鄰居中預測值為1的前5筆索引:
# [64, 102, 103, 184, 57]
# 64     士電
# 102    中鼎
# 103    D 復盛
# 184    勤益
# 57     華泰
# Name: 簡稱, dtype: object
# 64    -12.1348
# 102    22.4832
# 103    -8.6990
# 184   -51.7345
# 57    -16.4648
# Name: Return, dtype: float64
# 0.8669002
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[47 69]
#  [22 62]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.68      0.41      0.51       116
#            1       0.47      0.74      0.58        84
#
#     accuracy                           0.55       200
#    macro avg       0.58      0.57      0.54       200
# weighted avg       0.59      0.55      0.54       200
#
# 新數據的預測準確率: 0.545
# 1.3727964808396946
# 最近鄰居中預測值為1的前5筆索引:
# [110, 142, 54, 24, 63]
# 110    佳格
# 142    華電
# 54     長億
# 24     中華
# 63     神達
# Name: 簡稱, dtype: object
# 110    -6.4982
# 142   -57.4022
# 54    -44.5789
# 24      7.0642
# 63     41.4634
# Name: Return, dtype: float64
# 0.8800966
# 2004
# Number of rows in test_data: 200
# confusion_matrix:
# [[58 72]
#  [41 29]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.45      0.51       130
#            1       0.29      0.41      0.34        70
#
#     accuracy                           0.43       200
#    macro avg       0.44      0.43      0.42       200
# weighted avg       0.48      0.43      0.45       200
#
# 新數據的預測準確率: 0.435
# 1.0909643821782178
# 最近鄰居中預測值為1的前5筆索引:
# [33, 147, 86, 24, 90]
# 33      統一超
# 147     所羅門
# 86     台橡
# 24     中華
# 90      嘉食化
# Name: 簡稱, dtype: object
# 33     24.9683
# 147   -36.7034
# 86    -30.8219
# 24      7.0642
# 90    -13.4908
# Name: Return, dtype: float64
# 0.9020328
# 2005
# Number of rows in test_data: 200
# confusion_matrix:
# [[58 54]
#  [41 47]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.52      0.55       112
#            1       0.47      0.53      0.50        88
#
#     accuracy                           0.53       200
#    macro avg       0.53      0.53      0.52       200
# weighted avg       0.53      0.53      0.53       200
#
# 新數據的預測準確率: 0.525
# 1.2758620566336634
# 最近鄰居中預測值為1的前5筆索引:
# [102, 6, 110, 54, 23]
# 102    中鼎
# 6       日月光
# 110    佳格
# 54     長億
# 23     國建
# Name: 簡稱, dtype: object
# 102    22.4832
# 6     -17.5732
# 110    -6.4982
# 54    -44.5789
# 23    -41.5319
# Name: Return, dtype: float64
# 0.8246020000000001
# 2006
# Number of rows in test_data: 200
# confusion_matrix:
# [[69 46]
#  [53 32]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.57      0.60      0.58       115
#            1       0.41      0.38      0.39        85
#
#     accuracy                           0.51       200
#    macro avg       0.49      0.49      0.49       200
# weighted avg       0.50      0.51      0.50       200
#
# 新數據的預測準確率: 0.505
# 1.0896707371794871
# 最近鄰居中預測值為1的前5筆索引:
# [39, 173, 14, 143, 152]
# 39      佳世達
# 173    優美
# 14     裕隆
# 143    基泰
# 152    亞聚
# Name: 簡稱, dtype: object
# 39     -8.9455
# 173   -48.2066
# 14      1.1003
# 143   -39.0995
# 152   -16.2685
# Name: Return, dtype: float64
# 0.7771604
# 2007
# Number of rows in test_data: 200
# confusion_matrix:
# [[79 33]
#  [59 29]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.57      0.71      0.63       112
#            1       0.47      0.33      0.39        88
#
#     accuracy                           0.54       200
#    macro avg       0.52      0.52      0.51       200
# weighted avg       0.53      0.54      0.52       200
#
# 新數據的預測準確率: 0.54
# 0.48124461290322573
# 最近鄰居中預測值為1的前5筆索引:
# [131, 101, 12, 147, 183]
# 131    寶建
# 101    和成
# 12      英業達
# 147     所羅門
# 183    民興
# Name: 簡稱, dtype: object
# 131   -18.7251
# 101   -48.3639
# 12     42.6763
# 147   -36.7034
# 183    -8.2347
# Name: Return, dtype: float64
# 0.8612984
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[43 74]
#  [24 59]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.64      0.37      0.47       117
#            1       0.44      0.71      0.55        83
#
#     accuracy                           0.51       200
#    macro avg       0.54      0.54      0.51       200
# weighted avg       0.56      0.51      0.50       200
#
# 新數據的預測準確率: 0.51
# 2.1417351879699247
# 最近鄰居中預測值為1的前5筆索引:
# [4, 133, 167, 136, 178]
# 4      華碩
# 133    台紙
# 167    佳和
# 136    中紡
# 178    益航
# Name: 簡稱, dtype: object
# 4      46.2737
# 133   -40.7609
# 167     6.2537
# 136   -33.6004
# 178   -49.2928
# Name: Return, dtype: float64
# 0.8577466
# {1998: 1.1347986019417475, 1999: 0.5862180714285714, 2000: 1.3283256666666667, 2001: 1.052709705, 2002: 1.3727964808396946, 2004: 1.0909643821782178, 2005: 1.2758620566336634, 2006: 1.0896707371794871, 2007: 0.48124461290322573, 2008: 2.1417351879699247}
# 年均化複利為:0.19963587056507856
#
#
# {1998: 0.9283232, 1999: 1.0189552, 2000: 1.1358796, 2001: 0.8669002, 2002: 0.8800966, 2004: 0.9020328, 2005: 0.8246020000000001, 2006: 0.7771604, 2007: 0.8612984, 2008: 0.8577466}
# 年均化複利為:0.03500870633817423
# ori sum2:0.35008706338174234
# test years have:10
# after sum2:0.03500870633817423
# Optimal k value for minimum error rate: 61
# 1998
# Number of rows in test_data: 200
# confusion_matrix:
# [[57 69]
#  [30 44]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.66      0.45      0.54       126
#            1       0.39      0.59      0.47        74
#
#     accuracy                           0.51       200
#    macro avg       0.52      0.52      0.50       200
# weighted avg       0.56      0.51      0.51       200
#
# 新數據的預測準確率: 0.505
# 1.1707303805309734
# 最近鄰居中預測值為1的前5筆索引:
# [52, 23, 151, 57, 28]
# 52     錸德
# 23     國建
# 151    碧悠
# 57     華泰
# 28     東元
# Name: 簡稱, dtype: object
# 52     48.4848
# 23    -41.5319
# 151    37.9771
# 57    -16.4648
# 28    -25.7937
# Name: Return, dtype: float64
# 1.005343
# 1999
# Number of rows in test_data: 200
# confusion_matrix:
# [[75 36]
#  [25 64]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.75      0.68      0.71       111
#            1       0.64      0.72      0.68        89
#
#     accuracy                           0.69       200
#    macro avg       0.70      0.70      0.69       200
# weighted avg       0.70      0.69      0.70       200
#
# 新數據的預測準確率: 0.695
# 0.66133834
# 最近鄰居中預測值為1的前5筆索引:
# [14, 79, 17, 184, 121]
# 14     裕隆
# 79     旭麗
# 17     太電
# 184    勤益
# 121    台火
# Name: 簡稱, dtype: object
# 14      1.1003
# 79     14.0625
# 17    -31.3760
# 184   -51.7345
# 121   -39.6430
# Name: Return, dtype: float64
# 0.7848186
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[31 96]
#  [19 54]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.62      0.24      0.35       127
#            1       0.36      0.74      0.48        73
#
#     accuracy                           0.42       200
#    macro avg       0.49      0.49      0.42       200
# weighted avg       0.53      0.42      0.40       200
#
# 新數據的預測準確率: 0.425
# 1.31369472
# 最近鄰居中預測值為1的前5筆索引:
# [130, 4, 12, 18, 119]
# 130    三采
# 4      華碩
# 12      英業達
# 18     長榮
# 119    矽統
# Name: 簡稱, dtype: object
# 130   -76.5830
# 4      46.2737
# 12     42.6763
# 18    -16.8475
# 119    90.8365
# Name: Return, dtype: float64
# 1.172712
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[71 47]
#  [21 61]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.77      0.60      0.68       118
#            1       0.56      0.74      0.64        82
#
#     accuracy                           0.66       200
#    macro avg       0.67      0.67      0.66       200
# weighted avg       0.69      0.66      0.66       200
#
# 新數據的預測準確率: 0.66
# 1.0743127777777777
# 最近鄰居中預測值為1的前5筆索引:
# [69, 76, 184, 57, 59]
# 69      永豐餘
# 76     飛瑞
# 184    勤益
# 57     華泰
# 59     光罩
# Name: 簡稱, dtype: object
# 69    -27.8824
# 76      6.8826
# 184   -51.7345
# 57    -16.4648
# 59    -51.6712
# Name: Return, dtype: float64
# 0.7182594
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[42 74]
#  [26 58]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.62      0.36      0.46       116
#            1       0.44      0.69      0.54        84
#
#     accuracy                           0.50       200
#    macro avg       0.53      0.53      0.50       200
# weighted avg       0.54      0.50      0.49       200
#
# 新數據的預測準確率: 0.5
# 1.336935592348485
# 最近鄰居中預測值為1的前5筆索引:
# [66, 34, 12, 174, 79]
# 66     大榮
# 34     中環
# 12      英業達
# 174    榮櫃
# 79     旭麗
# Name: 簡稱, dtype: object
# 66    -38.3127
# 34     25.1898
# 12     42.6763
# 174    -6.9927
# 79     14.0625
# Name: Return, dtype: float64
# 1.0732464
# 2004
# Number of rows in test_data: 200
# confusion_matrix:
# [[36 94]
#  [25 45]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.28      0.38       130
#            1       0.32      0.64      0.43        70
#
#     accuracy                           0.41       200
#    macro avg       0.46      0.46      0.40       200
# weighted avg       0.50      0.41      0.40       200
#
# 新數據的預測準確率: 0.405
# 1.1240084899280576
# 最近鄰居中預測值為1的前5筆索引:
# [128, 130, 79, 184, 124]
# 128    東森
# 130    三采
# 79     旭麗
# 184    勤益
# 124    力麗
# Name: 簡稱, dtype: object
# 128   -35.0135
# 130   -76.5830
# 79     14.0625
# 184   -51.7345
# 124   -38.5344
# Name: Return, dtype: float64
# 0.6243942
# 2005
# Number of rows in test_data: 200
# confusion_matrix:
# [[57 55]
#  [26 62]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.69      0.51      0.58       112
#            1       0.53      0.70      0.60        88
#
#     accuracy                           0.59       200
#    macro avg       0.61      0.61      0.59       200
# weighted avg       0.62      0.59      0.59       200
#
# 新數據的預測準確率: 0.595
# 1.3702525914529913
# 最近鄰居中預測值為1的前5筆索引:
# [129, 17, 178, 118, 86]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 201
#     199 print("最近鄰居中預測值為1的前5筆索引:")
#     200 print(selected_indices_list)
# --> 201 select = pd.read_excel(csv_file_path)
#     202 # 獲取股票名稱
#     203 selects_stock = select.iloc[selected_indices_list]['簡稱']
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
#     509     )
#     510 elif engine and engine != io.engine:
#     511     raise ValueError(
#     512         "Engine should not be specified when passing "
#     513         "an ExcelFile - ExcelFile already has the engine set"
#     514     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1580, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1577 self.engine = engine
#    1578 self.storage_options = storage_options
# -> 1580 self._reader = self._engines[engine](
#    1581     self._io,
#    1582     storage_options=storage_options,
#    1583     engine_kwargs=engine_kwargs,
#    1584 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_xlrd.py:45, in XlrdReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#      43 err_msg = "Install xlrd >= 2.0.1 for xls Excel support"
#      44 import_optional_dependency("xlrd", extra=err_msg)
# ---> 45 super().__init__(
#      46     filepath_or_buffer,
#      47     storage_options=storage_options,
#      48     engine_kwargs=engine_kwargs,
#      49 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:582, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     580 self.handles.handle.seek(0)
#     581 try:
# --> 582     self.book = self.load_workbook(self.handles.handle, engine_kwargs)
#     583 except Exception:
#     584     self.close()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_xlrd.py:62, in XlrdReader.load_workbook(self, filepath_or_buffer, engine_kwargs)
#      60 if hasattr(filepath_or_buffer, "read"):
#      61     data = filepath_or_buffer.read()
# ---> 62     return open_workbook(file_contents=data, **engine_kwargs)
#      63 else:
#      64     return open_workbook(filepath_or_buffer, **engine_kwargs)
#
# File ~\anaconda3\Lib\site-packages\xlrd\__init__.py:172, in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows, ignore_workbook_corruption)
#     169 if file_format and file_format != 'xls':
#     170     raise XLRDError(FILE_FORMAT_DESCRIPTIONS[file_format]+'; not supported')
# --> 172 bk = open_workbook_xls(
#     173     filename=filename,
#     174     logfile=logfile,
#     175     verbosity=verbosity,
#     176     use_mmap=use_mmap,
#     177     file_contents=file_contents,
#     178     encoding_override=encoding_override,
#     179     formatting_info=formatting_info,
#     180     on_demand=on_demand,
#     181     ragged_rows=ragged_rows,
#     182     ignore_workbook_corruption=ignore_workbook_corruption,
#     183 )
#     185 return bk
#
# File ~\anaconda3\Lib\site-packages\xlrd\book.py:107, in open_workbook_xls(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows, ignore_workbook_corruption)
#     105     bk._sheet_list = [None for sh in bk._sheet_names]
#     106     if not on_demand:
# --> 107         bk.get_sheets()
#     108 bk.nsheets = len(bk._sheet_list)
#     109 if biff_version == 45 and bk.nsheets > 1:
#
# File ~\anaconda3\Lib\site-packages\xlrd\book.py:722, in Book.get_sheets(self)
#     720 for sheetno in xrange(len(self._sheet_names)):
#     721     if DEBUG: print("GET_SHEETS: sheetno =", sheetno, self._sheet_names, self._sh_abs_posn, file=self.logfile)
# --> 722     self.get_sheet(sheetno)
#
# File ~\anaconda3\Lib\site-packages\xlrd\book.py:713, in Book.get_sheet(self, sh_number, update_pos)
#     702 # assert biff_version == self.biff_version ### FAILS
#     703 # Have an example where book is v7 but sheet reports v8!!!
#     704 # It appears to work OK if the sheet version is ignored.
#     705 # Confirmed by Daniel Rentz: happens when Excel does "save as"
#     706 # creating an old version file; ignore version details on sheet BOF.
#     707 sh = sheet.Sheet(
#     708     self,
#     709     self._position,
#     710     self._sheet_names[sh_number],
#     711     sh_number,
#     712 )
# --> 713 sh.read(self)
#     714 self._sheet_list[sh_number] = sh
#     715 return sh
#
# File ~\anaconda3\Lib\site-packages\xlrd\sheet.py:811, in Sheet.read(self, bk)
#     809 txos = {}
#     810 eof_found = 0
# --> 811 while 1:
#     812     # if DEBUG: print "SHEET.READ: about to read from position %d" % bk._position
#     813     rc, data_len, data = bk_get_record_parts()
#     814     # if rc in rc_stats:
#     815     #     rc_stats[rc] += 1
#     816     # else:
#     817     #     rc_stats[rc] = 1
#     818     # if DEBUG: print "SHEET.READ: op 0x%04x, %d bytes %r" % (rc, data_len, data)
#
# KeyboardInterrupt:
