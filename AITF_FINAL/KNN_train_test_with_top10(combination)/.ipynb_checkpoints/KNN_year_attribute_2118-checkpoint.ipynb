# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

csv_file_path='top200_training.xls'
#記得pip install xlrd
df = pd.read_excel(csv_file_path)
#df.head()

# %%
from itertools import product
from itertools import combinations


# 將年月轉換為日期型數據
df['年月'] = pd.to_datetime(df['年月'], format='%Y%m')

# 獲取所有不同的年份
all_years = ['1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008']

# 開始的欄位
start_column = '1997'

# 開始欄位的索引
start_index = all_years.index(start_column)

# 創建一個字典來保存結果
year_combinations_dict = {}

# 生成所有可能的欄位組合
for i in range(1, len(all_years) - start_index + 1):
    for subset in combinations(all_years[start_index:], i):
        selected_columns = list(subset)
        # 將結果存入字典
        year_combinations_dict[len(year_combinations_dict) + 1] = selected_columns

# 打開一個檔案來保存結果
with open('year_combinations.txt', 'w') as file:
    # 遍歷字典，將結果寫入檔案
    for key, value in year_combinations_dict.items():
        file.write(f"Key: {key}, Selected year: {value}\n")
        # 在這裡進行你的分析或模型擬合等操作
        # ...
        file.write("\n" + "="*40 + "\n")

# 提示保存成功
print("Results saved to 'year_combinations.txt'")
# Out:
# Results saved to 'year_combinations.txt'

# %%
from itertools import combinations
from sklearn.model_selection import train_test_split
import json
columns_comb1=['股價淨值比', '股價營收比', 'M營業利益成長率', 'M稅後淨利成長率']
columns_comb2=['股價淨值比', 'M淨值報酬率─稅後', '資產報酬率ROA', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M稅後淨利成長率']
columns_comb3=['股價淨值比', '利潤邊際NPM', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M營業利益成長率', 'M稅後淨利成長率']
columns_comb4=['股價營收比', '營業利益率OPM', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M營業利益成長率', 'M稅後淨利成長率']
columns_comb5=['本益比', '股價淨值比', '股價營收比', 'M淨值報酬率─稅後', '資產報酬率ROA', 'M存貨週轉率 (次)', 'M營業利益成長率']
columns_comb6=['股價淨值比', '股價營收比', 'M淨值報酬率─稅後', '資產報酬率ROA', 'M流動比率', 'M速動比率', 'M應收帳款週轉次']
columns_comb7=['本益比', '股價淨值比', '股價營收比', '資產報酬率ROA', '營業利益率OPM', '利潤邊際NPM', 'M流動比率', 'M應收帳款週轉次', 'M營業利益成長率']
columns_comb8=['本益比', '股價淨值比', '股價營收比', 'M淨值報酬率─稅後', '資產報酬率ROA', '利潤邊際NPM', '負債/淨值比', 'M流動比率', 'M速動比率', 'M營業利益成長率', 'M稅後淨利成長率']
columns_comb9=['股價營收比', '營業利益率OPM', '負債/淨值比', 'M速動比率', 'M存貨週轉率 (次)', 'M營業利益成長率', 'M稅後淨利成長率']
columns_comb10=['本益比', '股價淨值比', '股價營收比', '營業利益率OPM', '利潤邊際NPM', 'M流動比率', 'M速動比率', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M營業利益成長率', 'M稅後淨利成長率']
column_combinations_dict = {}
columns_combinations = [columns_comb1, columns_comb2, columns_comb3, columns_comb4, columns_comb5, columns_comb6, columns_comb7, columns_comb8, columns_comb9, columns_comb10]

for i, columns_comb in enumerate(columns_combinations, start=1):
    column_combinations_dict[i] = columns_comb
print(column_combinations_dict)
# 將字典保存到.txt文件
file_path = 'column_combinations_KNN_train.txt'

with open(file_path, 'w', encoding='utf-8') as file:
    json.dump(column_combinations_dict, file, ensure_ascii=False)
print('Results saved to column_combinations_KNN_train.txt')
# Out:
# {1: ['股價淨值比', '股價營收比', 'M營業利益成長率', 'M稅後淨利成長率'], 2: ['股價淨值比', 'M淨值報酬率─稅後', '資產報酬率ROA', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M稅後淨利成長率'], 3: ['股價淨值比', '利潤邊際NPM', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M營業利益成長率', 'M稅後淨利成長率'], 4: ['股價營收比', '營業利益率OPM', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M營業利益成長率', 'M稅後淨利成長率'], 5: ['本益比', '股價淨值比', '股價營收比', 'M淨值報酬率─稅後', '資產報酬率ROA', 'M存貨週轉率 (次)', 'M營業利益成長率'], 6: ['股價淨值比', '股價營收比', 'M淨值報酬率─稅後', '資產報酬率ROA', 'M流動比率', 'M速動比率', 'M應收帳款週轉次'], 7: ['本益比', '股價淨值比', '股價營收比', '資產報酬率ROA', '營業利益率OPM', '利潤邊際NPM', 'M流動比率', 'M應收帳款週轉次', 'M營業利益成長率'], 8: ['本益比', '股價淨值比', '股價營收比', 'M淨值報酬率─稅後', '資產報酬率ROA', '利潤邊際NPM', '負債/淨值比', 'M流動比率', 'M速動比率', 'M營業利益成長率', 'M稅後淨利成長率'], 9: ['股價營收比', '營業利益率OPM', '負債/淨值比', 'M速動比率', 'M存貨週轉率 (次)', 'M營業利益成長率', 'M稅後淨利成長率'], 10: ['本益比', '股價淨值比', '股價營收比', '營業利益率OPM', '利潤邊際NPM', 'M流動比率', 'M速動比率', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M營業利益成長率', 'M稅後淨利成長率']}
# Results saved to column_combinations_KNN_train.txt

# %%
max_ret=0
ans={}
list_ans=[]
#選擇特定欄位分析
from sklearn.preprocessing import StandardScaler
from itertools import islice

start_index = 3000  # 第36筆資料的索引
end_index = 4093  # 最後一筆資料的索引

selected_range = islice(year_combinations_dict.items(), start_index, end_index + 1)

#selected_range = islice(year_combinations_dict.items(), 4094) #4094是所有可用來訓練的年份組合
cols=0
#16384
with open('KNN_train_test_result.txt', 'a') as file:
    for key, selected_years in selected_range:
        
        # 選擇訓練集年分
        train_years = [int(year) for year in selected_years]
        #print(train_years)

        #print("---------------------")
        # 選擇測試集年分
        test_years = [int(year) for year in all_years if year not in selected_years]
        print(f'總共有test year:{len(test_years)}')
        
        # 根據年份選擇訓練集
        train_data = df[df['年月'].dt.year.isin(train_years)]
        print(f"Number of rows in train_data: {len(train_data)}")
        #print(train_data)
        
        # 排除指定列，並標準化
        #columns_to_exclude = ['簡稱', '證券代碼', '年月', 'ReturnMean_year_Label', 'Return']
        #features_to_scale_train = train_data.drop(columns=columns_to_exclude)
        #features_to_scale_test = test_data.drop(columns=columns_to_exclude)
    
        for col in range (1,11):#取top10組合
            cols=cols+1
            list_ans=[]
            # 指定要選擇的欄位
            selected_columns = column_combinations_dict[col]
            list_ans.append(selected_columns)
            
            # 選擇指定的欄位
            features_to_scale_train = train_data[selected_columns]

            scaler = StandardScaler()
            scaled_features_train = scaler.fit_transform(features_to_scale_train)
            
            # 轉換為dataframe
            df_feat_train = pd.DataFrame(scaled_features_train, columns=features_to_scale_train.columns)
            
        #---------------------------------------------------------------------------------------------
            # 分割訓練集和測試集
            X_train = df_feat_train
            y_train = train_data['ReturnMean_year_Label']
            
            X_train, X_test, y_train, y_test = train_test_split(X_train,y_train,test_size=0.3,random_state=101)
  
        #--------------------------------------------------------------------------------------------------
            error_rate = []
            from sklearn.neighbors import KNeighborsClassifier
            for i in range(1, 100):
                knn = KNeighborsClassifier(n_neighbors=i, p=2, weights='distance', algorithm='brute')
                knn.fit(X_train, y_train)
                pred_i = knn.predict(X_test)
                error_rate.append(np.mean(pred_i != y_test))

            # 將k=1~60的錯誤率製圖畫出。k=23之後，錯誤率就在5-6%之間震盪。
            #plt.figure(figsize=(10, 6))
            #plt.plot(range(1, 100), error_rate, color='blue', linestyle='dashed', marker='o', markerfacecolor='red', markersize=10)
            #plt.title('Error Rate vs. K Value')
            #plt.xlabel('K')
            #plt.ylabel('Error Rate')
            #plt.show()
        #--------------------------------------------------------------------------------------------------
            min_error = min(error_rate)
            optimal_k = error_rate.index(min_error) + 1  # Adding 1 because Python indexing starts from 0

            print(f"Optimal k value for minimum error rate: {optimal_k}")
            #print(f"Minimum Error Rate: {min_error}")
            list_ans.append(optimal_k)
        #--------------------------------------------------------------------------------------------------
            #使用KNN演算法
            clf=KNeighborsClassifier(n_neighbors=optimal_k,p=2,weights='distance',algorithm='brute')
            clf.fit(X_train,y_train)
        #--------------------------------------------------------------------------------------------------
            predict_label1={}
            predict_k_pre5={}
        #--------------------------------------------------------------------------------------------------

            for year in test_years:
                
                # 選擇特定年份的 test_data
                test_data = df[df['年月'].dt.year == year]
                print(year)
                #print(test_data)
                print(f"Number of rows in test_data: {len(test_data)}")
                
                # 選擇指定的欄位
                features_to_scale_test = test_data[selected_columns]
                # 使用之前訓練好的標準化物件進行標準化
                scaled_features_test = scaler.transform(features_to_scale_test)
                # 將標準化後的特徵資料轉換為 DataFrame
                df_feat_test = pd.DataFrame(scaled_features_test, columns=features_to_scale_test.columns)

                
                # 使用已經訓練好的模型進行預測
                predictions_new = clf.predict(df_feat_test)

                #------------------------------
                #測試KNN演算法的好壞
                from sklearn.metrics import classification_report,confusion_matrix
                #將實際類別分為真正例（True Positive）、真負例（True Negative）、偽正例（False Positive）和偽負例（False Negative）
                print('confusion_matrix:')
                print(confusion_matrix(test_data['ReturnMean_year_Label'],predictions_new))

                #模型的精確度、召回率、F1分數和支持數等指標，用來評估模型對於每個類別的預測性能。
                print('classification_report')
                print(classification_report(test_data['ReturnMean_year_Label'],predictions_new))

                # 比較預測結果
                accuracy_new = clf.score(df_feat_test, test_data['ReturnMean_year_Label'])
                print(f'新數據的預測準確率: {accuracy_new}')
                #---------------------------------------
                #print(predictions_new)

                #predicted_positive_indices = (predictions_new == 1)

                # 獲取股票名稱
                #predicted_positive_stock_names = new.loc[predicted_positive_indices, '簡稱']

                # 設定檔案名稱
                #output_file_name = 'selected_stocks_1998.csv'

                # 匯出成 CSV 檔案
                #predicted_positive_stock_names.to_csv(output_file_name, index=True)

                # 預測要投資的股票名稱
                #print("選擇股票:")
                #print(predicted_positive_stock_names)


                # 選擇預測為1的股票
                selected_stocks = test_data[predictions_new == 1]

                # 計算return
                stock_returns = selected_stocks['Return']

                portfolio_returns = (stock_returns.mean()/100)+1

                print(portfolio_returns)
                predict_label1[year]=portfolio_returns

                # 使用 kneighbors 方法取得最近鄰居的索引和距離
                distances, indices = clf.kneighbors(df_feat_test, n_neighbors=5)

                # 合併所有測試樣本的最近鄰居索引
                all_indices = np.concatenate(indices)
                all_distances = np.concatenate(distances)

                # 將索引和距離組合成一個 2D 陣列，方便排序
                combined_data = np.column_stack((all_indices, all_distances))

                # 按照距離重新排序
                sorted_combined_data = combined_data[np.argsort(combined_data[:, 1])]

                # 選取最近鄰居中預測值為1的前5筆，且不重複
                selected_indices = set()
                i = 0
                while len(selected_indices) < 5 and i < len(sorted_combined_data):
                    index = int(sorted_combined_data[i, 0])
                    if(index>=200 and index<400):
                        index=index-200
                    elif(index>=400 and index<600):
                        index=index-400
                    elif(index>=600 and index<800):
                        index=index-600
                    elif(index>=800 and index<1000):
                        index=index-800
                    elif(index>=1000 and index<1200):
                        index=index-1000
                    elif(index>=1200 and index<1400):
                        index=index-1200
                    elif(index>=1400 and index<1600):
                        index=index-1400
                    elif(index>=1600 and index<1800):
                        index=index-1600
                    elif(index>=1800 and index<2000):
                        index=index-1800
                    elif(index>=2000 and index<2200):
                        index=index-2000
                    elif(index>=2200 and index<2400):
                        index=index-2200
                    elif(index>=2400 and index<2600):
                        index=index-2400
                    elif(index>=2600 and index<2800):
                        index=index-2600
                    elif(index>=2800 and index<3000):
                        index=index-2800
                    elif(index>=3000 and index<3200):
                        index=index-3000
                    prediction = predictions_new[index]
                    if prediction == 1 and index not in selected_indices:
                        selected_indices.add(index)
                    i += 1
                        

                # 將選取的索引轉換成列表
                selected_indices_list = list(selected_indices)

                # 打印最近鄰居中預測值為1的前5筆索引
                print("最近鄰居中預測值為1的前5筆索引:")
                print(selected_indices_list)
                select = test_data
                # 獲取股票名稱
                selects_stock = select.iloc[selected_indices_list]['簡稱']
                print(selects_stock)
                # 獲取股票return
                selects_ret = select.iloc[selected_indices_list]['Return']
                print(selects_ret)
                with open(f'selected_stock_KNN_train/{cols}.txt', 'a') as stockfile:
                    stockfile.write(selects_stock.to_string())
                    stockfile.write('\n')
                    stockfile.write(selects_ret.to_string())
                # 計算return
                stock_returns = (selects_ret.mean() / 100)+1
                portfolio_returns = stock_returns
                print(portfolio_returns)
                predict_k_pre5[year] = portfolio_returns
                #print(stock_returns)
            sum1=1
            sum2=1
            print(predict_label1)
            for k in predict_label1.keys():
                if not (predict_label1[k]==0):
                    sum1=predict_label1[k]*sum1
            print(f'年均化複利為:{sum1/int(len(test_years))}')
            print('\n')
            print(predict_k_pre5)
            for k in predict_k_pre5.keys():
                if not (predict_k_pre5[k]==0):
                    sum2=predict_k_pre5[k]*sum2
            print(f'年均化複利為:{sum2/int(len(test_years))}')
            #list_ans.append(sum2/len(test_data)/200)
            print(f'ori sum2:{sum2}')
            print(f'test years have:{int(len(test_years))}')
            sum2=sum2/int(len(test_years))
            print(f'after sum2:{sum2}')
            list_ans.append(sum2)
            ans[cols]=list_ans
            file.write(f'{cols}:{list_ans}\n\n')
            file.flush()  # 強制將緩衝區內容寫入檔案
            if(sum2>max_ret):
                max_ret=sum2
                with open('max_KNN_train.txt', 'w') as maxfile:
                    maxfile.write(f'max:train_year:{train_years},test_year:{test_years}:{cols}:{list_ans}\n\n')
                    maxfile.flush()  # 強制將緩衝區內容寫入檔案
# Out:
# 總共有test year:11
# Number of rows in train_data: 200
# Optimal k value for minimum error rate: 41
# 1998
# Number of rows in test_data: 200
# confusion_matrix:
# [[71 55]
#  [38 36]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.65      0.56      0.60       126
#            1       0.40      0.49      0.44        74
#
#     accuracy                           0.54       200
#    macro avg       0.52      0.52      0.52       200
# weighted avg       0.56      0.54      0.54       200
#
# 新數據的預測準確率: 0.535
# 1.11534
# 最近鄰居中預測值為1的前5筆索引:
# [109, 46, 117, 24, 126]
# 309    聯華
# 246     中石化
# 317    東陽
# 224    寶成
# 326    德寶
# Name: 簡稱, dtype: object
# 309   -19.8123
# 246   -13.4566
# 317   -24.1624
# 224    25.5390
# 326   -45.1830
# Name: Return, dtype: float64
# 0.8458494
# 1999
# Number of rows in test_data: 200
# confusion_matrix:
# [[72 39]
#  [42 47]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.63      0.65      0.64       111
#            1       0.55      0.53      0.54        89
#
#     accuracy                           0.59       200
#    macro avg       0.59      0.59      0.59       200
# weighted avg       0.59      0.59      0.59       200
#
# 新數據的預測準確率: 0.595
# 0.6141104186046512
# 最近鄰居中預測值為1的前5筆索引:
# [103, 109, 49, 60, 125]
# 503    鴻準
# 509    世平
# 449    萬海
# 460    精碟
# 525    豐泰
# Name: 簡稱, dtype: object
# 503   -73.3545
# 509   -40.9449
# 449    -4.4390
# 460   -37.6890
# 525   -36.8932
# Name: Return, dtype: float64
# 0.6133588000000001
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[50 77]
#  [20 53]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.71      0.39      0.51       127
#            1       0.41      0.73      0.52        73
#
#     accuracy                           0.52       200
#    macro avg       0.56      0.56      0.51       200
# weighted avg       0.60      0.52      0.51       200
#
# 新數據的預測準確率: 0.515
# 1.379558623076923
# 最近鄰居中預測值為1的前5筆索引:
# [8, 46, 112, 125, 31]
# 608    廣達
# 646    聯強
# 712     華新科
# 725    南紡
# 631    台泥
# Name: 簡稱, dtype: object
# 608    75.0099
# 646    26.9263
# 712    87.1128
# 725    -5.2805
# 631   -42.4508
# Name: Return, dtype: float64
# 1.2826354
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[83 35]
#  [23 59]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.78      0.70      0.74       118
#            1       0.63      0.72      0.67        82
#
#     accuracy                           0.71       200
#    macro avg       0.71      0.71      0.71       200
# weighted avg       0.72      0.71      0.71       200
#
# 新數據的預測準確率: 0.71
# 1.1157145170212766
# 最近鄰居中預測值為1的前5筆索引:
# [8, 46, 88, 125, 31]
# 808    台塑
# 846    中華
# 888    瑞軒
# 925    士電
# 831    技嘉
# Name: 簡稱, dtype: object
# 808     54.4404
# 846    191.9494
# 888    -16.4050
# 925      7.3290
# 831    -45.7149
# Name: Return, dtype: float64
# 1.3831978
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[47 69]
#  [31 53]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.60      0.41      0.48       116
#            1       0.43      0.63      0.51        84
#
#     accuracy                           0.50       200
#    macro avg       0.52      0.52      0.50       200
# weighted avg       0.53      0.50      0.50       200
#
# 新數據的預測準確率: 0.5
# 1.334907095819672
# 最近鄰居中預測值為1的前5筆索引:
# [133, 7, 19, 90, 60]
# 1133    遠雄
# 1007    台化
# 1019     佳世達
# 1090    億豐
# 1060    陽明
# Name: 簡稱, dtype: object
# 1133     30.7607
# 1007     74.1454
# 1019     33.1299
# 1090     14.5258
# 1060    168.4874
# Name: Return, dtype: float64
# 1.6420984
# 2003
# Number of rows in test_data: 200
# confusion_matrix:
# [[56 42]
#  [41 61]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.57      0.57        98
#            1       0.59      0.60      0.60       102
#
#     accuracy                           0.58       200
#    macro avg       0.58      0.58      0.58       200
# weighted avg       0.58      0.58      0.58       200
#
# 新數據的預測準確率: 0.585
# 1.0772141650485436
# 最近鄰居中預測值為1的前5筆索引:
# [133, 76, 109, 60, 31]
# 1333    瑞軒
# 1276    福懋
# 1309    正崴
# 1260    台玻
# 1231     遠東新
# Name: 簡稱, dtype: object
# 1333   -37.3156
# 1276    21.4932
# 1309    16.2290
# 1260    27.9754
# 1231    67.9134
# Name: Return, dtype: float64
# 1.1925908
# 2004
# Number of rows in test_data: 200
# confusion_matrix:
# [[59 71]
#  [32 38]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.65      0.45      0.53       130
#            1       0.35      0.54      0.42        70
#
#     accuracy                           0.48       200
#    macro avg       0.50      0.50      0.48       200
# weighted avg       0.54      0.48      0.50       200
#
# 新數據的預測準確率: 0.485
# 1.1316295733944954
# 最近鄰居中預測值為1的前5筆索引:
# [66, 6, 109, 20, 123]
# 1466    福懋
# 1406    南亞
# 1509     統一實
# 1420     遠東新
# 1523     中石化
# Name: 簡稱, dtype: object
# 1466     9.6834
# 1406     6.9848
# 1509   -22.5850
# 1420    -2.7550
# 1523     9.3660
# Name: Return, dtype: float64
# 1.0013884
# 2005
# Number of rows in test_data: 200
# confusion_matrix:
# [[70 42]
#  [41 47]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.63      0.62      0.63       112
#            1       0.53      0.53      0.53        88
#
#     accuracy                           0.58       200
#    macro avg       0.58      0.58      0.58       200
# weighted avg       0.59      0.58      0.59       200
#
# 新數據的預測準確率: 0.585
# 1.3636826103370785
# 最近鄰居中預測值為1的前5筆索引:
# [8, 74, 60, 93, 127]
# 1608    中鋼
# 1674    福懋
# 1660    華新
# 1693    東元
# 1727    榮化
# Name: 簡稱, dtype: object
# 1608    64.0869
# 1674    61.0357
# 1660    58.2150
# 1693    84.4712
# 1727    60.3425
# Name: Return, dtype: float64
# 1.6563026
# 2006
# Number of rows in test_data: 200
# confusion_matrix:
# [[74 41]
#  [52 33]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.64      0.61       115
#            1       0.45      0.39      0.42        85
#
#     accuracy                           0.54       200
#    macro avg       0.52      0.52      0.51       200
# weighted avg       0.53      0.54      0.53       200
#
# 新數據的預測準確率: 0.535
# 1.1568743662162162
# 最近鄰居中預測值為1的前5筆索引:
# [45, 46, 47, 49, 30]
# 1845    華映
# 1846    華航
# 1847    裕隆
# 1849    華寶
# 1830    統一
# Name: 簡稱, dtype: object
# 1845    60.69800
# 1846    -0.42959
# 1847   -18.37970
# 1849   -11.72530
# 1830    45.82790
# Name: Return, dtype: float64
# 1.15198262
# 2007
# Number of rows in test_data: 200
# confusion_matrix:
# [[86 26]
#  [53 35]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.62      0.77      0.69       112
#            1       0.57      0.40      0.47        88
#
#     accuracy                           0.60       200
#    macro avg       0.60      0.58      0.58       200
# weighted avg       0.60      0.60      0.59       200
#
# 新數據的預測準確率: 0.605
# 0.5469464672131148
# 最近鄰居中預測值為1的前5筆索引:
# [117, 24, 92, 126, 95]
# 2117    亞光
# 2024    宏碁
# 2092     中光電
# 2126     中石化
# 2095    正崴
# Name: 簡稱, dtype: object
# 2117   -53.3168
# 2024   -26.7681
# 2092   -55.1960
# 2126   -47.2881
# 2095   -43.5888
# Name: Return, dtype: float64
# 0.5476844
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[56 61]
#  [27 56]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.67      0.48      0.56       117
#            1       0.48      0.67      0.56        83
#
#     accuracy                           0.56       200
#    macro avg       0.58      0.58      0.56       200
# weighted avg       0.59      0.56      0.56       200
#
# 新數據的預測準確率: 0.56
# 2.1301243675213675
# 最近鄰居中預測值為1的前5筆索引:
# [100, 9, 19, 60, 31]
# 2300    燁輝
# 2209    台化
# 2219     遠東新
# 2260    遠百
# 2231     光寶科
# Name: 簡稱, dtype: object
# 2300     49.1935
# 2209     81.8992
# 2219     98.8072
# 2260    105.2724
# 2231    134.0591
# Name: Return, dtype: float64
# 1.9384628
# {1998: 1.11534, 1999: 0.6141104186046512, 2000: 1.379558623076923, 2001: 1.1157145170212766, 2002: 1.334907095819672, 2003: 1.0772141650485436, 2004: 1.1316295733944954, 2005: 1.3636826103370785, 2006: 1.1568743662162162, 2007: 0.5469464672131148, 2008: 2.1301243675213675}
# 年均化複利為:0.2866559564774944
#
#
# {1998: 0.8458494, 1999: 0.6133588000000001, 2000: 1.2826354, 2001: 1.3831978, 2002: 1.6420984, 2003: 1.1925908, 2004: 1.0013884, 2005: 1.6563026, 2006: 1.15198262, 2007: 0.5476844, 2008: 1.9384628}
# 年均化複利為:0.33240619874937055
# ori sum2:3.6564681862430763
# test years have:11
# after sum2:0.33240619874937055
# Optimal k value for minimum error rate: 19
# 1998
# Number of rows in test_data: 200
# confusion_matrix:
# [[73 53]
#  [39 35]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.65      0.58      0.61       126
#            1       0.40      0.47      0.43        74
#
#     accuracy                           0.54       200
#    macro avg       0.52      0.53      0.52       200
# weighted avg       0.56      0.54      0.55       200
#
# 新數據的預測準確率: 0.54
# 1.144121840909091
# 最近鄰居中預測值為1的前5筆索引:
# [10, 77, 49, 24, 126]
# 210    華通
# 277     金像電
# 249    凌陽
# 224    寶成
# 326    德寶
# Name: 簡稱, dtype: object
# 210     5.8307
# 277    -8.0565
# 249    80.2007
# 224    25.5390
# 326   -45.1830
# Name: Return, dtype: float64
# 1.1166618
# 1999
# Number of rows in test_data: 200
# confusion_matrix:
# [[76 35]
#  [39 50]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.66      0.68      0.67       111
#            1       0.59      0.56      0.57        89
#
#     accuracy                           0.63       200
#    macro avg       0.62      0.62      0.62       200
# weighted avg       0.63      0.63      0.63       200
#
# 新數據的預測準確率: 0.63
# 0.6230220352941176
# 最近鄰居中預測值為1的前5筆索引:
# [131, 5, 109, 14, 28]
# 531    和桐
# 405    廣達
# 509    世平
# 414    台化
# 428    精業
# Name: 簡稱, dtype: object
# 531   -38.4132
# 405   -51.2020
# 509   -40.9449
# 414   -23.6226
# 428   -74.0175
# Name: Return, dtype: float64
# 0.5435996000000001
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[66 61]
#  [29 44]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.69      0.52      0.59       127
#            1       0.42      0.60      0.49        73
#
#     accuracy                           0.55       200
#    macro avg       0.56      0.56      0.54       200
# weighted avg       0.59      0.55      0.56       200
#
# 新數據的預測準確率: 0.55
# 1.4420691047619048
# 最近鄰居中預測值為1的前5筆索引:
# [0, 4, 69, 9, 28]
# 600     台積電
# 604    南亞
# 669    和泰
# 609    威盛
# 628    中環
# Name: 簡稱, dtype: object
# 600    59.7499
# 604   -17.4744
# 669   -21.8910
# 609    28.5075
# 628    37.1997
# Name: Return, dtype: float64
# 1.1721834
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[61 57]
#  [50 32]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.55      0.52      0.53       118
#            1       0.36      0.39      0.37        82
#
#     accuracy                           0.47       200
#    macro avg       0.45      0.45      0.45       200
# weighted avg       0.47      0.47      0.47       200
#
# 新數據的預測準確率: 0.465
# 0.9087209775280899
# 最近鄰居中預測值為1的前5筆索引:
# [9, 109, 55, 24, 88]
# 809    威盛
# 909    光罩
# 855    金寶
# 824    凌陽
# 888    瑞軒
# Name: 簡稱, dtype: object
# 809   -66.5162
# 909   -21.8798
# 855   -15.6557
# 824   -22.2344
# 888   -16.4050
# Name: Return, dtype: float64
# 0.7146178
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[53 63]
#  [48 36]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.52      0.46      0.49       116
#            1       0.36      0.43      0.39        84
#
#     accuracy                           0.45       200
#    macro avg       0.44      0.44      0.44       200
# weighted avg       0.46      0.45      0.45       200
#
# 新數據的預測準確率: 0.445
# 1.263905496868687
# 最近鄰居中預測值為1的前5筆索引:
# [8, 41, 74, 22, 26]
# 1008    廣達
# 1041    國電
# 1074    研華
# 1022    遠傳
# 1026    瑞昱
# Name: 簡稱, dtype: object
# 1008    66.9324
# 1041    -6.6639
# 1074    11.5560
# 1022    20.4255
# 1026   -18.7895
# Name: Return, dtype: float64
# 1.146921
# 2003
# Number of rows in test_data: 200
# confusion_matrix:
# [[40 58]
#  [37 65]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.52      0.41      0.46        98
#            1       0.53      0.64      0.58       102
#
#     accuracy                           0.53       200
#    macro avg       0.52      0.52      0.52       200
# weighted avg       0.52      0.53      0.52       200
#
# 新數據的預測準確率: 0.525
# 0.9990621739837399
# 最近鄰居中預測值為1的前5筆索引:
# [5, 135, 22, 28, 61]
# 1205    南亞
# 1335    啟碁
# 1222    中華
# 1228    陽明
# 1261    D 復盛
# Name: 簡稱, dtype: object
# 1205     9.3384
# 1335   -48.6910
# 1222   -26.4064
# 1228     3.1299
# 1261    -0.5099
# Name: Return, dtype: float64
# 0.873722
# 2004
# Number of rows in test_data: 200
# confusion_matrix:
# [[56 74]
#  [19 51]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.75      0.43      0.55       130
#            1       0.41      0.73      0.52        70
#
#     accuracy                           0.54       200
#    macro avg       0.58      0.58      0.53       200
# weighted avg       0.63      0.54      0.54       200
#
# 新數據的預測準確率: 0.535
# 1.2326216008
# 最近鄰居中預測值為1的前5筆索引:
# [0, 133, 55, 24, 25]
# 1400     台積電
# 1533    景碩
# 1455     英業達
# 1424     佳世達
# 1425    長榮
# Name: 簡稱, dtype: object
# 1400     35.9455
# 1533    163.1637
# 1455     47.8824
# 1424     -3.2342
# 1425    -11.9318
# Name: Return, dtype: float64
# 1.4636512000000002
# 2005
# Number of rows in test_data: 200
# confusion_matrix:
# [[43 69]
#  [36 52]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.54      0.38      0.45       112
#            1       0.43      0.59      0.50        88
#
#     accuracy                           0.48       200
#    macro avg       0.49      0.49      0.47       200
# weighted avg       0.49      0.47      0.47       200
#
# 新數據的預測準確率: 0.475
# 1.2540711076033058
# 最近鄰居中預測值為1的前5筆索引:
# [0, 66, 74, 19, 123]
# 1600     台積電
# 1666     玉晶光
# 1674    福懋
# 1619    矽品
# 1723    華立
# Name: 簡稱, dtype: object
# 1600    17.4271
# 1666   -64.6585
# 1674    61.0357
# 1619    28.1999
# 1723    17.0347
# Name: Return, dtype: float64
# 1.1180778
# 2006
# Number of rows in test_data: 200
# confusion_matrix:
# [[45 70]
#  [29 56]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.61      0.39      0.48       115
#            1       0.44      0.66      0.53        85
#
#     accuracy                           0.51       200
#    macro avg       0.53      0.53      0.50       200
# weighted avg       0.54      0.51      0.50       200
#
# 新數據的預測準確率: 0.505
# 1.0957643373015873
# 最近鄰居中預測值為1的前5筆索引:
# [0, 6, 9, 17, 28]
# 1800     台積電
# 1806    中鋼
# 1809    台塑
# 1817     日月光
# 1828     華亞科
# Name: 簡稱, dtype: object
# 1800    -2.0470
# 1806    38.5188
# 1809    77.8561
# 1817     6.0419
# 1828   -25.0520
# Name: Return, dtype: float64
# 1.1906356
# 2007
# Number of rows in test_data: 200
# confusion_matrix:
# [[35 77]
#  [35 53]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.50      0.31      0.38       112
#            1       0.41      0.60      0.49        88
#
#     accuracy                           0.44       200
#    macro avg       0.45      0.46      0.44       200
# weighted avg       0.46      0.44      0.43       200
#
# 新數據的預測準確率: 0.44
# 0.4794423630769231
# 最近鄰居中預測值為1的前5筆索引:
# [103, 9, 24, 123, 60]
# 2103     信昌化
# 2009     聯發科
# 2024    宏碁
# 2123    合勤
# 2060     中美晶
# Name: 簡稱, dtype: object
# 2103   -78.0456
# 2009   -42.2294
# 2024   -26.7681
# 2123   -57.0590
# 2060   -71.8365
# Name: Return, dtype: float64
# 0.44812280000000004
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[62 55]
#  [32 51]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.66      0.53      0.59       117
#            1       0.48      0.61      0.54        83
#
#     accuracy                           0.56       200
#    macro avg       0.57      0.57      0.56       200
# weighted avg       0.59      0.56      0.57       200
#
# 新數據的預測準確率: 0.565
# 2.093774103773585
# 最近鄰居中預測值為1的前5筆索引:
# [0, 98, 103, 22, 94]
# 2200     台積電
# 2298    景碩
# 2303    訊連
# 2222    亞泥
# 2294    長興
# Name: 簡稱, dtype: object
# 2200     54.3008
# 2298    186.9535
# 2303     25.8613
# 2222     31.9100
# 2294    125.6584
# Name: Return, dtype: float64
# 1.849368
# {1998: 1.144121840909091, 1999: 0.6230220352941176, 2000: 1.4420691047619048, 2001: 0.9087209775280899, 2002: 1.263905496868687, 2003: 0.9990621739837399, 2004: 1.2326216008, 2005: 1.2540711076033058, 2006: 1.0957643373015873, 2007: 0.4794423630769231, 2008: 2.093774103773585}
# 年均化複利為:0.1823232572293316
#
#
# {1998: 1.1166618, 1999: 0.5435996000000001, 2000: 1.1721834, 2001: 0.7146178, 2002: 1.146921, 2003: 0.873722, 2004: 1.4636512000000002, 2005: 1.1180778, 2006: 1.1906356, 2007: 0.44812280000000004, 2008: 1.849368}
# 年均化複利為:0.07479854262392248
# ori sum2:0.8227839688631472
# test years have:11
# after sum2:0.07479854262392248
# Optimal k value for minimum error rate: 74
# 1998
# Number of rows in test_data: 200
# confusion_matrix:
# [[104  22]
#  [ 57  17]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.65      0.83      0.72       126
#            1       0.44      0.23      0.30        74
#
#     accuracy                           0.60       200
#    macro avg       0.54      0.53      0.51       200
# weighted avg       0.57      0.60      0.57       200
#
# 新數據的預測準確率: 0.605
# 1.317691794871795
# 最近鄰居中預測值為1的前5筆索引:
# [65, 17, 49, 20, 126]
# 265    南港
# 217     台達電
# 249    凌陽
# 220    台泥
# 326    德寶
# Name: 簡稱, dtype: object
# 265   -32.3554
# 217    61.8932
# 249    80.2007
# 220    30.3519
# 326   -45.1830
# Name: Return, dtype: float64
# 1.1898148
# 1999
# Number of rows in test_data: 200
# confusion_matrix:
# [[94 17]
#  [77 12]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.55      0.85      0.67       111
#            1       0.41      0.13      0.20        89
#
#     accuracy                           0.53       200
#    macro avg       0.48      0.49      0.44       200
# weighted avg       0.49      0.53      0.46       200
#
# 新數據的預測準確率: 0.53
# 0.5365678620689656
# 最近鄰居中預測值為1的前5筆索引:
# [3, 6, 108, 19, 60]
# 403    南亞
# 406    鴻海
# 508    燿華
# 419     台達電
# 460    精碟
# Name: 簡稱, dtype: object
# 403   -39.7367
# 406    -6.6126
# 508   -68.8312
# 419    -1.8891
# 460   -37.6890
# Name: Return, dtype: float64
# 0.6904828000000001
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[98 29]
#  [53 20]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.65      0.77      0.71       127
#            1       0.41      0.27      0.33        73
#
#     accuracy                           0.59       200
#    macro avg       0.53      0.52      0.52       200
# weighted avg       0.56      0.59      0.57       200
#
# 新數據的預測準確率: 0.59
# 1.2993250204081632
# 最近鄰居中預測值為1的前5筆索引:
# [0, 121, 4, 133, 25]
# 600     台積電
# 721     偉詮電
# 604    南亞
# 733    聯華
# 625    華新
# Name: 簡稱, dtype: object
# 600    59.7499
# 721    52.4904
# 604   -17.4744
# 733   -18.3807
# 625   -29.4118
# Name: Return, dtype: float64
# 1.0939467999999999
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[103  15]
#  [ 61  21]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.63      0.87      0.73       118
#            1       0.58      0.26      0.36        82
#
#     accuracy                           0.62       200
#    macro avg       0.61      0.56      0.54       200
# weighted avg       0.61      0.62      0.58       200
#
# 新數據的預測準確率: 0.62
# 1.0693598333333334
# 最近鄰居中預測值為1的前5筆索引:
# [41, 49, 17, 91, 126]
# 841     建興電
# 849    台玻
# 817     台達電
# 891    飛瑞
# 926    思源
# Name: 簡稱, dtype: object
# 841    20.0347
# 849    12.6240
# 817   -19.8608
# 891     7.4385
# 926   -13.5894
# Name: Return, dtype: float64
# 1.013294
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[93 23]
#  [63 21]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.60      0.80      0.68       116
#            1       0.48      0.25      0.33        84
#
#     accuracy                           0.57       200
#    macro avg       0.54      0.53      0.51       200
# weighted avg       0.55      0.57      0.53       200
#
# 新數據的預測準確率: 0.57
# 1.3457701022727273
# 最近鄰居中預測值為1的前5筆索引:
# [100, 8, 9, 111, 54]
# 1100    正崴
# 1008    廣達
# 1009     聯發科
# 1111    群光
# 1054    技嘉
# Name: 簡稱, dtype: object
# 1100     24.5960
# 1008     66.9324
# 1009     58.8235
# 1111    104.7619
# 1054     34.4386
# Name: Return, dtype: float64
# 1.5791048
# 2003
# Number of rows in test_data: 200
# confusion_matrix:
# [[78 20]
#  [80 22]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.49      0.80      0.61        98
#            1       0.52      0.22      0.31       102
#
#     accuracy                           0.50       200
#    macro avg       0.51      0.51      0.46       200
# weighted avg       0.51      0.50      0.45       200
#
# 新數據的預測準確率: 0.5
# 1.0049693595238096
# 最近鄰居中預測值為1的前5筆索引:
# [2, 99, 5, 109, 22]
# 1202    聯電
# 1299    精業
# 1205    南亞
# 1309    正崴
# 1222    中華
# Name: 簡稱, dtype: object
# 1202   -23.6632
# 1299   -35.2800
# 1205     9.3384
# 1309    16.2290
# 1222   -26.4064
# Name: Return, dtype: float64
# 0.8804356
# 2004
# Number of rows in test_data: 200
# confusion_matrix:
# [[109  21]
#  [ 54  16]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.67      0.84      0.74       130
#            1       0.43      0.23      0.30        70
#
#     accuracy                           0.62       200
#    macro avg       0.55      0.53      0.52       200
# weighted avg       0.59      0.62      0.59       200
#
# 新數據的預測準確率: 0.625
# 1.2212303243243243
# 最近鄰居中預測值為1的前5筆索引:
# [73, 118, 60, 94, 31]
# 1473     永豐餘
# 1518    東森
# 1460     裕日車
# 1494    瑞儀
# 1431    台泥
# Name: 簡稱, dtype: object
# 1473   -26.1538
# 1518   -21.6799
# 1460    27.3867
# 1494    29.9543
# 1431    22.2067
# Name: Return, dtype: float64
# 1.063428
# 2005
# Number of rows in test_data: 200
# confusion_matrix:
# [[104   8]
#  [ 65  23]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.62      0.93      0.74       112
#            1       0.74      0.26      0.39        88
#
#     accuracy                           0.64       200
#    macro avg       0.68      0.59      0.56       200
# weighted avg       0.67      0.64      0.58       200
#
# 新數據的預測準確率: 0.635
# 1.5120593838709677
# 最近鄰居中預測值為1的前5筆索引:
# [100, 6, 41, 126, 127]
# 1700    長興
# 1606    友達
# 1641    陽明
# 1726    輔祥
# 1727    榮化
# Name: 簡稱, dtype: object
# 1700    121.57290
# 1606     -3.04620
# 1641      0.90439
# 1726    -32.98720
# 1727     60.34250
# Name: Return, dtype: float64
# 1.29357278
# 2006
# Number of rows in test_data: 200
# confusion_matrix:
# [[99 16]
#  [71 14]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.86      0.69       115
#            1       0.47      0.16      0.24        85
#
#     accuracy                           0.56       200
#    macro avg       0.52      0.51      0.47       200
# weighted avg       0.53      0.56      0.50       200
#
# 新數據的預測準確率: 0.565
# 1.1380968333333334
# 最近鄰居中預測值為1的前5筆索引:
# [68, 6, 43, 54, 28]
# 1868    中華
# 1806    中鋼
# 1843    台肥
# 1854     長榮航
# 1828     華亞科
# Name: 簡稱, dtype: object
# 1868   -14.7197
# 1806    38.5188
# 1843    32.8709
# 1854    -0.3554
# 1828   -25.0520
# Name: Return, dtype: float64
# 1.0625252
# 2007
# Number of rows in test_data: 200
# confusion_matrix:
# [[109   3]
#  [ 71  17]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.61      0.97      0.75       112
#            1       0.85      0.19      0.31        88
#
#     accuracy                           0.63       200
#    macro avg       0.73      0.58      0.53       200
# weighted avg       0.71      0.63      0.56       200
#
# 新數據的預測準確率: 0.63
# 0.610827775
# 最近鄰居中預測值為1的前5筆索引:
# [2, 66, 137, 43, 126]
# 2002     台塑化
# 2066    神達
# 2137    南紡
# 2043    裕民
# 2126     中石化
# Name: 簡稱, dtype: object
# 2002   -24.6554
# 2066   -58.7019
# 2137   -46.8322
# 2043   -50.3668
# 2126   -47.2881
# Name: Return, dtype: float64
# 0.5443112
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[106  11]
#  [ 76   7]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.91      0.71       117
#            1       0.39      0.08      0.14        83
#
#     accuracy                           0.56       200
#    macro avg       0.49      0.50      0.42       200
# weighted avg       0.50      0.56      0.47       200
#
# 新數據的預測準確率: 0.565
# 2.003958777777778
# 最近鄰居中預測值為1的前5筆索引:
# [104, 41, 20, 54, 127]
# 2304    中航
# 2241    裕民
# 2220    台泥
# 2254    陽明
# 2327    昱晶
# Name: 簡稱, dtype: object
# 2304    89.9723
# 2241    80.9351
# 2220    30.6557
# 2254    21.7435
# 2327    85.2072
# Name: Return, dtype: float64
# 1.6170276000000001
# {1998: 1.317691794871795, 1999: 0.5365678620689656, 2000: 1.2993250204081632, 2001: 1.0693598333333334, 2002: 1.3457701022727273, 2003: 1.0049693595238096, 2004: 1.2212303243243243, 2005: 1.5120593838709677, 2006: 1.1380968333333334, 2007: 0.610827775, 2008: 2.003958777777778}
# 年均化複利為:0.3107165467182911
#
#
# {1998: 1.1898148, 1999: 0.6904828000000001, 2000: 1.0939467999999999, 2001: 1.013294, 2002: 1.5791048, 2003: 0.8804356, 2004: 1.063428, 2005: 1.29357278, 2006: 1.0625252, 2007: 0.5443112, 2008: 1.6170276000000001}
# 年均化複利為:0.14807531658435397
# ori sum2:1.6288284824278936
# test years have:11
# after sum2:0.14807531658435397
# Optimal k value for minimum error rate: 4
# 1998
# Number of rows in test_data: 200
# confusion_matrix:
# [[66 60]
#  [36 38]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.65      0.52      0.58       126
#            1       0.39      0.51      0.44        74
#
#     accuracy                           0.52       200
#    macro avg       0.52      0.52      0.51       200
# weighted avg       0.55      0.52      0.53       200
#
# 新數據的預測準確率: 0.52
# 1.1759891224489796
# 最近鄰居中預測值為1的前5筆索引:
# [10, 19, 123, 29, 127]
# 210    華通
# 219    亞泥
# 323    中橡
# 229    萬海
# 327    英誌
# Name: 簡稱, dtype: object
# 210     5.8307
# 219     3.2937
# 323    -9.6610
# 229   -33.2510
# 327   -19.8965
# Name: Return, dtype: float64
# 0.8926318
# 1999
# Number of rows in test_data: 200
# confusion_matrix:
# [[71 40]
#  [36 53]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.66      0.64      0.65       111
#            1       0.57      0.60      0.58        89
#
#     accuracy                           0.62       200
#    macro avg       0.62      0.62      0.62       200
# weighted avg       0.62      0.62      0.62       200
#
# 新數據的預測準確率: 0.62
# 0.5894919569892474
# 最近鄰居中預測值為1的前5筆索引:
# [9, 109, 83, 31, 95]
# 409    茂德
# 509    世平
# 483    博達
# 431    華宇
# 495    士電
# Name: 簡稱, dtype: object
# 409   -59.5213
# 509   -40.9449
# 483   -37.6195
# 431   -71.2190
# 495   -25.2321
# Name: Return, dtype: float64
# 0.5309264
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[56 71]
#  [24 49]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.70      0.44      0.54       127
#            1       0.41      0.67      0.51        73
#
#     accuracy                           0.53       200
#    macro avg       0.55      0.56      0.52       200
# weighted avg       0.59      0.53      0.53       200
#
# 新數據的預測準確率: 0.525
# 1.3880518166666667
# 最近鄰居中預測值為1的前5筆索引:
# [8, 108, 23, 127, 31]
# 608    廣達
# 708    鈺創
# 623    凌陽
# 727    鑽全
# 631    台泥
# Name: 簡稱, dtype: object
# 608    75.0099
# 708    72.8899
# 623    13.1168
# 727     8.2527
# 631   -42.4508
# Name: Return, dtype: float64
# 1.253637
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[61 57]
#  [40 42]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.60      0.52      0.56       118
#            1       0.42      0.51      0.46        82
#
#     accuracy                           0.52       200
#    macro avg       0.51      0.51      0.51       200
# weighted avg       0.53      0.52      0.52       200
#
# 新數據的預測準確率: 0.515
# 0.9502648575757576
# 最近鄰居中預測值為1的前5筆索引:
# [98, 100, 77, 23, 87]
# 898    創見
# 900     三商行
# 877    福懋
# 823    瑞昱
# 887    飛宏
# Name: 簡稱, dtype: object
# 898    16.4140
# 900   -33.8859
# 877    55.0832
# 823   -29.2174
# 887   -46.4371
# Name: Return, dtype: float64
# 0.9239136
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[55 61]
#  [38 46]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.47      0.53       116
#            1       0.43      0.55      0.48        84
#
#     accuracy                           0.51       200
#    macro avg       0.51      0.51      0.50       200
# weighted avg       0.52      0.51      0.51       200
#
# 新數據的預測準確率: 0.505
# 1.314783423271028
# 最近鄰居中預測值為1的前5筆索引:
# [100, 133, 8, 10, 121]
# 1100    正崴
# 1133    遠雄
# 1008    廣達
# 1010     台灣大
# 1121    正隆
# Name: 簡稱, dtype: object
# 1100    24.5960
# 1133    30.7607
# 1008    66.9324
# 1010    14.1383
# 1121    29.5385
# Name: Return, dtype: float64
# 1.3319318
# 2003
# Number of rows in test_data: 200
# confusion_matrix:
# [[47 51]
#  [49 53]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.49      0.48      0.48        98
#            1       0.51      0.52      0.51       102
#
#     accuracy                           0.50       200
#    macro avg       0.50      0.50      0.50       200
# weighted avg       0.50      0.50      0.50       200
#
# 新數據的預測準確率: 0.5
# 1.0214744076923077
# 最近鄰居中預測值為1的前5筆索引:
# [133, 109, 17, 82, 127]
# 1333    瑞軒
# 1309    正崴
# 1217    宏碁
# 1282    和泰
# 1327     潤泰全
# Name: 簡稱, dtype: object
# 1333   -37.3156
# 1309    16.2290
# 1217    17.2195
# 1282    77.1662
# 1327     0.0000
# Name: Return, dtype: float64
# 1.1465982000000001
# 2004
# Number of rows in test_data: 200
# confusion_matrix:
# [[59 71]
#  [25 45]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.70      0.45      0.55       130
#            1       0.39      0.64      0.48        70
#
#     accuracy                           0.52       200
#    macro avg       0.55      0.55      0.52       200
# weighted avg       0.59      0.52      0.53       200
#
# 新數據的預測準確率: 0.52
# 1.2217845698275862
# 最近鄰居中預測值為1的前5筆索引:
# [4, 75, 118, 120, 31]
# 1404    聯電
# 1475    技嘉
# 1518    東森
# 1520     晶豪科
# 1431    台泥
# Name: 簡稱, dtype: object
# 1404     1.1583
# 1475    -7.9775
# 1518   -21.6799
# 1520   -32.6188
# 1431    22.2067
# Name: Return, dtype: float64
# 0.9221776
# 2005
# Number of rows in test_data: 200
# confusion_matrix:
# [[49 63]
#  [38 50]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.56      0.44      0.49       112
#            1       0.44      0.57      0.50        88
#
#     accuracy                           0.49       200
#    macro avg       0.50      0.50      0.49       200
# weighted avg       0.51      0.49      0.49       200
#
# 新數據的預測準確率: 0.495
# 1.2980416539823008
# 最近鄰居中預測值為1的前5筆索引:
# [66, 100, 4, 133, 75]
# 1666     玉晶光
# 1700    長興
# 1604     聯發科
# 1733    川湖
# 1675    合勤
# Name: 簡稱, dtype: object
# 1666    -64.6585
# 1700    121.5729
# 1604      1.2951
# 1733      3.9142
# 1675    -22.5082
# Name: Return, dtype: float64
# 1.079231
# 2006
# Number of rows in test_data: 200
# confusion_matrix:
# [[46 69]
#  [35 50]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.57      0.40      0.47       115
#            1       0.42      0.59      0.49        85
#
#     accuracy                           0.48       200
#    macro avg       0.49      0.49      0.48       200
# weighted avg       0.51      0.48      0.48       200
#
# 新數據的預測準確率: 0.48
# 1.098110206722689
# 最近鄰居中預測值為1的前5筆索引:
# [100, 133, 72, 23, 29]
# 1900    立錡
# 1933    中橡
# 1872    凌陽
# 1823     奇美電
# 1829    仁寶
# Name: 簡稱, dtype: object
# 1900    32.4277
# 1933   -17.2212
# 1872   -21.0797
# 1823    94.4106
# 1829    29.6381
# Name: Return, dtype: float64
# 1.236351
# 2007
# Number of rows in test_data: 200
# confusion_matrix:
# [[53 59]
#  [38 50]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.47      0.52       112
#            1       0.46      0.57      0.51        88
#
#     accuracy                           0.52       200
#    macro avg       0.52      0.52      0.51       200
# weighted avg       0.53      0.52      0.52       200
#
# 新數據的預測準確率: 0.515
# 0.49404880275229357
# 最近鄰居中預測值為1的前5筆索引:
# [4, 100, 73, 43, 109]
# 2004     中華電
# 2100    台橡
# 2073    遠百
# 2043    裕民
# 2109    達方
# Name: 簡稱, dtype: object
# 2004     7.3156
# 2100   -36.7860
# 2073   -48.1155
# 2043   -50.3668
# 2109   -74.2956
# Name: Return, dtype: float64
# 0.5955034000000001
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[58 59]
#  [42 41]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.50      0.53       117
#            1       0.41      0.49      0.45        83
#
#     accuracy                           0.49       200
#    macro avg       0.49      0.49      0.49       200
# weighted avg       0.51      0.49      0.50       200
#
# 新數據的預測準確率: 0.495
# 2.02053607
# 最近鄰居中預測值為1的前5筆索引:
# [4, 74, 19, 20, 60]
# 2204    中鋼
# 2274    群光
# 2219     遠東新
# 2220    台泥
# 2260    遠百
# Name: 簡稱, dtype: object
# 2204     55.6115
# 2274    165.6756
# 2219     98.8072
# 2220     30.6557
# 2260    105.2724
# Name: Return, dtype: float64
# 1.9120447999999999
# {1998: 1.1759891224489796, 1999: 0.5894919569892474, 2000: 1.3880518166666667, 2001: 0.9502648575757576, 2002: 1.314783423271028, 2003: 1.0214744076923077, 2004: 1.2217845698275862, 2005: 1.2980416539823008, 2006: 1.098110206722689, 2007: 0.49404880275229357, 2008: 2.02053607}
# 年均化複利為:0.1940824265201858
#
#
# {1998: 0.8926318, 1999: 0.5309264, 2000: 1.253637, 2001: 0.9239136, 2002: 1.3319318, 2003: 1.1465982000000001, 2004: 0.9221776, 2005: 1.079231, 2006: 1.236351, 2007: 0.5955034000000001, 2008: 1.9120447999999999}
# 年均化複利為:0.10677349761555256
# ori sum2:1.1745084737710783
# test years have:11
# after sum2:0.10677349761555256
# Optimal k value for minimum error rate: 47
# 1998
# Number of rows in test_data: 200
# confusion_matrix:
# [[81 45]
#  [36 38]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.69      0.64      0.67       126
#            1       0.46      0.51      0.48        74
#
#     accuracy                           0.59       200
#    macro avg       0.58      0.58      0.58       200
# weighted avg       0.61      0.59      0.60       200
#
# 新數據的預測準確率: 0.595
# 1.2306802409638555
# 最近鄰居中預測值為1的前5筆索引:
# [103, 18, 24, 121, 126]
# 303    耀文
# 218    矽品
# 224    寶成
# 321    致茂
# 326    德寶
# Name: 簡稱, dtype: object
# 303   -39.2704
# 218    74.4608
# 224    25.5390
# 321    41.9126
# 326   -45.1830
# Name: Return, dtype: float64
# 1.114918
# 1999
# Number of rows in test_data: 200
# confusion_matrix:
# [[75 36]
#  [44 45]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.63      0.68      0.65       111
#            1       0.56      0.51      0.53        89
#
#     accuracy                           0.60       200
#    macro avg       0.59      0.59      0.59       200
# weighted avg       0.60      0.60      0.60       200
#
# 新數據的預測準確率: 0.6
# 0.5914478765432098
# 最近鄰居中預測值為1的前5筆索引:
# [64, 4, 9, 10, 109]
# 464    正新
# 404    宏電
# 409    茂德
# 410    中鋼
# 509    世平
# Name: 簡稱, dtype: object
# 464   -13.8482
# 404   -80.3727
# 409   -59.5213
# 410    -6.8474
# 509   -40.9449
# Name: Return, dtype: float64
# 0.596931
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[66 61]
#  [22 51]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.75      0.52      0.61       127
#            1       0.46      0.70      0.55        73
#
#     accuracy                           0.58       200
#    macro avg       0.60      0.61      0.58       200
# weighted avg       0.64      0.58      0.59       200
#
# 新數據的預測準確率: 0.585
# 1.4669726607142857
# 最近鄰居中預測值為1的前5筆索引:
# [0, 103, 19, 84, 127]
# 600     台積電
# 703    豐泰
# 619     日月光
# 684    宏碁
# 727    鑽全
# Name: 簡稱, dtype: object
# 600    59.7499
# 703    44.3357
# 619    74.2887
# 684    39.6409
# 727     8.2527
# Name: Return, dtype: float64
# 1.4525358
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[64 54]
#  [47 35]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.54      0.56       118
#            1       0.39      0.43      0.41        82
#
#     accuracy                           0.49       200
#    macro avg       0.48      0.48      0.48       200
# weighted avg       0.50      0.49      0.50       200
#
# 新數據的預測準確率: 0.495
# 0.9076352584269662
# 最近鄰居中預測值為1的前5筆索引:
# [100, 24, 121, 126, 95]
# 900     三商行
# 824    凌陽
# 921    巨大
# 926    思源
# 895    群光
# Name: 簡稱, dtype: object
# 900   -33.8859
# 824   -22.2344
# 921    50.6470
# 926   -13.5894
# 895   -10.4196
# Name: Return, dtype: float64
# 0.9410354
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[49 67]
#  [42 42]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.54      0.42      0.47       116
#            1       0.39      0.50      0.44        84
#
#     accuracy                           0.46       200
#    macro avg       0.46      0.46      0.45       200
# weighted avg       0.47      0.46      0.46       200
#
# 新數據的預測準確率: 0.455
# 1.2799782275229359
# 最近鄰居中預測值為1的前5筆索引:
# [8, 11, 109, 56, 26]
# 1008    廣達
# 1011    華碩
# 1109    豐泰
# 1056    精英
# 1026    瑞昱
# Name: 簡稱, dtype: object
# 1008    66.9324
# 1011    41.7338
# 1109    27.7822
# 1056   -25.2116
# 1026   -18.7895
# Name: Return, dtype: float64
# 1.1848946
# 2003
# Number of rows in test_data: 200
# confusion_matrix:
# [[40 58]
#  [38 64]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.51      0.41      0.45        98
#            1       0.52      0.63      0.57       102
#
#     accuracy                           0.52       200
#    macro avg       0.52      0.52      0.51       200
# weighted avg       0.52      0.52      0.51       200
#
# 新數據的預測準確率: 0.52
# 1.0028950524590163
# 最近鄰居中預測值為1的前5筆索引:
# [4, 6, 120, 123, 125]
# 1204    鴻海
# 1206    台塑
# 1320    盛餘
# 1323    豐泰
# 1325    奇景
# Name: 簡稱, dtype: object
# 1204    30.9336
# 1206     7.2428
# 1320    14.4641
# 1323    22.5564
# 1325     9.4411
# Name: Return, dtype: float64
# 1.169276
# 2004
# Number of rows in test_data: 200
# confusion_matrix:
# [[42 88]
#  [16 54]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.72      0.32      0.45       130
#            1       0.38      0.77      0.51        70
#
#     accuracy                           0.48       200
#    macro avg       0.55      0.55      0.48       200
# weighted avg       0.60      0.48      0.47       200
#
# 新數據的預測準確率: 0.48
# 1.2081065992957747
# 最近鄰居中預測值為1的前5筆索引:
# [133, 72, 118, 24, 121]
# 1533    景碩
# 1472    勝華
# 1518    東森
# 1424     佳世達
# 1521    長興
# Name: 簡稱, dtype: object
# 1533    163.1637
# 1472     89.4196
# 1518    -21.6799
# 1424     -3.2342
# 1521     36.2832
# Name: Return, dtype: float64
# 1.5279048
# 2005
# Number of rows in test_data: 200
# confusion_matrix:
# [[40 72]
#  [37 51]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.52      0.36      0.42       112
#            1       0.41      0.58      0.48        88
#
#     accuracy                           0.46       200
#    macro avg       0.47      0.47      0.45       200
# weighted avg       0.47      0.46      0.45       200
#
# 新數據的預測準確率: 0.455
# 1.2322172936585365
# 最近鄰居中預測值為1的前5筆索引:
# [103, 135, 74, 109, 19]
# 1703    豐泰
# 1735    精元
# 1674    福懋
# 1709    頎邦
# 1619    矽品
# Name: 簡稱, dtype: object
# 1703    -6.2811
# 1735    -2.4518
# 1674    61.0357
# 1709   -39.6236
# 1619    28.1999
# Name: Return, dtype: float64
# 1.0817582
# 2006
# Number of rows in test_data: 200
# confusion_matrix:
# [[42 73]
#  [27 58]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.61      0.37      0.46       115
#            1       0.44      0.68      0.54        85
#
#     accuracy                           0.50       200
#    macro avg       0.53      0.52      0.50       200
# weighted avg       0.54      0.50      0.49       200
#
# 新數據的預測準確率: 0.5
# 1.1022789083969466
# 最近鄰居中預測值為1的前5筆索引:
# [100, 71, 103, 9, 120]
# 1900    立錡
# 1871    和泰
# 1903    智原
# 1809    台塑
# 1920    群聯
# Name: 簡稱, dtype: object
# 1900    32.4277
# 1871    19.1732
# 1903    -1.5183
# 1809    77.8561
# 1920    -1.9618
# Name: Return, dtype: float64
# 1.2519538
# 2007
# Number of rows in test_data: 200
# confusion_matrix:
# [[34 78]
#  [28 60]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.55      0.30      0.39       112
#            1       0.43      0.68      0.53        88
#
#     accuracy                           0.47       200
#    macro avg       0.49      0.49      0.46       200
# weighted avg       0.50      0.47      0.45       200
#
# 新數據的預測準確率: 0.47
# 0.4962696318840579
# 最近鄰居中預測值為1的前5筆索引:
# [9, 19, 26, 123, 28]
# 2009     聯發科
# 2019     日月光
# 2026    仁寶
# 2123    合勤
# 2028    亞泥
# Name: 簡稱, dtype: object
# 2009   -42.2294
# 2019   -59.9225
# 2026   -46.6431
# 2123   -57.0590
# 2028   -32.2397
# Name: Return, dtype: float64
# 0.5238126000000001
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[66 51]
#  [34 49]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.66      0.56      0.61       117
#            1       0.49      0.59      0.54        83
#
#     accuracy                           0.57       200
#    macro avg       0.57      0.58      0.57       200
# weighted avg       0.59      0.57      0.58       200
#
# 新數據的預測準確率: 0.575
# 2.1143612
# 最近鄰居中預測值為1的前5筆索引:
# [4, 135, 103, 111, 56]
# 2204    中鋼
# 2335     新日興
# 2303    訊連
# 2311     大聯大
# 2256    創見
# Name: 簡稱, dtype: object
# 2204     55.6115
# 2335    116.9515
# 2303     25.8613
# 2311    270.3226
# 2256    113.9037
# Name: Return, dtype: float64
# 2.1653012
# {1998: 1.2306802409638555, 1999: 0.5914478765432098, 2000: 1.4669726607142857, 2001: 0.9076352584269662, 2002: 1.2799782275229359, 2003: 1.0028950524590163, 2004: 1.2081065992957747, 2005: 1.2322172936585365, 2006: 1.1022789083969466, 2007: 0.4962696318840579, 2008: 2.1143612}
# 年均化複利為:0.19473382930312322
#
#
# {1998: 1.114918, 1999: 0.596931, 2000: 1.4525358, 2001: 0.9410354, 2002: 1.1848946, 2003: 1.169276, 2004: 1.5279048, 2005: 1.0817582, 2006: 1.2519538, 2007: 0.5238126000000001, 2008: 2.1653012}
# 年均化複利為:0.2689137374539426
# ori sum2:2.9580511119933686
# test years have:11
# after sum2:0.2689137374539426
# Optimal k value for minimum error rate: 10
# 1998
# Number of rows in test_data: 200
# confusion_matrix:
# [[84 42]
#  [38 36]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.69      0.67      0.68       126
#            1       0.46      0.49      0.47        74
#
#     accuracy                           0.60       200
#    macro avg       0.58      0.58      0.58       200
# weighted avg       0.60      0.60      0.60       200
#
# 新數據的預測準確率: 0.6
# 1.1942455
# 最近鄰居中預測值為1的前5筆索引:
# [6, 77, 60, 17, 28]
# 206     英業達
# 277     金像電
# 260    飛瑞
# 217     台達電
# 228    中環
# Name: 簡稱, dtype: object
# 206    -13.1390
# 277     -8.0565
# 260     11.1953
# 217     61.8932
# 228    191.6759
# Name: Return, dtype: float64
# 1.4871378
# 1999
# Number of rows in test_data: 200
# confusion_matrix:
# [[64 47]
#  [44 45]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.58      0.58       111
#            1       0.49      0.51      0.50        89
#
#     accuracy                           0.55       200
#    macro avg       0.54      0.54      0.54       200
# weighted avg       0.55      0.55      0.55       200
#
# 新數據的預測準確率: 0.545
# 0.5765984782608695
# 最近鄰居中預測值為1的前5筆索引:
# [69, 133, 87, 89, 60]
# 469    年興
# 533    正隆
# 487    致茂
# 489    聯成
# 460    精碟
# Name: 簡稱, dtype: object
# 469   -34.9908
# 533   -26.9406
# 487   -66.7308
# 489   -72.7273
# 460   -37.6890
# Name: Return, dtype: float64
# 0.5218430000000001
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[64 63]
#  [17 56]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.79      0.50      0.62       127
#            1       0.47      0.77      0.58        73
#
#     accuracy                           0.60       200
#    macro avg       0.63      0.64      0.60       200
# weighted avg       0.67      0.60      0.60       200
#
# 新數據的預測準確率: 0.6
# 1.464445613445378
# 最近鄰居中預測值為1的前5筆索引:
# [4, 133, 109, 77, 60]
# 604    南亞
# 733    聯華
# 709     禾伸堂
# 677    晶華
# 660    聲寶
# Name: 簡稱, dtype: object
# 604   -17.4744
# 733   -18.3807
# 709    46.1834
# 677   -29.5122
# 660   -16.8148
# Name: Return, dtype: float64
# 0.9280026
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[67 51]
#  [45 37]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.60      0.57      0.58       118
#            1       0.42      0.45      0.44        82
#
#     accuracy                           0.52       200
#    macro avg       0.51      0.51      0.51       200
# weighted avg       0.53      0.52      0.52       200
#
# 新數據的預測準確率: 0.52
# 0.9387934045454546
# 最近鄰居中預測值為1的前5筆索引:
# [98, 9, 55, 23, 94]
# 898    創見
# 809    威盛
# 855    金寶
# 823    瑞昱
# 894     第一店
# Name: 簡稱, dtype: object
# 898    16.4140
# 809   -66.5162
# 855   -15.6557
# 823   -29.2174
# 894   -78.7800
# Name: Return, dtype: float64
# 0.6524894000000001
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[57 59]
#  [46 38]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.55      0.49      0.52       116
#            1       0.39      0.45      0.42        84
#
#     accuracy                           0.48       200
#    macro avg       0.47      0.47      0.47       200
# weighted avg       0.49      0.47      0.48       200
#
# 新數據的預測準確率: 0.475
# 1.2586436937113403
# 最近鄰居中預測值為1的前5筆索引:
# [135, 56, 26, 126, 127]
# 1135    中鴻
# 1056    精英
# 1026    瑞昱
# 1126    和桐
# 1127     美隆電
# Name: 簡稱, dtype: object
# 1135    105.40540
# 1056    -25.21160
# 1026    -18.78950
# 1126     -2.61380
# 1127      0.40177
# Name: Return, dtype: float64
# 1.11838454
# 2003
# Number of rows in test_data: 200
# confusion_matrix:
# [[40 58]
#  [34 68]]
# classification_report
#               precision    recall  f1-score   support
#
# ...
#
#           -1       0.62      0.81      0.70       111
#            1       0.62      0.38      0.47        89
#
#     accuracy                           0.62       200
#    macro avg       0.62      0.60      0.59       200
# weighted avg       0.62      0.62      0.60       200
#
# 新數據的預測準確率: 0.62
# 0.652721309090909
# 最近鄰居中預測值為1的前5筆索引:
# [33, 6, 40, 8, 19]
# 433    亞泥
# 406    鴻海
# 440    技嘉
# 408    台塑
# 419     台達電
# Name: 簡稱, dtype: object
# 433   -25.6864
# 406    -6.6126
# 440   -55.1449
# 408   -18.0935
# 419    -1.8891
# Name: Return, dtype: float64
# 0.785147
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[95 32]
#  [49 24]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.66      0.75      0.70       127
#            1       0.43      0.33      0.37        73
#
#     accuracy                           0.59       200
#    macro avg       0.54      0.54      0.54       200
# weighted avg       0.58      0.59      0.58       200
#
# 新數據的預測準確率: 0.595
# 1.432826232142857
# 最近鄰居中預測值為1的前5筆索引:
# [101, 133, 6, 85, 55]
# 701    毅嘉
# 733    聯華
# 606    中鋼
# 685    亞光
# 655    精碟
# Name: 簡稱, dtype: object
# 701     -3.1608
# 733    -18.3807
# 606    -22.2052
# 685    159.1819
# 655      3.9474
# Name: Return, dtype: float64
# 1.2387652
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[85 33]
#  [57 25]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.60      0.72      0.65       118
#            1       0.43      0.30      0.36        82
#
#     accuracy                           0.55       200
#    macro avg       0.51      0.51      0.51       200
# weighted avg       0.53      0.55      0.53       200
#
# 新數據的預測準確率: 0.55
# 0.9060969137931034
# 最近鄰居中預測值為1的前5筆索引:
# [34, 98, 109, 53, 22]
# 834    統一
# 898    創見
# 909    光罩
# 853    精業
# 822    微星
# Name: 簡稱, dtype: object
# 834    -8.0711
# 898    16.4140
# 909   -21.8798
# 853   -49.7189
# 822   -49.4284
# Name: Return, dtype: float64
# 0.7746316
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[69 47]
#  [61 23]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.53      0.59      0.56       116
#            1       0.33      0.27      0.30        84
#
#     accuracy                           0.46       200
#    macro avg       0.43      0.43      0.43       200
# weighted avg       0.45      0.46      0.45       200
#
# 新數據的預測準確率: 0.46
# 1.2185532255714286
# 最近鄰居中預測值為1的前5筆索引:
# [8, 16, 58, 127, 63]
# 1008    廣達
# 1016    裕隆
# 1058     宏達電
# 1127     美隆電
# 1063    D 復盛
# Name: 簡稱, dtype: object
# 1008    66.93240
# 1016     5.92150
# 1058     6.06900
# 1127     0.40177
# 1063    67.87510
# Name: Return, dtype: float64
# 1.2943995400000001
# 2003
# Number of rows in test_data: 200
# confusion_matrix:
# [[63 35]
#  [62 40]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.50      0.64      0.57        98
#            1       0.53      0.39      0.45       102
#
#     accuracy                           0.52       200
#    macro avg       0.52      0.52      0.51       200
# weighted avg       0.52      0.52      0.51       200
#
# 新數據的預測準確率: 0.515
# 1.032973044
# 最近鄰居中預測值為1的前5筆索引:
# [1, 6, 40, 74, 138]
# 1201     中華電
# 1206    台塑
# 1240    萬海
# 1274    東聯
# 1338    燦坤
# Name: 簡稱, dtype: object
# 1201    37.45940
# 1206     7.24280
# 1240    21.04590
# 1274    -0.56497
# 1338   -20.05360
# Name: Return, dtype: float64
# 1.09025906
# 2004
# Number of rows in test_data: 200
# confusion_matrix:
# [[78 52]
#  [45 25]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.63      0.60      0.62       130
#            1       0.32      0.36      0.34        70
#
#     accuracy                           0.52       200
#    macro avg       0.48      0.48      0.48       200
# weighted avg       0.53      0.52      0.52       200
#
# 新數據的預測準確率: 0.515
# 1.126244607792208
# 最近鄰居中預測值為1的前5筆索引:
# [66, 2, 3, 101, 85]
# 1466    福懋
# 1402     台塑化
# 1403    鴻海
# 1501    中保
# 1485    可成
# Name: 簡稱, dtype: object
# 1466      9.6834
# 1402     13.6871
# 1403     51.0110
# 1501     38.4021
# 1485    251.7606
# Name: Return, dtype: float64
# 1.7290884000000002
# 2005
# Number of rows in test_data: 200
# confusion_matrix:
# [[71 41]
#  [56 32]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.56      0.63      0.59       112
#            1       0.44      0.36      0.40        88
#
#     accuracy                           0.52       200
#    macro avg       0.50      0.50      0.50       200
# weighted avg       0.51      0.52      0.51       200
#
# 新數據的預測準確率: 0.515
# 1.2605067049315068
# 最近鄰居中預測值為1的前5筆索引:
# [102, 8, 51, 118, 120]
# 1702    超豐
# 1608    中鋼
# 1651    台玻
# 1718    豐興
# 1720     華晶科
# Name: 簡稱, dtype: object
# 1702    19.2163
# 1608    64.0869
# 1651    14.9649
# 1718    84.7247
# 1720    11.6762
# Name: Return, dtype: float64
# 1.389338
# 2007
# Number of rows in test_data: 200
# confusion_matrix:
# [[85 27]
#  [63 25]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.57      0.76      0.65       112
#            1       0.48      0.28      0.36        88
#
#     accuracy                           0.55       200
#    macro avg       0.53      0.52      0.51       200
# weighted avg       0.53      0.55      0.52       200
#
# 新數據的預測準確率: 0.55
# 0.5335082057692306
# 最近鄰居中預測值為1的前5筆索引:
# [71, 18, 119, 120, 124]
# 2071     英業達
# 2018    矽品
# 2119     建興電
# 2120    中保
# 2124    群聯
# Name: 簡稱, dtype: object
# 2071   -44.02170
# 2018   -45.92720
# 2119   -45.89870
# 2120     0.83672
# 2124   -62.79050
# Name: Return, dtype: float64
# 0.60439724
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[80 37]
#  [45 38]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.64      0.68      0.66       117
#            1       0.51      0.46      0.48        83
#
#     accuracy                           0.59       200
#    macro avg       0.57      0.57      0.57       200
# weighted avg       0.58      0.59      0.59       200
#
# 新數據的預測準確率: 0.59
# 2.132551373333333
# 最近鄰居中預測值為1的前5筆索引:
# [133, 6, 109, 80, 57]
# 2333    錸德
# 2206    台塑
# 2309     中光電
# 2280    新普
# 2257     英業達
# Name: 簡稱, dtype: object
# 2333    106.5728
# 2206     70.3833
# 2309    189.3970
# 2280    172.0434
# 2257    140.0832
# Name: Return, dtype: float64
# 2.3569594
# {1997: 0.8761941780821918, 1998: 1.1807883787878788, 1999: 0.652721309090909, 2000: 1.432826232142857, 2001: 0.9060969137931034, 2002: 1.2185532255714286, 2003: 1.032973044, 2004: 1.126244607792208, 2005: 1.2605067049315068, 2007: 0.5335082057692306, 2008: 2.132551373333333}
# 年均化複利為:0.16204203820344043
#
#
# {1997: 0.8106222000000001, 1998: 1.1071898, 1999: 0.785147, 2000: 1.2387652, 2001: 0.7746316, 2002: 1.2943995400000001, 2003: 1.09025906, 2004: 1.7290884000000002, 2005: 1.389338, 2007: 0.60439724, 2008: 2.3569594}
# 年均化複利為:0.2968799073001662
# ori sum2:3.2656789803018285
# test years have:11
# after sum2:0.2968799073001662
# Optimal k value for minimum error rate: 15
# 1997
# Number of rows in test_data: 200
# confusion_matrix:
# [[85 24]
#  [68 23]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.56      0.78      0.65       109
#            1       0.49      0.25      0.33        91
#
#     accuracy                           0.54       200
#    macro avg       0.52      0.52      0.49       200
# weighted avg       0.53      0.54      0.51       200
#
# 新數據的預測準確率: 0.54
# 0.8488394042553191
# 最近鄰居中預測值為1的前5筆索引:
# [2, 98, 106, 75, 109]
# 2      中鋼
# 98     信大
# 106    裕民
# 75     長興
# 109     楠梓電
# Name: 簡稱, dtype: object
# 2      -9.2224
# 98    -41.2002
# 106   -26.5082
# 75    -18.1818
# 109    62.2231
# Name: Return, dtype: float64
# 0.934221
# 1998
# Number of rows in test_data: 200
# confusion_matrix:
# [[109  17]
#  [ 56  18]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.66      0.87      0.75       126
#            1       0.51      0.24      0.33        74
#
#     accuracy                           0.64       200
#    macro avg       0.59      0.55      0.54       200
# weighted avg       0.61      0.64      0.59       200
#
# 新數據的預測準確率: 0.635
# 1.3429210285714286
# 最近鄰居中預測值為1的前5筆索引:
# [2, 34, 3, 43, 50]
# 202    南亞
# 234    聯強
# 203    中鋼
# 243    正新
# 250     楠梓電
# Name: 簡稱, dtype: object
# 202    86.7127
# 234    89.9180
# 203    39.6414
# 243   -22.2567
# 250   -20.4121
# Name: Return, dtype: float64
# 1.3472066
# 1999
# Number of rows in test_data: 200
# confusion_matrix:
# [[97 14]
#  [59 30]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.62      0.87      0.73       111
#            1       0.68      0.34      0.45        89
#
#     accuracy                           0.64       200
#    macro avg       0.65      0.61      0.59       200
# weighted avg       0.65      0.64      0.60       200
#
# 新數據的預測準確率: 0.635
# 0.6537566363636365
# 最近鄰居中預測值為1的前5筆索引:
# [7, 8, 40, 71, 109]
# 407     日月光
# 408    台塑
# 440    技嘉
# 471    慧智
# 509    世平
# Name: 簡稱, dtype: object
# 407   -73.8927
# 408   -18.0935
# 440   -55.1449
# 471   -80.8009
# 509   -40.9449
# Name: Return, dtype: float64
# 0.46224619999999994
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[95 32]
#  [53 20]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.64      0.75      0.69       127
#            1       0.38      0.27      0.32        73
#
#     accuracy                           0.57       200
#    macro avg       0.51      0.51      0.51       200
# weighted avg       0.55      0.57      0.56       200
#
# 新數據的預測準確率: 0.575
# 1.297981346153846
# 最近鄰居中預測值為1的前5筆索引:
# [2, 75, 18, 120, 29]
# 602    聯電
# 675     普立爾
# 618    仁寶
# 720    裕民
# 629     英業達
# Name: 簡稱, dtype: object
# 602     26.1251
# 675    137.1613
# 618     26.4574
# 720      3.8462
# 629     13.5381
# Name: Return, dtype: float64
# 1.4142562
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[103  15]
#  [ 66  16]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.61      0.87      0.72       118
#            1       0.52      0.20      0.28        82
#
#     accuracy                           0.59       200
#    macro avg       0.56      0.53      0.50       200
# weighted avg       0.57      0.59      0.54       200
#
# 新數據的預測準確率: 0.595
# 1.0521956451612904
# 最近鄰居中預測值為1的前5筆索引:
# [101, 106, 43, 115, 86]
# 901    世平
# 906    和桐
# 843     光寶科
# 915    豐泰
# 886    義隆
# Name: 簡稱, dtype: object
# 901   -33.2513
# 906    -8.9094
# 843     5.6481
# 915    21.0271
# 886   -39.7265
# Name: Return, dtype: float64
# 0.889576
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[90 26]
#  [69 15]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.57      0.78      0.65       116
#            1       0.37      0.18      0.24        84
#
#     accuracy                           0.53       200
#    macro avg       0.47      0.48      0.45       200
# weighted avg       0.48      0.53      0.48       200
# 新數據的預測準確率: 0.525
# 1.3029606097560975
# 最近鄰居中預測值為1的前5筆索引:
# [7, 109, 56, 25, 126]
# 1007    台化
# 1109    豐泰
# 1056    精英
# 1025    寶成
# 1126    和桐
# Name: 簡稱, dtype: object
# 1007    74.1454
# 1109    27.7822
# 1056   -25.2116
# 1025    42.0615
# 1126    -2.6138
# Name: Return, dtype: float64
# 1.2323274
# 2003
# Number of rows in test_data: 200
# confusion_matrix:
# [[77 21]
#  [66 36]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.54      0.79      0.64        98
#            1       0.63      0.35      0.45       102
#
#     accuracy                           0.56       200
#    macro avg       0.59      0.57      0.55       200
# weighted avg       0.59      0.56      0.54       200
#
# 新數據的預測準確率: 0.565
# 1.1018471105263157
# 最近鄰居中預測值為1的前5筆索引:
# [40, 74, 106, 117, 120]
# 1240    萬海
# 1274    東聯
# 1306    中鼎
# 1317    中保
# 1320    盛餘
# Name: 簡稱, dtype: object
# 1240    21.04590
# 1274    -0.56497
# 1306   -20.82080
# 1317    29.64200
# 1320    14.46410
# Name: Return, dtype: float64
# 1.08753246
# 2004
# Number of rows in test_data: 200
# confusion_matrix:
# [[80 50]
#  [52 18]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.61      0.62      0.61       130
#            1       0.26      0.26      0.26        70
#
#     accuracy                           0.49       200
#    macro avg       0.44      0.44      0.44       200
# weighted avg       0.49      0.49      0.49       200
#
# 新數據的預測準確率: 0.49
# 1.0557905779411765
# 最近鄰居中預測值為1的前5筆索引:
# [34, 132, 111, 49, 118]
# 1434    中華
# 1532    元太
# 1511    豐泰
# 1449    聯強
# 1518    東森
# Name: 簡稱, dtype: object
# 1434   -10.5772
# 1532   -28.5369
# 1511    13.1391
# 1449    -2.0372
# 1518   -21.6799
# Name: Return, dtype: float64
# 0.9006158
# 2005
# Number of rows in test_data: 200
# confusion_matrix:
# [[84 28]
#  [58 30]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.75      0.66       112
#            1       0.52      0.34      0.41        88
#
#     accuracy                           0.57       200
#    macro avg       0.55      0.55      0.54       200
# weighted avg       0.56      0.57      0.55       200
#
# 新數據的預測準確率: 0.57
# 1.2958260027586206
# 最近鄰居中預測值為1的前5筆索引:
# [133, 7, 43, 118, 127]
# 1733    川湖
# 1607    台塑
# 1643    勝華
# 1718    豐興
# 1727    榮化
# Name: 簡稱, dtype: object
# 1733     3.9142
# 1607    20.4242
# 1643   -31.1336
# 1718    84.7247
# 1727    60.3425
# Name: Return, dtype: float64
# 1.276544
# 2007
# Number of rows in test_data: 200
# confusion_matrix:
# [[80 32]
#  [58 30]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.71      0.64       112
#            1       0.48      0.34      0.40        88
#
#     accuracy                           0.55       200
#    macro avg       0.53      0.53      0.52       200
# weighted avg       0.54      0.55      0.53       200
#
# 新數據的預測準確率: 0.55
# 0.5137032129032258
# 最近鄰居中預測值為1的前5筆索引:
# [33, 34, 71, 18, 119]
# 2033    可成
# 2034    長榮
# 2071     英業達
# 2018    矽品
# 2119     建興電
# Name: 簡稱, dtype: object
# 2033   -66.5847
# 2034   -43.4687
# 2071   -44.0217
# 2018   -45.9272
# 2119   -45.8987
# Name: Return, dtype: float64
# 0.5081979999999999
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[90 27]
#  [57 26]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.61      0.77      0.68       117
#            1       0.49      0.31      0.38        83
#
#     accuracy                           0.58       200
#    macro avg       0.55      0.54      0.53       200
# weighted avg       0.56      0.58      0.56       200
#
# 新數據的預測準確率: 0.58
# 2.0827213018867923
# 最近鄰居中預測值為1的前5筆索引:
# [2, 40, 106, 111, 25]
# 2202     中華電
# 2240    力成
# 2306    世界
# 2311     大聯大
# 2225     統一超
# Name: 簡稱, dtype: object
# 2202     11.8788
# 2240    116.3248
# 2306    122.3329
# 2311    270.3226
# 2225     12.9840
# Name: Return, dtype: float64
# 2.0676862
# {1997: 0.8488394042553191, 1998: 1.3429210285714286, 1999: 0.6537566363636365, 2000: 1.297981346153846, 2001: 1.0521956451612904, 2002: 1.3029606097560975, 2003: 1.1018471105263157, 2004: 1.0557905779411765, 2005: 1.2958260027586206, 2007: 0.5137032129032258, 2008: 2.0827213018867923}
# 年均化複利為:0.19443968992839114
#
#
# {1997: 0.934221, 1998: 1.3472066, 1999: 0.46224619999999994, 2000: 1.4142562, 2001: 0.889576, 2002: 1.2323274, 2003: 1.08753246, 2004: 0.9006158, 2005: 1.276544, 2007: 0.5081979999999999, 2008: 2.0676862}
# 年均化複利為:0.10773006079890622
# ori sum2:1.1850306687879684
# test years have:11
# after sum2:0.10773006079890622
