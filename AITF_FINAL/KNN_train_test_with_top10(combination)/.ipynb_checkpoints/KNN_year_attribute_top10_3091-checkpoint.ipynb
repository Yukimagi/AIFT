# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

csv_file_path='top200_training.xls'
#記得pip install xlrd
df = pd.read_excel(csv_file_path)
#df.head()

# %%
from itertools import product
from itertools import combinations


# 將年月轉換為日期型數據
df['年月'] = pd.to_datetime(df['年月'], format='%Y%m')

# 獲取所有不同的年份
all_years = ['1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008']

# 開始的欄位
start_column = '1997'

# 開始欄位的索引
start_index = all_years.index(start_column)

# 創建一個字典來保存結果
year_combinations_dict = {}

# 生成所有可能的欄位組合
for i in range(1, len(all_years) - start_index + 1):
    for subset in combinations(all_years[start_index:], i):
        selected_columns = list(subset)
        # 將結果存入字典
        year_combinations_dict[len(year_combinations_dict) + 1] = selected_columns

# 打開一個檔案來保存結果
with open('year_combinations.txt', 'w') as file:
    # 遍歷字典，將結果寫入檔案
    for key, value in year_combinations_dict.items():
        file.write(f"Key: {key}, Selected year: {value}\n")
        # 在這裡進行你的分析或模型擬合等操作
        # ...
        file.write("\n" + "="*40 + "\n")

# 提示保存成功
print("Results saved to 'year_combinations.txt'")
# Out:
# Results saved to 'year_combinations.txt'

# %%
from itertools import combinations
from sklearn.model_selection import train_test_split
import json
columns_comb1=['股價淨值比', '股價營收比', 'M營業利益成長率', 'M稅後淨利成長率']
columns_comb2=['股價淨值比', 'M淨值報酬率─稅後', '資產報酬率ROA', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M稅後淨利成長率']
columns_comb3=['股價淨值比', '利潤邊際NPM', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M營業利益成長率', 'M稅後淨利成長率']
columns_comb4=['股價營收比', '營業利益率OPM', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M營業利益成長率', 'M稅後淨利成長率']
columns_comb5=['本益比', '股價淨值比', '股價營收比', 'M淨值報酬率─稅後', '資產報酬率ROA', 'M存貨週轉率 (次)', 'M營業利益成長率']
columns_comb6=['股價淨值比', '股價營收比', 'M淨值報酬率─稅後', '資產報酬率ROA', 'M流動比率', 'M速動比率', 'M應收帳款週轉次']
columns_comb7=['本益比', '股價淨值比', '股價營收比', '資產報酬率ROA', '營業利益率OPM', '利潤邊際NPM', 'M流動比率', 'M應收帳款週轉次', 'M營業利益成長率']
columns_comb8=['本益比', '股價淨值比', '股價營收比', 'M淨值報酬率─稅後', '資產報酬率ROA', '利潤邊際NPM', '負債/淨值比', 'M流動比率', 'M速動比率', 'M營業利益成長率', 'M稅後淨利成長率']
columns_comb9=['股價營收比', '營業利益率OPM', '負債/淨值比', 'M速動比率', 'M存貨週轉率 (次)', 'M營業利益成長率', 'M稅後淨利成長率']
columns_comb10=['本益比', '股價淨值比', '股價營收比', '營業利益率OPM', '利潤邊際NPM', 'M流動比率', 'M速動比率', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M營業利益成長率', 'M稅後淨利成長率']
column_combinations_dict = {}
columns_combinations = [columns_comb1, columns_comb2, columns_comb3, columns_comb4, columns_comb5, columns_comb6, columns_comb7, columns_comb8, columns_comb9, columns_comb10]

for i, columns_comb in enumerate(columns_combinations, start=1):
    column_combinations_dict[i] = columns_comb
print(column_combinations_dict)
# 將字典保存到.txt文件
file_path = 'column_combinations_KNN_train.txt'

with open(file_path, 'w', encoding='utf-8') as file:
    json.dump(column_combinations_dict, file, ensure_ascii=False)
print('Results saved to column_combinations_KNN_train.txt')
# Out:
# {1: ['股價淨值比', '股價營收比', 'M營業利益成長率', 'M稅後淨利成長率'], 2: ['股價淨值比', 'M淨值報酬率─稅後', '資產報酬率ROA', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M稅後淨利成長率'], 3: ['股價淨值比', '利潤邊際NPM', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M營業利益成長率', 'M稅後淨利成長率'], 4: ['股價營收比', '營業利益率OPM', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M營業利益成長率', 'M稅後淨利成長率'], 5: ['本益比', '股價淨值比', '股價營收比', 'M淨值報酬率─稅後', '資產報酬率ROA', 'M存貨週轉率 (次)', 'M營業利益成長率'], 6: ['股價淨值比', '股價營收比', 'M淨值報酬率─稅後', '資產報酬率ROA', 'M流動比率', 'M速動比率', 'M應收帳款週轉次'], 7: ['本益比', '股價淨值比', '股價營收比', '資產報酬率ROA', '營業利益率OPM', '利潤邊際NPM', 'M流動比率', 'M應收帳款週轉次', 'M營業利益成長率'], 8: ['本益比', '股價淨值比', '股價營收比', 'M淨值報酬率─稅後', '資產報酬率ROA', '利潤邊際NPM', '負債/淨值比', 'M流動比率', 'M速動比率', 'M營業利益成長率', 'M稅後淨利成長率'], 9: ['股價營收比', '營業利益率OPM', '負債/淨值比', 'M速動比率', 'M存貨週轉率 (次)', 'M營業利益成長率', 'M稅後淨利成長率'], 10: ['本益比', '股價淨值比', '股價營收比', '營業利益率OPM', '利潤邊際NPM', 'M流動比率', 'M速動比率', 'M存貨週轉率 (次)', 'M應收帳款週轉次', 'M營業利益成長率', 'M稅後淨利成長率']}
# Results saved to column_combinations_KNN_train.txt

# %%
max_ret=3.9601632488342764
ans={}
list_ans=[]
#選擇特定欄位分析
from sklearn.preprocessing import StandardScaler
from itertools import islice

start_index = 3091  # 第3001筆資料的索引
end_index = 4093  # 最後一筆資料的索引

selected_range = islice(year_combinations_dict.items(), start_index, end_index + 1)

#selected_range = islice(year_combinations_dict.items(), 4094) #4094是所有可用來訓練的年份組合
cols=39090

with open('KNN_train_test_result_30000.txt', 'a') as file:
    for key, selected_years in selected_range:
        
        # 選擇訓練集年分
        train_years = [int(year) for year in selected_years]
        #print(train_years)

        #print("---------------------")
        # 選擇測試集年分
        test_years = [int(year) for year in all_years if year not in selected_years]
        print(f'總共有test year:{len(test_years)}')
        
        # 根據年份選擇訓練集
        train_data = df[df['年月'].dt.year.isin(train_years)]
        print(f"Number of rows in train_data: {len(train_data)}")
        #print(train_data)
        
        # 排除指定列，並標準化
        #columns_to_exclude = ['簡稱', '證券代碼', '年月', 'ReturnMean_year_Label', 'Return']
        #features_to_scale_train = train_data.drop(columns=columns_to_exclude)
        #features_to_scale_test = test_data.drop(columns=columns_to_exclude)
    
        for col in range (1,11):#取top10組合
            cols=cols+1
            list_ans=[]
            # 指定要選擇的欄位
            selected_columns = column_combinations_dict[col]
            list_ans.append(selected_columns)
            
            # 選擇指定的欄位
            features_to_scale_train = train_data[selected_columns]

            scaler = StandardScaler()
            scaled_features_train = scaler.fit_transform(features_to_scale_train)
            
            # 轉換為dataframe
            df_feat_train = pd.DataFrame(scaled_features_train, columns=features_to_scale_train.columns)
            
        #---------------------------------------------------------------------------------------------
            # 分割訓練集和測試集
            X_train = df_feat_train
            y_train = train_data['ReturnMean_year_Label']
            
            X_train, X_test, y_train, y_test = train_test_split(X_train,y_train,test_size=0.3,random_state=101)
  
        #--------------------------------------------------------------------------------------------------
            error_rate = []
            from sklearn.neighbors import KNeighborsClassifier
            for i in range(1, 100):
                knn = KNeighborsClassifier(n_neighbors=i, p=2, weights='distance', algorithm='brute')
                knn.fit(X_train, y_train)
                pred_i = knn.predict(X_test)
                error_rate.append(np.mean(pred_i != y_test))

            # 將k=1~60的錯誤率製圖畫出。k=23之後，錯誤率就在5-6%之間震盪。
            #plt.figure(figsize=(10, 6))
            #plt.plot(range(1, 100), error_rate, color='blue', linestyle='dashed', marker='o', markerfacecolor='red', markersize=10)
            #plt.title('Error Rate vs. K Value')
            #plt.xlabel('K')
            #plt.ylabel('Error Rate')
            #plt.show()
        #--------------------------------------------------------------------------------------------------
            min_error = min(error_rate)
            optimal_k = error_rate.index(min_error) + 1  # Adding 1 because Python indexing starts from 0

            print(f"Optimal k value for minimum error rate: {optimal_k}")
            #print(f"Minimum Error Rate: {min_error}")
            list_ans.append(optimal_k)
        #--------------------------------------------------------------------------------------------------
            #使用KNN演算法
            clf=KNeighborsClassifier(n_neighbors=optimal_k,p=2,weights='distance',algorithm='brute')
            clf.fit(X_train,y_train)
        #--------------------------------------------------------------------------------------------------
            predict_label1={}
            predict_k_pre5={}
        #--------------------------------------------------------------------------------------------------

            for year in test_years:
                
                # 選擇特定年份的 test_data
                test_data = df[df['年月'].dt.year == year]
                print(year)
                #print(test_data)
                print(f"Number of rows in test_data: {len(test_data)}")
                
                # 選擇指定的欄位
                features_to_scale_test = test_data[selected_columns]
                # 使用之前訓練好的標準化物件進行標準化
                scaled_features_test = scaler.transform(features_to_scale_test)
                # 將標準化後的特徵資料轉換為 DataFrame
                df_feat_test = pd.DataFrame(scaled_features_test, columns=features_to_scale_test.columns)

                
                # 使用已經訓練好的模型進行預測
                predictions_new = clf.predict(df_feat_test)

                #------------------------------
                #測試KNN演算法的好壞
                from sklearn.metrics import classification_report,confusion_matrix
                #將實際類別分為真正例（True Positive）、真負例（True Negative）、偽正例（False Positive）和偽負例（False Negative）
                print('confusion_matrix:')
                print(confusion_matrix(test_data['ReturnMean_year_Label'],predictions_new))

                #模型的精確度、召回率、F1分數和支持數等指標，用來評估模型對於每個類別的預測性能。
                print('classification_report')
                print(classification_report(test_data['ReturnMean_year_Label'],predictions_new))

                # 比較預測結果
                accuracy_new = clf.score(df_feat_test, test_data['ReturnMean_year_Label'])
                print(f'新數據的預測準確率: {accuracy_new}')
                #---------------------------------------
                #print(predictions_new)

                #predicted_positive_indices = (predictions_new == 1)

                # 獲取股票名稱
                #predicted_positive_stock_names = new.loc[predicted_positive_indices, '簡稱']

                # 設定檔案名稱
                #output_file_name = 'selected_stocks_1998.csv'

                # 匯出成 CSV 檔案
                #predicted_positive_stock_names.to_csv(output_file_name, index=True)

                # 預測要投資的股票名稱
                #print("選擇股票:")
                #print(predicted_positive_stock_names)


                # 選擇預測為1的股票
                selected_stocks = test_data[predictions_new == 1]

                # 計算return
                stock_returns = selected_stocks['Return']

                portfolio_returns = (stock_returns.mean()/100)+1

                print(portfolio_returns)
                predict_label1[year]=portfolio_returns

                # 使用 kneighbors 方法取得最近鄰居的索引和距離
                distances, indices = clf.kneighbors(df_feat_test, n_neighbors=5)

                # 合併所有測試樣本的最近鄰居索引
                all_indices = np.concatenate(indices)
                all_distances = np.concatenate(distances)

                # 將索引和距離組合成一個 2D 陣列，方便排序
                combined_data = np.column_stack((all_indices, all_distances))

                # 按照距離重新排序
                sorted_combined_data = combined_data[np.argsort(combined_data[:, 1])]

                # 選取最近鄰居中預測值為1的前5筆，且不重複
                selected_indices = set()
                i = 0
                while len(selected_indices) < 5 and i < len(sorted_combined_data):
                    index = int(sorted_combined_data[i, 0])
                    if(index>=200 and index<400):
                        index=index-200
                    elif(index>=400 and index<600):
                        index=index-400
                    elif(index>=600 and index<800):
                        index=index-600
                    elif(index>=800 and index<1000):
                        index=index-800
                    elif(index>=1000 and index<1200):
                        index=index-1000
                    elif(index>=1200 and index<1400):
                        index=index-1200
                    elif(index>=1400 and index<1600):
                        index=index-1400
                    elif(index>=1600 and index<1800):
                        index=index-1600
                    elif(index>=1800 and index<2000):
                        index=index-1800
                    elif(index>=2000 and index<2200):
                        index=index-2000
                    elif(index>=2200 and index<2400):
                        index=index-2200
                    elif(index>=2400 and index<2600):
                        index=index-2400
                    elif(index>=2600 and index<2800):
                        index=index-2600
                    elif(index>=2800 and index<3000):
                        index=index-2800
                    elif(index>=3000 and index<3200):
                        index=index-3000
                    prediction = predictions_new[index]
                    if prediction == 1 and index not in selected_indices:
                        selected_indices.add(index)
                    i += 1
                        

                # 將選取的索引轉換成列表
                selected_indices_list = list(selected_indices)

                # 打印最近鄰居中預測值為1的前5筆索引
                print("最近鄰居中預測值為1的前5筆索引:")
                print(selected_indices_list)
                select = test_data
                # 獲取股票名稱
                selects_stock = select.iloc[selected_indices_list]['簡稱']
                print(selects_stock)
                # 獲取股票return
                selects_ret = select.iloc[selected_indices_list]['Return']
                print(selects_ret)
                with open(f'selected_stock_KNN_train_30000/{cols}.txt', 'a') as stockfile:
                    stockfile.write(selects_stock.to_string())
                    stockfile.write('\n')
                    stockfile.write(selects_ret.to_string())
                # 計算return
                stock_returns = (selects_ret.mean() / 100)+1
                portfolio_returns = stock_returns
                print(portfolio_returns)
                predict_k_pre5[year] = portfolio_returns
                #print(stock_returns)
            sum1=1
            sum2=1
            print(predict_label1)
            for k in predict_label1.keys():
                if not (predict_label1[k]==0):
                    sum1=predict_label1[k]*sum1
            print(f'年均化複利為:{sum1/int(len(test_years))}')
            print('\n')
            print(predict_k_pre5)
            for k in predict_k_pre5.keys():
                if not (predict_k_pre5[k]==0):
                    sum2=predict_k_pre5[k]*sum2
            print(f'年均化複利為:{sum2/int(len(test_years))}')
            #list_ans.append(sum2/len(test_data)/200)
            print(f'ori sum2:{sum2}')
            print(f'test years have:{int(len(test_years))}')
            sum2=sum2/int(len(test_years))
            print(f'after sum2:{sum2}')
            list_ans.append(sum2)
            ans[cols]=list_ans
            file.write(f'{cols}:{list_ans}\n\n')
            file.flush()  # 強制將緩衝區內容寫入檔案
            if(sum2>max_ret):
                max_ret=sum2
                with open('max_KNN_train_30000.txt', 'w') as maxfile:
                    maxfile.write(f'max:train_year:{train_years},test_year:{test_years}:{cols}:{list_ans}\n\n')
                    maxfile.flush()  # 強制將緩衝區內容寫入檔案
# Out:
# 總共有test year:5
# Number of rows in train_data: 1400
# Optimal k value for minimum error rate: 57
# 1997
# Number of rows in test_data: 200
# confusion_matrix:
# [[81 28]
#  [57 34]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.74      0.66       109
#            1       0.55      0.37      0.44        91
#
#     accuracy                           0.57       200
#    macro avg       0.57      0.56      0.55       200
# weighted avg       0.57      0.57      0.56       200
#
# 新數據的預測準確率: 0.575
# 0.9363147258064516
# 最近鄰居中預測值為1的前5筆索引:
# [129, 100, 38, 72, 45]
# 129    盛餘
# 100    正隆
# 38     福懋
# 72     凌陽
# 45     南紡
# Name: 簡稱, dtype: object
# 129   -44.1894
# 100   -33.2625
# 38    -19.8825
# 72     21.4721
# 45    -26.0263
# Name: Return, dtype: float64
# 0.7962228
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[57 70]
#  [30 43]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.66      0.45      0.53       127
#            1       0.38      0.59      0.46        73
#
#     accuracy                           0.50       200
#    macro avg       0.52      0.52      0.50       200
# weighted avg       0.55      0.50      0.51       200
#
# 新數據的預測準確率: 0.5
# 1.3723131504424777
# 最近鄰居中預測值為1的前5筆索引:
# [161, 129, 5, 133, 187]
# 761    燦坤
# 729    豐興
# 605    台塑
# 733    聯華
# 787     三商電
# Name: 簡稱, dtype: object
# 761    157.7938
# 729    -19.5652
# 605    -21.7514
# 733    -18.3807
# 787     41.6107
# Name: Return, dtype: float64
# 1.2794144
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[103  15]
#  [ 30  52]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.77      0.87      0.82       118
#            1       0.78      0.63      0.70        82
#
#     accuracy                           0.78       200
#    macro avg       0.78      0.75      0.76       200
# weighted avg       0.78      0.78      0.77       200
#
# 新數據的預測準確率: 0.775
# 1.2573968358208956
# 最近鄰居中預測值為1的前5筆索引:
# [6, 46, 183, 152, 155]
# 806    南亞
# 846    中華
# 983    台聚
# 952    億豐
# 955     京元電
# Name: 簡稱, dtype: object
# 806     22.4979
# 846    191.9494
# 983     41.6667
# 952     96.6168
# 955     10.2067
# Name: Return, dtype: float64
# 1.725875
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[71 45]
#  [39 45]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.65      0.61      0.63       116
#            1       0.50      0.54      0.52        84
#
#     accuracy                           0.58       200
#    macro avg       0.57      0.57      0.57       200
# weighted avg       0.58      0.58      0.58       200
#
# 新數據的預測準確率: 0.58
# 1.3790007610000001
# 最近鄰居中預測值為1的前5筆索引:
# [197, 109, 77, 117, 125]
# 1197    超豐
# 1109    豐泰
# 1077    和泰
# 1117    燦坤
# 1125    大陸
# Name: 簡稱, dtype: object
# 1197    71.9298
# 1109    27.7822
# 1077    44.8034
# 1117    12.1743
# 1125    31.6045
# Name: Return, dtype: float64
# 1.3765884
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[89 28]
#  [52 31]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.63      0.76      0.69       117
#            1       0.53      0.37      0.44        83
#
#     accuracy                           0.60       200
#    macro avg       0.58      0.57      0.56       200
# weighted avg       0.59      0.60      0.58       200
#
# 新數據的預測準確率: 0.6
# 2.173836830508475
# 最近鄰居中預測值為1的前5筆索引:
# [162, 105, 119, 57, 159]
# 2362    統寶
# 2305    友訊
# 2319     建興電
# 2257     英業達
# 2359    環電
# Name: 簡稱, dtype: object
# 2362    175.9709
# 2305     70.3840
# 2319    153.7697
# 2257    140.0832
# 2359    162.3377
# Name: Return, dtype: float64
# 2.405091
# {1997: 0.9363147258064516, 2000: 1.3723131504424777, 2001: 1.2573968358208956, 2002: 1.3790007610000001, 2008: 2.173836830508475}
# 年均化複利為:0.968654468035753
#
#
# {1997: 0.7962228, 2000: 1.2794144, 2001: 1.725875, 2002: 1.3765884, 2008: 2.405091}
# 年均化複利為:1.1641817751439407
# ori sum2:5.820908875719704
# test years have:5
# after sum2:1.1641817751439407
# Optimal k value for minimum error rate: 30
# 1997
# Number of rows in test_data: 200
# confusion_matrix:
# [[78 31]
#  [60 31]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.57      0.72      0.63       109
#            1       0.50      0.34      0.41        91
#
#     accuracy                           0.55       200
#    macro avg       0.53      0.53      0.52       200
# weighted avg       0.54      0.55      0.53       200
#
# 新數據的預測準確率: 0.545
# 0.8594966774193549
# 最近鄰居中預測值為1的前5筆索引:
# [72, 108, 56, 185, 152]
# 72     凌陽
# 108    新保
# 56     藍天
# 185    宏碁
# 152    亞聚
# Name: 簡稱, dtype: object
# 72     21.4721
# 108   -28.3389
# 56    -49.1160
# 185    15.1993
# 152   -16.2685
# Name: Return, dtype: float64
# 0.885896
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[59 68]
#  [43 30]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.46      0.52       127
#            1       0.31      0.41      0.35        73
#
#     accuracy                           0.45       200
#    macro avg       0.44      0.44      0.43       200
# weighted avg       0.48      0.45      0.46       200
#
# 新數據的預測準確率: 0.445
# 1.3296142551020407
# 最近鄰居中預測值為1的前5筆索引:
# [64, 135, 83, 23, 24]
# 664    微星
# 735    飛宏
# 683    智邦
# 623    凌陽
# 624    華航
# Name: 簡稱, dtype: object
# 664    401.5549
# 735    155.9271
# 683    257.5379
# 623     13.1168
# 624    -33.1144
# Name: Return, dtype: float64
# 2.5900445999999997
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[105  13]
#  [ 41  41]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.72      0.89      0.80       118
#            1       0.76      0.50      0.60        82
#
#     accuracy                           0.73       200
#    macro avg       0.74      0.69      0.70       200
# weighted avg       0.74      0.73      0.72       200
#
# 新數據的預測準確率: 0.73
# 1.2479520370370372
# 最近鄰居中預測值為1的前5筆索引:
# [139, 177, 115, 187, 30]
# 939    裕融
# 977    科風
# 915    豐泰
# 987    嘉泥
# 830     統一超
# Name: 簡稱, dtype: object
# 939    -5.2083
# 977   -42.7225
# 915    21.0271
# 987    98.0000
# 830   -19.5689
# Name: Return, dtype: float64
# 1.1030548
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[75 41]
#  [43 41]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.64      0.65      0.64       116
#            1       0.50      0.49      0.49        84
#
#     accuracy                           0.58       200
#    macro avg       0.57      0.57      0.57       200
# weighted avg       0.58      0.58      0.58       200
#
# 新數據的預測準確率: 0.58
# 1.377792219512195
# 最近鄰居中預測值為1的前5筆索引:
# [6, 102, 135, 81, 125]
# 1006    中鋼
# 1102     永豐餘
# 1135    中鴻
# 1081    友訊
# 1125    大陸
# Name: 簡稱, dtype: object
# 1006     56.1449
# 1102     59.5365
# 1135    105.4054
# 1081     65.8381
# 1125     31.6045
# Name: Return, dtype: float64
# 1.6370588000000001
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[66 51]
#  [52 31]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.56      0.56      0.56       117
#            1       0.38      0.37      0.38        83
#
#     accuracy                           0.48       200
#    macro avg       0.47      0.47      0.47       200
# weighted avg       0.48      0.48      0.48       200
#
# 新數據的預測準確率: 0.485
# 1.9652441585365854
# 最近鄰居中預測值為1的前5筆索引:
# [65, 139, 155, 93, 126]
# 2265    茂迪
# 2339    中工
# 2355    金寶
# 2293     統一實
# 2326     英華達
# Name: 簡稱, dtype: object
# 2265    141.4094
# 2339     36.8504
# 2355     57.0248
# 2293     34.8730
# 2326     82.5237
# Name: Return, dtype: float64
# 1.7053626
# {1997: 0.8594966774193549, 2000: 1.3296142551020407, 2001: 1.2479520370370372, 2002: 1.377792219512195, 2008: 1.9652441585365854}
# 年均化複利為:0.7723212719699345
#
#
# {1997: 0.885896, 2000: 2.5900445999999997, 2001: 1.1030548, 2002: 1.6370588000000001, 2008: 1.7053626}
# 年均化複利為:1.4131819472238978
# ori sum2:7.065909736119489
# test years have:5
# after sum2:1.4131819472238978
# Optimal k value for minimum error rate: 11
# 1997
# Number of rows in test_data: 200
# confusion_matrix:
# [[70 39]
#  [53 38]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.57      0.64      0.60       109
#            1       0.49      0.42      0.45        91
#
#     accuracy                           0.54       200
#    macro avg       0.53      0.53      0.53       200
# weighted avg       0.53      0.54      0.53       200
#
# 新數據的預測準確率: 0.54
# 0.8487537532467532
# 最近鄰居中預測值為1的前5筆索引:
# [0, 35, 42, 108, 23]
# 0       台積電
# 35     陽明
# 42     正新
# 108    新保
# 23     國建
# Name: 簡稱, dtype: object
# 0      -6.3648
# 35     -3.3784
# 42     -8.7819
# 108   -28.3389
# 23    -41.5319
# Name: Return, dtype: float64
# 0.8232082
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[59 68]
#  [38 35]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.61      0.46      0.53       127
#            1       0.34      0.48      0.40        73
#
#     accuracy                           0.47       200
#    macro avg       0.47      0.47      0.46       200
# weighted avg       0.51      0.47      0.48       200
#
# 新數據的預測準確率: 0.47
# 1.366545495145631
# 最近鄰居中預測值為1的前5筆索引:
# [70, 48, 87, 24, 25]
# 670    友訊
# 648    瑞昱
# 687    正崴
# 624    華航
# 625    華新
# Name: 簡稱, dtype: object
# 670    135.5422
# 648    199.0037
# 687    101.7535
# 624    -33.1144
# 625    -29.4118
# Name: Return, dtype: float64
# 1.7475464
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[92 26]
#  [39 43]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.70      0.78      0.74       118
#            1       0.62      0.52      0.57        82
#
#     accuracy                           0.68       200
#    macro avg       0.66      0.65      0.65       200
# weighted avg       0.67      0.68      0.67       200
#
# 新數據的預測準確率: 0.675
# 1.119767231884058
# 最近鄰居中預測值為1的前5筆索引:
# [193, 162, 134, 145, 23]
# 993    東森
# 962    福聚
# 934    藍天
# 945    新保
# 823    瑞昱
# Name: 簡稱, dtype: object
# 993   -13.6038
# 962    24.5744
# 934   -43.5801
# 945   -24.6269
# 823   -29.2174
# Name: Return, dtype: float64
# 0.8270924
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[74 42]
#  [43 41]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.63      0.64      0.64       116
#            1       0.49      0.49      0.49        84
#
#     accuracy                           0.57       200
#    macro avg       0.56      0.56      0.56       200
# weighted avg       0.57      0.57      0.57       200
#
# 新數據的預測準確率: 0.575
# 1.3429817831325301
# 最近鄰居中預測值為1的前5筆索引:
# [36, 105, 172, 81, 56]
# 1036     英業達
# 1105    豐興
# 1172    廣宇
# 1081    友訊
# 1056    精英
# Name: 簡稱, dtype: object
# 1036     9.7735
# 1105    23.2274
# 1172    15.9409
# 1081    65.8381
# 1056   -25.2116
# Name: Return, dtype: float64
# 1.1791366
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[71 46]
#  [53 30]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.57      0.61      0.59       117
#            1       0.39      0.36      0.38        83
#
#     accuracy                           0.51       200
#    macro avg       0.48      0.48      0.48       200
# weighted avg       0.50      0.51      0.50       200
#
# 新數據的預測準確率: 0.505
# 2.017924552631579
# 最近鄰居中預測值為1的前5筆索引:
# [36, 70, 74, 85, 57]
# 2236    寶成
# 2270    東元
# 2274    群光
# 2285    正崴
# 2257     英業達
# Name: 簡稱, dtype: object
# 2236     86.0428
# 2270     43.5897
# 2274    165.6756
# 2285    120.8022
# 2257    140.0832
# Name: Return, dtype: float64
# 2.112387
# {1997: 0.8487537532467532, 2000: 1.366545495145631, 2001: 1.119767231884058, 2002: 1.3429817831325301, 2008: 2.017924552631579}
# 年均化複利為:0.7039447899701374
#
#
# {1997: 0.8232082, 2000: 1.7475464, 2001: 0.8270924, 2002: 1.1791366, 2008: 2.112387}
# 年均化複利為:0.5927342671938847
# ori sum2:2.9636713359694236
# test years have:5
# after sum2:0.5927342671938847
# Optimal k value for minimum error rate: 54
# 1997
# Number of rows in test_data: 200
# confusion_matrix:
# [[91 18]
#  [70 21]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.57      0.83      0.67       109
#            1       0.54      0.23      0.32        91
#
#     accuracy                           0.56       200
#    macro avg       0.55      0.53      0.50       200
# weighted avg       0.55      0.56      0.51       200
#
# 新數據的預測準確率: 0.56
# 0.8558271282051282
# 最近鄰居中預測值為1的前5筆索引:
# [108, 114, 51, 24, 153]
# 108    新保
# 114    豐泰
# 51     聯強
# 24     中華
# 153    統領
# Name: 簡稱, dtype: object
# 108   -28.3389
# 114    -9.4761
# 51     46.0888
# 24      7.0642
# 153   -12.9635
# Name: Return, dtype: float64
# 1.004749
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[91 36]
#  [53 20]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.63      0.72      0.67       127
#            1       0.36      0.27      0.31        73
#
#     accuracy                           0.56       200
#    macro avg       0.49      0.50      0.49       200
# weighted avg       0.53      0.56      0.54       200
#
# 新數據的預測準確率: 0.555
# 1.3422559285714284
# 最近鄰居中預測值為1的前5筆索引:
# [194, 101, 173, 153, 191]
# 794     劍湖山
# 701    毅嘉
# 773    特力
# 753    兆赫
# 791    廣宇
# Name: 簡稱, dtype: object
# 794    -33.5557
# 701     -3.1608
# 773     63.6111
# 753     44.9336
# 791    114.3284
# Name: Return, dtype: float64
# 1.3723132
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[105  13]
#  [ 58  24]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.64      0.89      0.75       118
#            1       0.65      0.29      0.40        82
#
#     accuracy                           0.65       200
#    macro avg       0.65      0.59      0.58       200
# weighted avg       0.65      0.65      0.61       200
#
# 新數據的預測準確率: 0.645
# 1.1978509459459459
# 最近鄰居中預測值為1的前5筆索引:
# [8, 46, 145, 23, 183]
# 808    台塑
# 846    中華
# 945    新保
# 823    瑞昱
# 983    台聚
# Name: 簡稱, dtype: object
# 808     54.4404
# 846    191.9494
# 945    -24.6269
# 823    -29.2174
# 983     41.6667
# Name: Return, dtype: float64
# 1.4684244
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[83 33]
#  [64 20]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.56      0.72      0.63       116
#            1       0.38      0.24      0.29        84
#
#     accuracy                           0.52       200
#    macro avg       0.47      0.48      0.46       200
# weighted avg       0.49      0.52      0.49       200
#
# 新數據的預測準確率: 0.515
# 1.317780433962264
# 最近鄰居中預測值為1的前5筆索引:
# [1, 176, 145, 89, 57]
# 1001     中華電
# 1176    晶華
# 1145    裕民
# 1089     晶豪科
# 1057     普立爾
# Name: 簡稱, dtype: object
# 1001      3.6275
# 1176     45.9056
# 1145    203.0769
# 1089    -19.0821
# 1057     21.4225
# Name: Return, dtype: float64
# 1.5099008
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[81 36]
#  [64 19]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.56      0.69      0.62       117
#            1       0.35      0.23      0.28        83
#
#     accuracy                           0.50       200
#    macro avg       0.45      0.46      0.45       200
# weighted avg       0.47      0.50      0.48       200
#
# 新數據的預測準確率: 0.5
# 1.889679854545455
# 最近鄰居中預測值為1的前5筆索引:
# [110, 174, 54, 184, 95]
# 2310    台船
# 2374    神腦
# 2254    陽明
# 2384    益航
# 2295    中鼎
# Name: 簡稱, dtype: object
# 2310    72.2884
# 2374    63.7755
# 2254    21.7435
# 2384    84.8863
# 2295    53.1234
# Name: Return, dtype: float64
# 1.5916342
# {1997: 0.8558271282051282, 2000: 1.3422559285714284, 2001: 1.1978509459459459, 2002: 1.317780433962264, 2008: 1.889679854545455}
# 年均化複利為:0.6853074350287536
#
#
# {1997: 1.004749, 2000: 1.3723132, 2001: 1.4684244, 2002: 1.5099008, 2008: 1.5916342}
# 年均化複利為:0.9731596398306739
# ori sum2:4.865798199153369
# test years have:5
# after sum2:0.9731596398306739
# Optimal k value for minimum error rate: 42
# 1997
# Number of rows in test_data: 200
# confusion_matrix:
# [[97 12]
#  [62 29]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.61      0.89      0.72       109
#            1       0.71      0.32      0.44        91
#
#     accuracy                           0.63       200
#    macro avg       0.66      0.60      0.58       200
# weighted avg       0.65      0.63      0.59       200
#
# 新數據的預測準確率: 0.63
# 0.9365499268292683
# 最近鄰居中預測值為1的前5筆索引:
# [2, 4, 42, 108, 24]
# 2      中鋼
# 4      華碩
# 42     正新
# 108    新保
# 24     中華
# Name: 簡稱, dtype: object
# 2      -9.2224
# 4      46.2737
# 42     -8.7819
# 108   -28.3389
# 24      7.0642
# Name: Return, dtype: float64
# 1.0139894
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[71 56]
#  [43 30]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.62      0.56      0.59       127
#            1       0.35      0.41      0.38        73
#
#     accuracy                           0.51       200
#    macro avg       0.49      0.49      0.48       200
# weighted avg       0.52      0.51      0.51       200
# 新數據的預測準確率: 0.505
# 1.3461960465116278
# 最近鄰居中預測值為1的前5筆索引:
# [69, 70, 93, 23, 29]
# 669    和泰
# 670    友訊
# 693    世平
# 623    凌陽
# 629     英業達
# Name: 簡稱, dtype: object
# 669    -21.8910
# 670    135.5422
# 693     45.8974
# 623     13.1168
# 629     13.5381
# Name: Return, dtype: float64
# 1.372407
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[105  13]
#  [ 52  30]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.67      0.89      0.76       118
#            1       0.70      0.37      0.48        82
#
#     accuracy                           0.68       200
#    macro avg       0.68      0.63      0.62       200
# weighted avg       0.68      0.68      0.65       200
#
# 新數據的預測準確率: 0.675
# 1.2955845813953488
# 最近鄰居中預測值為1的前5筆索引:
# [169, 46, 47, 182, 187]
# 969    立榮
# 846    中華
# 847    裕隆
# 982    中碳
# 987    嘉泥
# Name: 簡稱, dtype: object
# 969   -100.0000
# 846    191.9494
# 847    161.3553
# 982     28.9879
# 987     98.0000
# Name: Return, dtype: float64
# 1.7605852
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[74 42]
#  [49 35]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.60      0.64      0.62       116
#            1       0.45      0.42      0.43        84
#
#     accuracy                           0.55       200
#    macro avg       0.53      0.53      0.53       200
# weighted avg       0.54      0.55      0.54       200
#
# 新數據的預測準確率: 0.545
# 1.3485482766233765
# 最近鄰居中預測值為1的前5筆索引:
# [133, 102, 139, 174, 175]
# 1133    遠雄
# 1102     永豐餘
# 1139    普誠
# 1174    晶電
# 1175    帆宣
# Name: 簡稱, dtype: object
# 1133    30.7607
# 1102    59.5365
# 1139   -12.9662
# 1174    50.9554
# 1175    15.1093
# Name: Return, dtype: float64
# 1.2867914
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[80 37]
#  [49 34]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.62      0.68      0.65       117
#            1       0.48      0.41      0.44        83
#
#     accuracy                           0.57       200
#    macro avg       0.55      0.55      0.55       200
# weighted avg       0.56      0.57      0.56       200
#
# 新數據的預測準確率: 0.57
# 2.0992478309859157
# 最近鄰居中預測值為1的前5筆索引:
# [65, 85, 53, 57, 155]
# 2265    茂迪
# 2285    正崴
# 2253     大立光
# 2257     英業達
# 2355    金寶
# Name: 簡稱, dtype: object
# 2265    141.4094
# 2285    120.8022
# 2253    116.2898
# 2257    140.0832
# 2355     57.0248
# Name: Return, dtype: float64
# 2.1512188
# {1997: 0.9365499268292683, 2000: 1.3461960465116278, 2001: 1.2955845813953488, 2002: 1.3485482766233765, 2008: 2.0992478309859157}
# 年均化複利為:0.9248370571269607
#
#
# {1997: 1.0139894, 2000: 1.372407, 2001: 1.7605852, 2002: 1.2867914, 2008: 2.1512188}
# 年均化複利為:1.3564260328847437
# ori sum2:6.782130164423719
# test years have:5
# after sum2:1.3564260328847437
# Optimal k value for minimum error rate: 76
# 1997
# Number of rows in test_data: 200
# confusion_matrix:
# [[94 15]
#  [69 22]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.86      0.69       109
#            1       0.59      0.24      0.34        91
#
#     accuracy                           0.58       200
#    macro avg       0.59      0.55      0.52       200
# weighted avg       0.58      0.58      0.53       200
#
# 新數據的預測準確率: 0.58
# 0.8870641891891893
# 最近鄰居中預測值為1的前5筆索引:
# [35, 42, 83, 58, 63]
# 35    陽明
# 42    正新
# 83    東鋼
# 58     統一實
# 63    神達
# Name: 簡稱, dtype: object
# 35    -3.3784
# 42    -8.7819
# 83   -30.7411
# 58   -25.0199
# 63    41.4634
# Name: Return, dtype: float64
# 0.9470842
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[67 60]
#  [49 24]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.53      0.55       127
#            1       0.29      0.33      0.31        73
#
#     accuracy                           0.46       200
#    macro avg       0.43      0.43      0.43       200
# weighted avg       0.47      0.46      0.46       200
#
# 新數據的預測準確率: 0.455
# 1.313624773809524
# 最近鄰居中預測值為1的前5筆索引:
# [128, 6, 105, 83, 19]
# 728    大榮
# 606    中鋼
# 705    新保
# 683    智邦
# 619     日月光
# Name: 簡稱, dtype: object
# 728    -31.3319
# 606    -22.2052
# 705     14.5299
# 683    257.5379
# 619     74.2887
# Name: Return, dtype: float64
# 1.5856388
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[105  13]
#  [ 48  34]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.69      0.89      0.77       118
#            1       0.72      0.41      0.53        82
#
#     accuracy                           0.69       200
#    macro avg       0.70      0.65      0.65       200
# weighted avg       0.70      0.69      0.67       200
#
# 新數據的預測準確率: 0.695
# 1.268347744680851
# 最近鄰居中預測值為1的前5筆索引:
# [65, 67, 99, 167, 149]
# 865    正新
# 867    D 復盛
# 899    燦坤
# 967    友尚
# 949    遠百
# Name: 簡稱, dtype: object
# 865    94.4010
# 867     7.1197
# 899    -7.1628
# 967    -7.5047
# 949    16.6282
# Name: Return, dtype: float64
# 1.2069628
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[79 37]
#  [56 28]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.68      0.63       116
#            1       0.43      0.33      0.38        84
#
#     accuracy                           0.54       200
#    macro avg       0.51      0.51      0.50       200
# weighted avg       0.52      0.54      0.52       200
#
# 新數據的預測準確率: 0.535
# 1.3109530923076922
# 最近鄰居中預測值為1的前5筆索引:
# [133, 105, 109, 142, 125]
# 1133    遠雄
# 1105    豐興
# 1109    豐泰
# 1142    全國
# 1125    大陸
# Name: 簡稱, dtype: object
# 1133    30.7607
# 1105    23.2274
# 1109    27.7822
# 1142     4.8171
# 1125    31.6045
# Name: Return, dtype: float64
# 1.2363838
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[81 36]
#  [62 21]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.57      0.69      0.62       117
#            1       0.37      0.25      0.30        83
#
#     accuracy                           0.51       200
#    macro avg       0.47      0.47      0.46       200
# weighted avg       0.48      0.51      0.49       200
#
# 新數據的預測準確率: 0.51
# 1.9823755614035088
# 最近鄰居中預測值為1的前5筆索引:
# [6, 105, 109, 47, 159]
# 2206    台塑
# 2305    友訊
# 2309     中光電
# 2247    福懋
# 2359    環電
# Name: 簡稱, dtype: object
# 2206     70.3833
# 2305     70.3840
# 2309    189.3970
# 2247     63.1100
# 2359    162.3377
# Name: Return, dtype: float64
# 2.111224
# {1997: 0.8870641891891893, 2000: 1.313624773809524, 2001: 1.268347744680851, 2002: 1.3109530923076922, 2008: 1.9823755614035088}
# 年均化複利為:0.768188500191742
#
#
# {1997: 0.9470842, 2000: 1.5856388, 2001: 1.2069628, 2002: 1.2363838, 2008: 2.111224}
# 年均化複利為:0.946246653188663
# ori sum2:4.731233265943315
# test years have:5
# after sum2:0.946246653188663
# Optimal k value for minimum error rate: 50
# 1997
# Number of rows in test_data: 200
# confusion_matrix:
# [[94 15]
#  [72 19]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.57      0.86      0.68       109
#            1       0.56      0.21      0.30        91
#
#     accuracy                           0.56       200
#    macro avg       0.56      0.54      0.49       200
# weighted avg       0.56      0.56      0.51       200
#
# 新數據的預測準確率: 0.565
# 0.8797862941176471
# 最近鄰居中預測值為1的前5筆索引:
# [2, 187, 24, 153, 59]
# 2      中鋼
# 187    巨大
# 24     中華
# 153    統領
# 59     光罩
# Name: 簡稱, dtype: object
# 2      -9.2224
# 187    57.0196
# 24      7.0642
# 153   -12.9635
# 59    -51.6712
# Name: Return, dtype: float64
# 0.9804534
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[70 57]
#  [49 24]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.55      0.57       127
#            1       0.30      0.33      0.31        73
#
#     accuracy                           0.47       200
#    macro avg       0.44      0.44      0.44       200
# weighted avg       0.48      0.47      0.48       200
#
# 新數據的預測準確率: 0.47
# 1.2118877530864198
# 最近鄰居中預測值為1的前5筆索引:
# [35, 174, 113, 189, 158]
# 635    東元
# 774    大成
# 713    和桐
# 789    昆盈
# 758    盛餘
# Name: 簡稱, dtype: object
# 635   -30.0532
# 774    11.3426
# 713    66.0714
# 789    72.3642
# 758   -11.0945
# Name: Return, dtype: float64
# 1.217261
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[101  17]
#  [ 47  35]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.68      0.86      0.76       118
#            1       0.67      0.43      0.52        82
#
#     accuracy                           0.68       200
#    macro avg       0.68      0.64      0.64       200
# weighted avg       0.68      0.68      0.66       200
#
# 新數據的預測準確率: 0.68
# 1.161865423076923
# 最近鄰居中預測值為1的前5筆索引:
# [2, 4, 51, 23, 185]
# 802     中華電
# 804     聯發科
# 851    長榮
# 823    瑞昱
# 985    健鼎
# Name: 簡稱, dtype: object
# 802     5.7753
# 804   -28.8091
# 851    80.0281
# 823   -29.2174
# 985   -25.0833
# Name: Return, dtype: float64
# 1.0053872
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[86 30]
#  [54 30]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.61      0.74      0.67       116
#            1       0.50      0.36      0.42        84
#
#     accuracy                           0.58       200
#    macro avg       0.56      0.55      0.54       200
# weighted avg       0.57      0.58      0.56       200
#
# 新數據的預測準確率: 0.58
# 1.3718121166666666
# 最近鄰居中預測值為1的前5筆索引:
# [35, 7, 77, 60, 61]
# 1035    統一
# 1007    台化
# 1077    和泰
# 1060    陽明
# 1061    福懋
# Name: 簡稱, dtype: object
# 1035     33.1845
# 1007     74.1454
# 1077     44.8034
# 1060    168.4874
# 1061      5.3635
# Name: Return, dtype: float64
# 1.6519684
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[74 43]
#  [64 19]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.54      0.63      0.58       117
#            1       0.31      0.23      0.26        83
#
#     accuracy                           0.47       200
#    macro avg       0.42      0.43      0.42       200
# weighted avg       0.44      0.47      0.45       200
#
# 新數據的預測準確率: 0.465
# 1.9093209032258067
# 最近鄰居中預測值為1的前5筆索引:
# [4, 70, 77, 47, 113]
# 2204    中鋼
# 2270    東元
# 2277    遠雄
# 2247    福懋
# 2313     四維航
# Name: 簡稱, dtype: object
# 2204     55.6115
# 2270     43.5897
# 2277    208.7081
# 2247     63.1100
# 2313     48.1376
# Name: Return, dtype: float64
# 1.8383138
# {1997: 0.8797862941176471, 2000: 1.2118877530864198, 2001: 1.161865423076923, 2002: 1.3718121166666666, 2008: 1.9093209032258067}
# 年均化複利為:0.648931675555719
#
#
# {1997: 0.9804534, 2000: 1.217261, 2001: 1.0053872, 2002: 1.6519684, 2008: 1.8383138}
# 年均化複利為:0.728778236974382
# ori sum2:3.64389118487191
# test years have:5
# after sum2:0.728778236974382
# Optimal k value for minimum error rate: 92
# 1997
# Number of rows in test_data: 200
# confusion_matrix:
# [[95 14]
#  [72 19]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.57      0.87      0.69       109
#            1       0.58      0.21      0.31        91
#
#     accuracy                           0.57       200
#    macro avg       0.57      0.54      0.50       200
# weighted avg       0.57      0.57      0.51       200
#
# 新數據的預測準確率: 0.57
# 0.9310302424242424
# 最近鄰居中預測值為1的前5筆索引:
# [9, 42, 41, 118, 189]
# 9      統一
# 42     正新
# 41     中工
# 118    友訊
# 189    長谷
# Name: 簡稱, dtype: object
# 9     -11.7468
# 42     -8.7819
# 41    -48.5844
# 118    51.1769
# 189   -33.1378
# Name: Return, dtype: float64
# 0.897852
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[80 47]
#  [56 17]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.63      0.61       127
#            1       0.27      0.23      0.25        73
#
#     accuracy                           0.48       200
#    macro avg       0.43      0.43      0.43       200
# weighted avg       0.47      0.48      0.48       200
#
# 新數據的預測準確率: 0.485
# 1.236279421875
# 最近鄰居中預測值為1的前5筆索引:
# [197, 6, 23, 152, 155]
# 797    冠德
# 606    中鋼
# 623    凌陽
# 752    訊連
# 755     所羅門
# Name: 簡稱, dtype: object
# 797    -8.4668
# 606   -22.2052
# 623    13.1168
# 752    11.6716
# 755    37.4582
# Name: Return, dtype: float64
# 1.0631492
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[107  11]
#  [ 58  24]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.65      0.91      0.76       118
#            1       0.69      0.29      0.41        82
#
#     accuracy                           0.66       200
#    macro avg       0.67      0.60      0.58       200
# weighted avg       0.66      0.66      0.61       200
#
# 新數據的預測準確率: 0.655
# 1.1910536
# 最近鄰居中預測值為1的前5筆索引:
# [196, 197, 4, 6, 167]
# 996     潤泰新
# 997    裕民
# 804     聯發科
# 806    南亞
# 967    友尚
# Name: 簡稱, dtype: object
# 996    -6.2619
# 997    68.5185
# 804   -28.8091
# 806    22.4979
# 967    -7.5047
# Name: Return, dtype: float64
# 1.0968814
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[100  16]
#  [ 60  24]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.62      0.86      0.72       116
#            1       0.60      0.29      0.39        84
#
#     accuracy                           0.62       200
#    macro avg       0.61      0.57      0.56       200
# weighted avg       0.61      0.62      0.58       200
#
# 新數據的預測準確率: 0.62
# 1.422322925
# 最近鄰居中預測值為1的前5筆索引:
# [102, 73, 137, 113, 117]
# 1102     永豐餘
# 1073    燁輝
# 1137    憶聲
# 1113    中鼎
# 1117    燦坤
# Name: 簡稱, dtype: object
# 1102    59.5365
# 1073    30.0083
# 1137    -4.9951
# 1113    55.4409
# 1117    12.1743
# Name: Return, dtype: float64
# 1.3043298
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[94 23]
#  [64 19]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.80      0.68       117
#            1       0.45      0.23      0.30        83
#
#     accuracy                           0.56       200
#    macro avg       0.52      0.52      0.49       200
# weighted avg       0.54      0.56      0.53       200
#
# 新數據的預測準確率: 0.565
# 2.0605516904761907
# 最近鄰居中預測值為1的前5筆索引:
# [34, 36, 109, 26, 91]
# 2234    正新
# 2236    寶成
# 2309     中光電
# 2226     日月光
# 2291    榮化
# Name: 簡稱, dtype: object
# 2234    191.1720
# 2236     86.0428
# 2309    189.3970
# 2226    150.2901
# 2291     99.0613
# Name: Return, dtype: float64
# 2.4319264
# {1997: 0.9310302424242424, 2000: 1.236279421875, 2001: 1.1910536, 2002: 1.422322925, 2008: 2.0605516904761907}
# 年均化複利為:0.803569517848047
#
#
# {1997: 0.897852, 2000: 1.0631492, 2001: 1.0968814, 2002: 1.3043298, 2008: 2.4319264}
# 年均化複利為:0.6642422299697354
# ori sum2:3.321211149848677
# test years have:5
# after sum2:0.6642422299697354
# Optimal k value for minimum error rate: 93
# 1997
# Number of rows in test_data: 200
# confusion_matrix:
# [[99 10]
#  [85  6]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.54      0.91      0.68       109
#            1       0.38      0.07      0.11        91
#
#     accuracy                           0.53       200
#    macro avg       0.46      0.49      0.39       200
# weighted avg       0.46      0.53      0.42       200
#
# 新數據的預測準確率: 0.525
# 0.84204525
# 最近鄰居中預測值為1的前5筆索引:
# [159, 162, 12, 177, 63]
# 159     第一店
# 162    中鴻
# 12      英業達
# 177    幸福
# 63     神達
# Name: 簡稱, dtype: object
# 159    50.7524
# 162   -49.8099
# 12     42.6763
# 177   -25.9654
# 63     41.4634
# Name: Return, dtype: float64
# 1.1182336
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[107  20]
#  [ 65   8]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.62      0.84      0.72       127
#            1       0.29      0.11      0.16        73
#
#     accuracy                           0.57       200
#    macro avg       0.45      0.48      0.44       200
# weighted avg       0.50      0.57      0.51       200
#
# 新數據的預測準確率: 0.575
# 1.2159776785714285
# 最近鄰居中預測值為1的前5筆索引:
# [160, 14, 153, 90, 91]
# 760    亞旭
# 614    茂德
# 753    兆赫
# 690     三商行
# 691    東鋼
# Name: 簡稱, dtype: object
# 760    162.3077
# 614     26.6324
# 753     44.9336
# 690     42.8030
# 691    -17.9389
# Name: Return, dtype: float64
# 1.5174756
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[103  15]
#  [ 66  16]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.61      0.87      0.72       118
#            1       0.52      0.20      0.28        82
#
#     accuracy                           0.59       200
#    macro avg       0.56      0.53      0.50       200
# weighted avg       0.57      0.59      0.54       200
#
# 新數據的預測準確率: 0.595
# 1.020156
# 最近鄰居中預測值為1的前5筆索引:
# [69, 70, 39, 47, 185]
# 869    神達
# 870    環電
# 839    國電
# 847    裕隆
# 985    健鼎
# Name: 簡稱, dtype: object
# 869    -28.2708
# 870    -61.6455
# 839     -6.0823
# 847    161.3553
# 985    -25.0833
# Name: Return, dtype: float64
# 1.0805468
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[107   9]
#  [ 74  10]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.92      0.72       116
#            1       0.53      0.12      0.19        84
#
#     accuracy                           0.58       200
#    macro avg       0.56      0.52      0.46       200
# weighted avg       0.56      0.58      0.50       200
#
# 新數據的預測準確率: 0.585
# 1.323986052631579
# 最近鄰居中預測值為1的前5筆索引:
# [1, 40, 83, 26, 30]
# 1001     中華電
# 1040     長榮航
# 1083     統一實
# 1026    瑞昱
# 1030     統一超
# Name: 簡稱, dtype: object
# 1001     3.6275
# 1040    -2.3832
# 1083     4.2042
# 1026   -18.7895
# 1030    14.5980
# Name: Return, dtype: float64
# 1.002514
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[100  17]
#  [ 74   9]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.57      0.85      0.69       117
#            1       0.35      0.11      0.17        83
#
#     accuracy                           0.55       200
#    macro avg       0.46      0.48      0.43       200
# weighted avg       0.48      0.55      0.47       200
#
# 新數據的預測準確率: 0.545
# 1.9771121538461536
# 最近鄰居中預測值為1的前5筆索引:
# [34, 41, 113, 23, 159]
# 2234    正新
# 2241    裕民
# 2313     四維航
# 2223     D 奇美電
# 2359    環電
# Name: 簡稱, dtype: object
# 2234    191.1720
# 2241     80.9351
# 2313     48.1376
# 2223    108.3333
# 2359    162.3377
# Name: Return, dtype: float64
# 2.1818314
# {1997: 0.84204525, 2000: 1.2159776785714285, 2001: 1.020156, 2002: 1.323986052631579, 2008: 1.9771121538461536}
# 年均化複利為:0.5468551833281926
#
#
# {1997: 1.1182336, 2000: 1.5174756, 2001: 1.0805468, 2002: 1.002514, 2008: 2.1818314}
# 年均化複利為:0.8021202217826003
# ori sum2:4.010601108913002
# test years have:5
# after sum2:0.8021202217826003
# Optimal k value for minimum error rate: 32
# 1997
# Number of rows in test_data: 200
# confusion_matrix:
# [[84 25]
#  [65 26]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.56      0.77      0.65       109
#            1       0.51      0.29      0.37        91
#
#     accuracy                           0.55       200
#    macro avg       0.54      0.53      0.51       200
# weighted avg       0.54      0.55      0.52       200
#
# 新數據的預測準確率: 0.55
# 0.8698046666666667
# 最近鄰居中預測值為1的前5筆索引:
# [153, 35, 38, 76, 185]
# 153    統領
# 35     陽明
# 38     福懋
# 76     飛瑞
# 185    宏碁
# Name: 簡稱, dtype: object
# 153   -12.9635
# 35     -3.3784
# 38    -19.8825
# 76      6.8826
# 185    15.1993
# Name: Return, dtype: float64
# 0.971715
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[68 59]
#  [45 28]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.60      0.54      0.57       127
#            1       0.32      0.38      0.35        73
#
#     accuracy                           0.48       200
#    macro avg       0.46      0.46      0.46       200
# weighted avg       0.50      0.48      0.49       200
#
# 新數據的預測準確率: 0.48
# 1.2559947011494252
# 最近鄰居中預測值為1的前5筆索引:
# [173, 14, 87, 25, 29]
# 773    特力
# 614    茂德
# 687    正崴
# 625    華新
# 629     英業達
# Name: 簡稱, dtype: object
# 773     63.6111
# 614     26.6324
# 687    101.7535
# 625    -29.4118
# 629     13.5381
# Name: Return, dtype: float64
# 1.3522466
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[93 25]
#  [46 36]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.67      0.79      0.72       118
#            1       0.59      0.44      0.50        82
#
#     accuracy                           0.65       200
#    macro avg       0.63      0.61      0.61       200
# weighted avg       0.64      0.65      0.63       200
#
# 新數據的預測準確率: 0.645
# 1.1261077540983606
# 最近鄰居中預測值為1的前5筆索引:
# [101, 41, 51, 23, 59]
# 901    世平
# 841     建興電
# 851    長榮
# 823    瑞昱
# 859    東元
# Name: 簡稱, dtype: object
# 901   -33.2513
# 841    20.0347
# 851    80.0281
# 823   -29.2174
# 859    -7.2243
# Name: Return, dtype: float64
# 1.0607396
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[74 42]
#  [53 31]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.64      0.61       116
#            1       0.42      0.37      0.39        84
#
#     accuracy                           0.53       200
#    macro avg       0.50      0.50      0.50       200
# weighted avg       0.52      0.53      0.52       200
#
# 新數據的預測準確率: 0.525
# 1.3480838493150684
# 最近鄰居中預測值為1的前5筆索引:
# [77, 78, 23, 153, 28]
# 1077    和泰
# 1078    台肥
# 1023    華映
# 1153    華立
# 1028    凌陽
# Name: 簡稱, dtype: object
# 1077    44.8034
# 1078    39.1414
# 1023    24.5445
# 1153    20.8175
# 1028    13.6400
# Name: Return, dtype: float64
# 1.2858936
# 2008
# Number of rows in test_data: 200
# confusion_matrix:
# [[75 42]
#  [52 31]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.64      0.61       117
#            1       0.42      0.37      0.40        83
#
#     accuracy                           0.53       200
#    macro avg       0.51      0.51      0.51       200
# weighted avg       0.52      0.53      0.52       200
#
# 新數據的預測準確率: 0.53
# 1.9823056712328768
# 最近鄰居中預測值為1的前5筆索引:
# [164, 70, 77, 47, 155]
# 2364    聯成
# 2270    東元
# 2277    遠雄
# 2247    福懋
# 2355    金寶
# Name: 簡稱, dtype: object
# 2364     78.3224
# 2270     43.5897
# 2277    208.7081
# 2247     63.1100
# 2355     57.0248
# Name: Return, dtype: float64
# 1.90151
# {1997: 0.8698046666666667, 2000: 1.2559947011494252, 2001: 1.1261077540983606, 2002: 1.3480838493150684, 2008: 1.9823056712328768}
# 年均化複利為:0.6575170429770423
#
#
# {1997: 0.971715, 2000: 1.3522466, 2001: 1.0607396, 2002: 1.2858936, 2008: 1.90151}
# 年均化複利為:0.6816120060456609
# ori sum2:3.408060030228304
# test years have:5
# after sum2:0.6816120060456609
# 總共有test year:5
# Number of rows in train_data: 1400
# Optimal k value for minimum error rate: 78
# 1997
# Number of rows in test_data: 200
# confusion_matrix:
# [[83 26]
#  [53 38]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.61      0.76      0.68       109
#            1       0.59      0.42      0.49        91
#
#     accuracy                           0.60       200
#    macro avg       0.60      0.59      0.58       200
# weighted avg       0.60      0.60      0.59       200
#
# 新數據的預測準確率: 0.605
# 0.922266390625
# 最近鄰居中預測值為1的前5筆索引:
# [72, 107, 139, 45, 180]
# 72     凌陽
# 107    光磊
# 139     大台北
# 45     南紡
# 180    精業
# Name: 簡稱, dtype: object
# 72      21.4721
# 107    -12.7740
# 139    -24.7191
# 45     -26.0263
# 180    120.0200
# Name: Return, dtype: float64
# 1.1559454
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[59 68]
#  [33 40]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.64      0.46      0.54       127
#            1       0.37      0.55      0.44        73
#
#     accuracy                           0.49       200
#    macro avg       0.51      0.51      0.49       200
# weighted avg       0.54      0.49      0.50       200
#
# 新數據的預測準確率: 0.495
# 1.3702504722222222
# 最近鄰居中預測值為1的前5筆索引:
# [161, 5, 55, 187, 94]
# 761    燦坤
# 605    台塑
# 655    精碟
# 787     三商電
# 694     統一實
# Name: 簡稱, dtype: object
# 761    157.7938
# 605    -21.7514
# 655      3.9474
# 787     41.6107
# 694     -9.5092
# Name: Return, dtype: float64
# 1.3441826000000001
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[100  18]
#  [ 39  43]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.72      0.85      0.78       118
#            1       0.70      0.52      0.60        82
#
#     accuracy                           0.71       200
#    macro avg       0.71      0.69      0.69       200
# weighted avg       0.71      0.71      0.71       200
#
# 新數據的預測準確率: 0.715
# 1.1971063442622951
# 最近鄰居中預測值為1的前5筆索引:
# [162, 46, 113, 152, 123]
# 962    福聚
# 846    中華
# 913    敬鵬
# 952    億豐
# 923     偉詮電
# Name: 簡稱, dtype: object
# 962     24.5744
# 846    191.9494
# 913    -24.0684
# 952     96.6168
# 923    -30.1866
# Name: Return, dtype: float64
# 1.5177711999999999
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[70 46]
#  [46 38]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.60      0.60      0.60       116
#            1       0.45      0.45      0.45        84
#
#     accuracy                           0.54       200
#    macro avg       0.53      0.53      0.53       200
# weighted avg       0.54      0.54      0.54       200
#
# 新數據的預測準確率: 0.54
# 1.341500291547619
# 最近鄰居中預測值為1的前5筆索引:
# [6, 109, 115, 117, 125]
# 1006    中鋼
# 1109    豐泰
# 1115    永大
# 1117    燦坤
# 1125    大陸
# Name: 簡稱, dtype: object
# 1006    56.1449
# 1109    27.7822
# 1115   -10.5798
# 1117    12.1743
# 1125    31.6045
# Name: Return, dtype: float64
# 1.2342522
# 2007
# Number of rows in test_data: 200
# confusion_matrix:
# [[102  10]
#  [ 71  17]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.91      0.72       112
#            1       0.63      0.19      0.30        88
#
#     accuracy                           0.59       200
#    macro avg       0.61      0.55      0.51       200
# weighted avg       0.61      0.59      0.53       200
#
# 新數據的預測準確率: 0.595
# 0.5604645000000001
# 最近鄰居中預測值為1的前5筆索引:
# [71, 170, 88, 89, 126]
# 2071     英業達
# 2170    金寶
# 2088    東元
# 2089    東聯
# 2126     中石化
# Name: 簡稱, dtype: object
# 2071   -44.0217
# 2170   -39.3788
# 2088   -32.9032
# 2089   -61.5046
# 2126   -47.2881
# Name: Return, dtype: float64
# 0.5498072
# {1997: 0.922266390625, 2000: 1.3702504722222222, 2001: 1.1971063442622951, 2002: 1.341500291547619, 2007: 0.5604645000000001}
# 年均化複利為:0.2274877166690097
#
#
# {1997: 1.1559454, 2000: 1.3441826000000001, 2001: 1.5177711999999999, 2002: 1.2342522, 2007: 0.5498072}
# 年均化複利為:0.32007092624209255
# ori sum2:1.6003546312104626
# test years have:5
# after sum2:0.32007092624209255
# Optimal k value for minimum error rate: 83
# 1997
# Number of rows in test_data: 200
# confusion_matrix:
# [[91 18]
#  [66 25]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.83      0.68       109
#            1       0.58      0.27      0.37        91
#
#     accuracy                           0.58       200
#    macro avg       0.58      0.55      0.53       200
# weighted avg       0.58      0.58      0.54       200
#
# 新數據的預測準確率: 0.58
# 0.8741387674418605
# 最近鄰居中預測值為1的前5筆索引:
# [0, 139, 56, 185, 156]
# 0       台積電
# 139     大台北
# 56     藍天
# 185    宏碁
# 156    瑞昱
# Name: 簡稱, dtype: object
# 0      -6.3648
# 139   -24.7191
# 56    -49.1160
# 185    15.1993
# 156    -2.4571
# Name: Return, dtype: float64
# 0.8650846
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[87 40]
#  [51 22]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.63      0.69      0.66       127
#            1       0.35      0.30      0.33        73
#
#     accuracy                           0.55       200
#    macro avg       0.49      0.49      0.49       200
# weighted avg       0.53      0.55      0.54       200
#
# 新數據的預測準確率: 0.545
# 1.516121548387097
# 最近鄰居中預測值為1的前5筆索引:
# [64, 129, 130, 83, 88]
# 664    微星
# 729    豐興
# 730    建碁
# 683    智邦
# 688    統領
# Name: 簡稱, dtype: object
# 664    401.5549
# 729    -19.5652
# 730    238.3350
# 683    257.5379
# 688      7.2216
# Name: Return, dtype: float64
# 2.7701683999999998
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[103  15]
#  [ 59  23]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.64      0.87      0.74       118
#            1       0.61      0.28      0.38        82
#
#     accuracy                           0.63       200
#    macro avg       0.62      0.58      0.56       200
# weighted avg       0.62      0.63      0.59       200
#
# 新數據的預測準確率: 0.63
# 1.1332625789473685
# 最近鄰居中預測值為1的前5筆索引:
# [134, 75, 115, 60, 30]
# 934    藍天
# 875    萬海
# 915    豐泰
# 860    研華
# 830     統一超
# Name: 簡稱, dtype: object
# 934    -43.5801
# 875    136.3281
# 915     21.0271
# 860    -13.7011
# 830    -19.5689
# Name: Return, dtype: float64
# 1.1610102
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[87 29]
#  [61 23]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.75      0.66       116
#            1       0.44      0.27      0.34        84
#
#     accuracy                           0.55       200
#    macro avg       0.52      0.51      0.50       200
# weighted avg       0.53      0.55      0.52       200
#
# 新數據的預測準確率: 0.55
# 1.3417104038461538
# 最近鄰居中預測值為1的前5筆索引:
# [195, 102, 6, 173, 125]
# 1195    神基
# 1102     永豐餘
# 1006    中鋼
# 1173    中碳
# 1125    大陸
# Name: 簡稱, dtype: object
# 1195   -26.8638
# 1102    59.5365
# 1006    56.1449
# ...
#    macro avg       0.71      0.61      0.58       200
# weighted avg       0.70      0.64      0.59       200
#
# 新數據的預測準確率: 0.64
# 1.0075116451612902
# 最近鄰居中預測值為1的前5筆索引:
# [0, 4, 42, 24, 26]
# 0      台積電
# 4     華碩
# 42    正新
# 24    中華
# 26    矽品
# Name: 簡稱, dtype: object
# 0     -6.3648
# 4     46.2737
# 42    -8.7819
# 24     7.0642
# 26     2.0266
# Name: Return, dtype: float64
# 1.0804356
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[86 41]
#  [46 27]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.65      0.68      0.66       127
#            1       0.40      0.37      0.38        73
#
#     accuracy                           0.56       200
#    macro avg       0.52      0.52      0.52       200
# weighted avg       0.56      0.56      0.56       200
#
# 新數據的預測準確率: 0.565
# 1.517572588235294
# 最近鄰居中預測值為1的前5筆索引:
# [69, 18, 122, 156, 93]
# 669    和泰
# 618    仁寶
# 722    裕融
# 756    東聯
# 693    世平
# Name: 簡稱, dtype: object
# 669   -21.8910
# 618    26.4574
# 722    34.3210
# 756    23.0548
# 693    45.8974
# Name: Return, dtype: float64
# 1.2156791999999998
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[103  15]
#  [ 59  23]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.64      0.87      0.74       118
#            1       0.61      0.28      0.38        82
#
#     accuracy                           0.63       200
#    macro avg       0.62      0.58      0.56       200
# weighted avg       0.62      0.63      0.59       200
#
# 新數據的預測準確率: 0.63
# 1.211232342105263
# 最近鄰居中預測值為1的前5筆索引:
# [32, 3, 67, 47, 88]
# 832     英業達
# 803    鴻海
# 867    D 復盛
# 847    裕隆
# 888    瑞軒
# Name: 簡稱, dtype: object
# 832    -15.9319
# 803    -11.6540
# 867      7.1197
# 847    161.3553
# 888    -16.4050
# Name: Return, dtype: float64
# 1.2489682
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[85 31]
#  [63 21]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.57      0.73      0.64       116
#            1       0.40      0.25      0.31        84
#
#     accuracy                           0.53       200
#    macro avg       0.49      0.49      0.48       200
# weighted avg       0.50      0.53      0.50       200
#
# 新數據的預測準確率: 0.53
# 1.335299475
# 最近鄰居中預測值為1的前5筆索引:
# [133, 73, 139, 174, 175]
# 1133    遠雄
# 1073    燁輝
# 1139    普誠
# 1174    晶電
# 1175    帆宣
# Name: 簡稱, dtype: object
# 1133    30.7607
# 1073    30.0083
# 1139   -12.9662
# 1174    50.9554
# 1175    15.1093
# Name: Return, dtype: float64
# 1.227735
# 2007
# Number of rows in test_data: 200
# confusion_matrix:
# [[104   8]
#  [ 82   6]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.56      0.93      0.70       112
#            1       0.43      0.07      0.12        88
#
#     accuracy                           0.55       200
#    macro avg       0.49      0.50      0.41       200
# weighted avg       0.50      0.55      0.44       200
#
# 新數據的預測準確率: 0.55
# 0.5070614999999999
# 最近鄰居中預測值為1的前5筆索引:
# [2, 199, 71, 154, 157]
# 2002     台塑化
# 2199    宏盛
# 2071     英業達
# 2154     光洋科
# 2157    信義
# Name: 簡稱, dtype: object
# 2002   -24.6554
# 2199   -60.2684
# 2071   -44.0217
# 2154   -41.5895
# 2157   -56.2835
# Name: Return, dtype: float64
# 0.5463629999999999
# {1997: 1.0075116451612902, 2000: 1.517572588235294, 2001: 1.211232342105263, 2002: 1.335299475, 2007: 0.5070614999999999}
# 年均化複利為:0.25078197449172973
#
#
# {1997: 1.0804356, 2000: 1.2156791999999998, 2001: 1.2489682, 2002: 1.227735, 2007: 0.5463629999999999}
# 年均化複利為:0.22008232535520098
# ori sum2:1.100411626776005
# test years have:5
# after sum2:0.22008232535520098
# Optimal k value for minimum error rate: 37
# 1997
# Number of rows in test_data: 200
# confusion_matrix:
# [[98 11]
#  [69 22]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.90      0.71       109
#            1       0.67      0.24      0.35        91
#
#     accuracy                           0.60       200
#    macro avg       0.63      0.57      0.53       200
# weighted avg       0.62      0.60      0.55       200
#
# 新數據的預測準確率: 0.6
# 0.980343393939394
# 最近鄰居中預測值為1的前5筆索引:
# [33, 103, 42, 111, 58]
# 33      統一超
# 103    D 復盛
# 42     正新
# 111    燁輝
# 58      統一實
# Name: 簡稱, dtype: object
# 33     24.9683
# 103    -8.6990
# 42     -8.7819
# 111   -27.8249
# 58    -25.0199
# Name: Return, dtype: float64
# 0.9092852
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[83 44]
#  [41 32]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.67      0.65      0.66       127
#            1       0.42      0.44      0.43        73
#
#     accuracy                           0.57       200
#    macro avg       0.55      0.55      0.55       200
# weighted avg       0.58      0.57      0.58       200
#
# 新數據的預測準確率: 0.575
# 1.4973070263157895
# 最近鄰居中預測值為1的前5筆索引:
# [19, 84, 23, 88, 59]
# 619     日月光
# 684    宏碁
# 623    凌陽
# 688    統領
# 659    金寶
# Name: 簡稱, dtype: object
# 619    74.2887
# 684    39.6409
# 623    13.1168
# 688     7.2216
# 659    84.2900
# Name: Return, dtype: float64
# 1.437116
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[102  16]
#  [ 54  28]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.65      0.86      0.74       118
#            1       0.64      0.34      0.44        82
#
#     accuracy                           0.65       200
#    macro avg       0.65      0.60      0.59       200
# weighted avg       0.65      0.65      0.62       200
#
# 新數據的預測準確率: 0.65
# 1.2532195227272727
# 最近鄰居中預測值為1的前5筆索引:
# [65, 2, 67, 41, 121]
# 865    正新
# 802     中華電
# 867    D 復盛
# 841     建興電
# 921    巨大
# Name: 簡稱, dtype: object
# 865    94.4010
# 802     5.7753
# 867     7.1197
# 841    20.0347
# 921    50.6470
# Name: Return, dtype: float64
# 1.3559554
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[81 35]
#  [60 24]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.57      0.70      0.63       116
#            1       0.41      0.29      0.34        84
#
#     accuracy                           0.53       200
#    macro avg       0.49      0.49      0.48       200
# weighted avg       0.50      0.53      0.51       200
#
# 新數據的預測準確率: 0.525
# 1.2700342288135593
# 最近鄰居中預測值為1的前5筆索引:
# [132, 105, 109, 56, 125]
# 1132    世平
# 1105    豐興
# 1109    豐泰
# 1056    精英
# 1125    大陸
# Name: 簡稱, dtype: object
# 1132    17.5882
# 1105    23.2274
# 1109    27.7822
# 1056   -25.2116
# 1125    31.6045
# Name: Return, dtype: float64
# 1.1499814
# 2007
# Number of rows in test_data: 200
# confusion_matrix:
# [[90 22]
#  [55 33]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.62      0.80      0.70       112
#            1       0.60      0.38      0.46        88
#
#     accuracy                           0.61       200
#    macro avg       0.61      0.59      0.58       200
# weighted avg       0.61      0.61      0.60       200
#
# 新數據的預測準確率: 0.615
# 0.5564908036363636
# 最近鄰居中預測值為1的前5筆索引:
# [6, 77, 120, 185, 154]
# 2006    中鋼
# 2077    世界
# 2120    中保
# 2185    中鼎
# 2154     光洋科
# Name: 簡稱, dtype: object
# 2006   -40.65110
# 2077   -66.10410
# 2120     0.83672
# 2185     9.64380
# 2154   -41.58950
# Name: Return, dtype: float64
# 0.72427164
# {1997: 0.980343393939394, 2000: 1.4973070263157895, 2001: 1.2532195227272727, 2002: 1.2700342288135593, 2007: 0.5564908036363636}
# 年均化複利為:0.2600277237350853
#
#
# {1997: 0.9092852, 2000: 1.437116, 2001: 1.3559554, 2002: 1.1499814, 2007: 0.72427164}
# 年均化複利為:0.2951614557761091
# ori sum2:1.4758072788805454
# test years have:5
# after sum2:0.2951614557761091
# Optimal k value for minimum error rate: 43
# 1997
# Number of rows in test_data: 200
# confusion_matrix:
# [[94 15]
#  [70 21]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.57      0.86      0.69       109
#            1       0.58      0.23      0.33        91
#
#     accuracy                           0.57       200
#    macro avg       0.58      0.55      0.51       200
# weighted avg       0.58      0.57      0.53       200
#
# 新數據的預測準確率: 0.575
# 0.9560889166666666
# 最近鄰居中預測值為1的前5筆索引:
# [2, 111, 24, 185, 187]
# 2      中鋼
# 111    燁輝
# 24     中華
# 185    宏碁
# 187    巨大
# Name: 簡稱, dtype: object
# 2      -9.2224
# 111   -27.8249
# 24      7.0642
# 185    15.1993
# 187    57.0196
# Name: Return, dtype: float64
# 1.0844716
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[74 53]
#  [43 30]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.63      0.58      0.61       127
#            1       0.36      0.41      0.38        73
#
#     accuracy                           0.52       200
#    macro avg       0.50      0.50      0.50       200
# weighted avg       0.53      0.52      0.53       200
#
# 新數據的預測準確率: 0.52
# 1.4213930843373495
# 最近鄰居中預測值為1的前5筆索引:
# [2, 35, 174, 23, 189]
# 602    聯電
# 635    東元
# 774    大成
# 623    凌陽
# 789    昆盈
# Name: 簡稱, dtype: object
# 602    26.1251
# 635   -30.0532
# 774    11.3426
# 623    13.1168
# 789    72.3642
# Name: Return, dtype: float64
# 1.185791
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[100  18]
#  [ 55  27]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.65      0.85      0.73       118
#            1       0.60      0.33      0.43        82
#
#     accuracy                           0.64       200
#    macro avg       0.62      0.59      0.58       200
# weighted avg       0.63      0.64      0.61       200
#
# 新數據的預測準確率: 0.635
# 1.110205688888889
# 最近鄰居中預測值為1的前5筆索引:
# [65, 2, 4, 23, 122]
# 865    正新
# 802     中華電
# 804     聯發科
# 823    瑞昱
# 922    大陸
# Name: 簡稱, dtype: object
# 865    94.4010
# 802     5.7753
# 804   -28.8091
# 823   -29.2174
# 922     7.8671
# Name: Return, dtype: float64
# 1.1000338
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[82 34]
#  [58 26]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.71      0.64       116
#            1       0.43      0.31      0.36        84
#
#     accuracy                           0.54       200
#    macro avg       0.51      0.51      0.50       200
# weighted avg       0.52      0.54      0.52       200
#
# 新數據的預測準確率: 0.54
# 1.3426989
# 最近鄰居中預測值為1的前5筆索引:
# [35, 7, 77, 153, 60]
# 1035    統一
# 1007    台化
# 1077    和泰
# 1153    華立
# 1060    陽明
# Name: 簡稱, dtype: object
# 1035     33.1845
# 1007     74.1454
# 1077     44.8034
# 1153     20.8175
# 1060    168.4874
# Name: Return, dtype: float64
# 1.6828764
# 2007
# Number of rows in test_data: 200
# confusion_matrix:
# [[85 27]
#  [56 32]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.60      0.76      0.67       112
#            1       0.54      0.36      0.44        88
#
#     accuracy                           0.58       200
#    macro avg       0.57      0.56      0.55       200
# weighted avg       0.58      0.58      0.57       200
#
# 新數據的預測準確率: 0.585
# 0.5451269864406779
# 最近鄰居中預測值為1的前5筆索引:
# [131, 101, 77, 185, 187]
# 2131    巨大
# 2101     大聯大
# 2077    世界
# 2185    中鼎
# 2187    技嘉
# Name: 簡稱, dtype: object
# 2131     9.7722
# 2101   -55.6668
# 2077   -66.1041
# 2185     9.6438
# 2187   -41.6760
# Name: Return, dtype: float64
# 0.7119382
# {1997: 0.9560889166666666, 2000: 1.4213930843373495, 2001: 1.110205688888889, 2002: 1.3426989, 2007: 0.5451269864406779}
# 年均化複利為:0.2208626309545842
#
#
# {1997: 1.0844716, 2000: 1.185791, 2001: 1.1000338, 2002: 1.6828764, 2007: 0.7119382}
# 年均化複利為:0.3389665745927994
# ori sum2:1.694832872963997
# test years have:5
# after sum2:0.3389665745927994
# Optimal k value for minimum error rate: 80
# 1997
# Number of rows in test_data: 200
# confusion_matrix:
# [[88 21]
#  [65 26]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.58      0.81      0.67       109
#            1       0.55      0.29      0.38        91
#
#     accuracy                           0.57       200
#    macro avg       0.56      0.55      0.52       200
# weighted avg       0.57      0.57      0.54       200
#
# 新數據的預測準確率: 0.57
# 0.9142594893617021
# 最近鄰居中預測值為1的前5筆索引:
# [9, 42, 14, 115, 187]
# 9      統一
# 42     正新
# 14     裕隆
# 115    宏遠
# 187    巨大
# Name: 簡稱, dtype: object
# 9     -11.7468
# 42     -8.7819
# 14      1.1003
# 115     7.4286
# 187    57.0196
# Name: Return, dtype: float64
# 1.0900395999999999
# 2000
# Number of rows in test_data: 200
# confusion_matrix:
# [[76 51]
#  [53 20]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.60      0.59       127
#            1       0.28      0.27      0.28        73
#
#     accuracy                           0.48       200
#    macro avg       0.44      0.44      0.44       200
# weighted avg       0.48      0.48      0.48       200
#
# 新數據的預測準確率: 0.48
# 1.2741488309859155
# 最近鄰居中預測值為1的前5筆索引:
# [35, 6, 23, 152, 155]
# 635    東元
# 606    中鋼
# 623    凌陽
# 752    訊連
# 755     所羅門
# Name: 簡稱, dtype: object
# 635   -30.0532
# 606   -22.2052
# 623    13.1168
# 752    11.6716
# 755    37.4582
# Name: Return, dtype: float64
# 1.0199764
# 2001
# Number of rows in test_data: 200
# confusion_matrix:
# [[97 21]
#  [57 25]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.63      0.82      0.71       118
#            1       0.54      0.30      0.39        82
#
#     accuracy                           0.61       200
#    macro avg       0.59      0.56      0.55       200
# weighted avg       0.59      0.61      0.58       200
#
# 新數據的預測準確率: 0.61
# 1.0504102391304349
# 最近鄰居中預測值為1的前5筆索引:
# [196, 4, 102, 6, 139]
# 996     潤泰新
# 804     聯發科
# 902    遠雄
# 806    南亞
# 939    裕融
# Name: 簡稱, dtype: object
# 996    -6.2619
# 804   -28.8091
# 902   -15.3128
# 806    22.4979
# 939    -5.2083
# Name: Return, dtype: float64
# 0.9338116000000001
# 2002
# Number of rows in test_data: 200
# confusion_matrix:
# [[89 27]
#  [58 26]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.61      0.77      0.68       116
#            1       0.49      0.31      0.38        84
#
#     accuracy                           0.57       200
#    macro avg       0.55      0.54      0.53       200
# weighted avg       0.56      0.57      0.55       200
#
# 新數據的預測準確率: 0.575
# 1.3296480188679245
# 最近鄰居中預測值為1的前5筆索引:
# [38, 73, 137, 117, 153]
# 1038    正新
# 1073    燁輝
# 1137    憶聲
# 1117    燦坤
# 1153    華立
# Name: 簡稱, dtype: object
# 1038    14.8024
# 1073    30.0083
# 1137    -4.9951
# 1117    12.1743
# 1153    20.8175
# Name: Return, dtype: float64
# 1.1456148
# 2007
# Number of rows in test_data: 200
# confusion_matrix:
# [[86 26]
#  [59 29]]
# classification_report
#               precision    recall  f1-score   support
#
#           -1       0.59      0.77      0.67       112
#            1       0.53      0.33      0.41        88
#
#     accuracy                           0.57       200
#    macro avg       0.56      0.55      0.54       200
# weighted avg       0.56      0.57      0.55       200
#
# 新數據的預測準確率: 0.575
# 0.51584384
# 最近鄰居中預測值為1的前5筆索引:
# [101, 45, 148, 185, 154]
# 2101     大聯大
# 2045    大同
# 2148     四維航
# 2185    中鼎
# 2154     光洋科
# Name: 簡稱, dtype: object
# 2101   -55.6668
# 2045   -61.3333
# 2148   -28.1600
# 2185     9.6438
# 2154   -41.5895
# Name: Return, dtype: float64
# 0.6457884
# {1997: 0.9142594893617021, 2000: 1.2741488309859155, 2001: 1.0504102391304349, 2002: 1.3296480188679245, 2007: 0.51584384}
# 年均化複利為:0.16785470477103087
#
#
# {1997: 1.0900395999999999, 2000: 1.0199764, 2001: 0.9338116000000001, 2002: 1.1456148, 2007: 0.6457884}
# 年均化複利為:0.15362097403742206
# ori sum2:0.7681048701871103
# test years have:5
# after sum2:0.15362097403742206
